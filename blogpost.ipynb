# %% [markdown]
# # Contents
#
# 1. [Project birds-eye view](#Project-at-a-glance)
#     - [Survey existing projects](#Survey); take notes (on datasets; research questions)
#     - [Data](#Data)
#          - [Get data](#Get-data)
#          - [Explore data](#Explore-data)
#          - [Pre-process data](#Preprocess-data)
#     - [Label recipes](#Label-recipes-as-W/NW) (based on ingredients? based on name?) as W or NW
#          - Define W/NW depending on:
#              - if non-fusion:
#                  - country of origin (straightforward for non-fusion recipes)
#              - if fusion:
#                  - recipes can be conceptualized as principal ingredient + form; ingredient and form can be of independent origins (e.g., matcha (NW) muffins (W); chocolate (W) zongzi (NW))—what to do in this case?
#                      - option 1: exclude
#                      - option 2: label based on country of origin of form
#     - Analyze words that are most marked for being NW
#
# 2. [Developing a classifier](#Develop-classifier)
#     - Assemble dataset of labeled W/NW recipes
#          - [Wikipedia cuisine portal](#Get-Wikipedia-data)
#          - Recipe collections (NYT, Bon Appétit, Food52, etc.)
#          - manual labeling to understand potential problem cases (e.g. fusion recipes; long names)
#     - Experiment w/ different models, baselines
#         - Filter adjectives and other modifiers from recipe titles so just nouns remain
#         - Look for explicit country-of-origin modifiers (e.g. “Turkish”, “Asian”)
#     - Some qualitative analysis
#
# 3. Analysis
#     - Assemble multiple different corpora of recipes/food-writing (preferably at least some distinct from training data)
#          - NYT Cooking columns
#          - Bon Appétit, Food52, food blogs
#          - Cookbooks (would be especially suited for longitudinal analysis)
#     - Ask research questions
#         - H: Length of adjectives in recipe title longer for NW than W (just introduced as in; no need to “hype up”)
#         - Do recipes belonging to multiple countries (e.g., baklava) get described differently when it’s framed as Western (=Greek) vs. Non-Western (=Turkish)?

# %% [markdown]
# # Project at a glance

# %% [markdown]
# ## Survey

# %% [markdown]
# - Data
#     - scraper from foodnetwork, epicurious, allrecipes (https://github.com/rtlee9/recipe-box)
#     - Food.com recipes (https://www.kaggle.com/shuyangli94/food-com-recipes-and-user-interactions?select=PP_recipes.csv)
#     - dataset w/ cuisine annotations (https://old.datahub.io/dataset/recipe-dataset)
#     - Recipe1M+ (https://luisrita.medium.com/recipe1m-dataset-2ecb62a43804)
# - Analysis
#     - Priya Krishna and Yewande Komolafe conversation (https://www.bonappetit.com/story/recipe-writing-whitewashed) with ideas for differences
#         - modifiers indexing “approachability” (“It's why modifiers like “simple” or “weeknight” that many publications (including BA) have historically added always make me laugh. Indian is my weeknight food. There's no weeknight dal and then dal. It's all just dal. It’s as if our food needs to be made more approachable.”)
#         - “translating” into familiar terms (“The recipe title reads "Kadhi," and then in parentheses "Turmeric Yogurt Soup.” Of course, people in the South Asian community were like, "What are you doing calling it a soup?””)
#         - having a technical term for everything (vs. intuitive description) (“It blew my mind when I first moved here how there’s a name for everything. Like, in Nigerian cooking there's this process where you take a starch and you pound it, but there’s no technical name for it. I think the way we write recipes now almost demands that we have one word for a given technique. When you throw spices in oil, it's called blooming. But do you bloom onions, too? Do you bloom dried fish?”)
#         - italicizing unfamiliar terms (“Last year when my book was coming out, I had to take a stand against italicizing non-English words. It's a way that Western publications literally "other" non-white foods: they make them look different. But why can't dal and jollof rice and macaroni and cheese all exist in the same font style?”)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Get data

# %% [markdown]
# - Recipe1M+ dataset: problems with download :(
# - Bon Appetit/NYT Cooking: scraped using modified code from [recipe-box](https://github.com/rtlee9/recipe-box)
#     - Modified code to additionally scrape free-form text and keywords
#     - `python get_recipes.py --nyt --ba` from within `./recipe-box/src` to get recipes
#     - `python get_recipes.py --nyt_cuisine` to get the titles of recipes belonging to each cuisine category (as categorized by NYT); BA does not practice any categorization

# %%
import os
import json
import glob
from collections import defaultdict

# %%
DOMAIN_CODES = {
    'Bon Appetit': 'ba',
    'NYT Cooking': 'nyt',
}

# %%
path_to_jsons = {code: 
                 'recipe-box/data/recipes_raw_{}.json'.format(code)
                for code in DOMAIN_CODES.values()}
path_to_jsons
# Out:
# {'ba': 'recipe-box/data/recipes_raw_ba.json',
#  'nyt': 'recipe-box/data/recipes_raw_nyt.json'}

# %%
with open(path_to_jsons['ba']) as f:
    ba_data = json.load(f)
    
with open(path_to_jsons['nyt']) as f:
    nyt_data = json.load(f)

# %% [markdown]
# Scraped 10.3K and 8.9K recipes from BA, NYT respectively.

# %%
len(ba_data.keys()),len(nyt_data.keys())
# Out:
# (10264, 8910)

# %% [markdown]
# Let's also collect the titles of recipes categorized by cuisine, from NYT:

# %%
# These are the cuisine filters, which I have assigned to 
# 'west' or 'non-west' based on my own intuitions

nyt_cuisine_types = {'west': [
    'American','Australian','Austrian','Belgian','British',
    'Canadian','Eastern%20European','French','German','Greek',
    'Icelandic','Irish','Italian','Jewish','Mediterranean',
    'New%20England','Portuguese','Provencal','Russian','Scandinavian',
    'Southern','Southwestern','Spanish'],
                    'non_west': [
    'African','Asian','Brazilian','Cajun','Caribbean',
    'Central%20American','Chinese','Creole','Cuban','Ethiopian',
    'Filipino','Indian','Indonesian','Japanese','Korean',
    'Latin%20American','Malaysian','Mexican','Middle%20Eastern',
    'Moroccan','Pakistani','South%20American','Thai','Tibetan',
    'Turkish','Vietnamese']}

cuisine2type = {cuisine: cuisine_type 
               for cuisine_type in ['west','non_west']
               for cuisine in nyt_cuisine_types[cuisine_type]}

# %% [markdown]
# We'll create a dictionary with (cuisine, list of recipes) key, val pairs.

# %%
recipes_per_cuisine = {}

for file in glob.glob('./recipe-box/data/per_cuisine/*.txt'):
    with open(file, 'r') as f:
        recipe_urls = f.read().splitlines()
    recipe_urls = ['http://cooking.nytimes.com/'+r for r in recipe_urls]
    recipe_titles = [" ".join([c for c in r.split('/')[-1].split('-')
                              if c.isalpha()]) 
                     for r in recipe_urls]
    recipes_per_cuisine[file.split('/')[-1][:-4]] = recipe_urls

# %% [markdown]
# And another dictionary with (recipe URL, set of cuisines) key, val pairs (as a recipe can belong to multiple cuisines).

# %%
recipe2cuisine = defaultdict(set)

for cuisine in recipes_per_cuisine:
    for r in recipes_per_cuisine[cuisine]:
        recipe2cuisine[r].add(cuisine)

# %%
recipe2cuisine['http://cooking.nytimes.com//recipes/1980-macadamia-meringue-triangles']
# Out:
# {'French'}

# %%
all_cuisine_urls = [recipes_per_cuisine[cuisine]
                    for cuisine in recipes_per_cuisine]
all_cuisine_urls = [item for sublist in all_cuisine_urls 
                   for item in sublist]
len(all_cuisine_urls)
# Out:
# 15419

# %% [markdown]
# ### Explore data

# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# Let's create a dataframe to store all the recipes, with the URL as the index.

# %%
df = pd.read_json(path_to_jsons['ba'],orient='index').append(
pd.read_json(path_to_jsons['nyt'],orient='index'))
df.shape
# Out:
# (19174, 4)

# %%
df.tail()
# Out:
#                                                                                             title  \
# http://cooking.nytimes.com//recipes/1739-hooten...               Hootenholler Whiskey Quick Bread
# http://cooking.nytimes.com//recipes/1740-braise...  Braised Chicken With Artichokes and Mushrooms
# http://cooking.nytimes.com//recipes/1878-roquef...                      Roquefort-and-Pear Eggnog
# http://cooking.nytimes.com//recipes/1877-1958-e...                                   1958: Eggnog
# http://cooking.nytimes.com//recipes/1015818-whi...                               White Bark Balls
#
#                                                                  author  \
# http://cooking.nytimes.com//recipes/1739-hooten...         Alex Witchel
# http://cooking.nytimes.com//recipes/1740-braise...         Alex Witchel
# http://cooking.nytimes.com//recipes/1878-roquef...        Amanda Hesser
# http://cooking.nytimes.com//recipes/1877-1958-e...        Amanda Hesser
# http://cooking.nytimes.com//recipes/1015818-whi...  Jennifer Steinhauer
#
#                                                                                           description  \
# http://cooking.nytimes.com//recipes/1739-hooten...  This recipe is adapted from the “I Hate to Coo...
# http://cooking.nytimes.com//recipes/1740-braise...  The men who ruled the world in the late 1950s,...
# http://cooking.nytimes.com//recipes/1878-roquef...  This fascinating recipe came to The Times in a...
# http://cooking.nytimes.com//recipes/1877-1958-e...  This recipe appeared in The Times in an articl...
# http://cooking.nytimes.com//recipes/1015818-whi...                                               None
#
#                                                                                                 steps
# http://cooking.nytimes.com//recipes/1739-hooten...  First, take the bourbon out of the cupboard an...
# http://cooking.nytimes.com//recipes/1740-braise...  Preheat the oven to 375 degrees. Mix together ...
# http://cooking.nytimes.com//recipes/1878-roquef...  One to two days before making the eggnog, comb...
# http://cooking.nytimes.com//recipes/1877-1958-e...  In an electric mixer, beat the egg yolks with ...
# http://cooking.nytimes.com//recipes/1015818-whi...  In a medium bowl, combine Rice Krispies, peanu...

# %% [markdown]
# We'll add a column indicating whether the recipe comes from BA or NYT.

# %%
df['source'] = ['ba' if url.startswith('http://www.bonappetit.com')
               else 'nyt' for url in df.index.values]
df['source'].value_counts()
# Out:
# ba     10264
# nyt     8910
# Name: source, dtype: int64

# %% [markdown]
# It looks like there are 5.5K recipes that do not have a cuisine category label:

# %%
len(set(df.loc[df['source']=='nyt'].index.values).difference(
    set(all_cuisine_urls)))
# Out:
# 5506

# %% [markdown]
# Let's see who the recipes are coming from over at NYT and BA:

# %%
df.loc[df['source']=='nyt']['author'].value_counts()
# Out:
# Martha Rose Shulman                                1632
# Melissa Clark                                       963
# Mark Bittman                                        664
# David Tanis                                         578
# Sam Sifton                                          248
#                                                    ...
# Recipe from Gladys Puglla-Jimenez                     1
# Recipe from Philip Greene                             1
# Recipe from “VegNews Holiday Cookie Collection”       1
# Recipe from Ree Drummond                              1
# Recipe from Robbie Richter and Zakary Pelaccio        1
# Name: author, Length: 1809, dtype: int64

# %%
df.loc[df['source']=='ba']['author'].value_counts()
# Out:
# Claire Saffitz                                    474
# The Bon Appétit Test Kitchen                      376
# Chris Morocco                                     374
# Andy Baraghani                                    298
# Alison Roman                                      291
#                                                  ...
# Bluewater Cafe New Canaan CT                        1
# Clyde Cooper s Barbecue Raleigh North Carolina      1
# Victoria Granof                                     1
# Judith Fertig and Karen Adler                       1
# Adam Sachs                                          1
# Name: author, Length: 1563, dtype: int64

# %% [markdown]
# It looks like some regularization is called for. We'll do that in the [Regularize authors](#Regularize-authors) section below.

# %% [markdown]
# Finally, let's explore the cuisine breakdown of recipes from NYT.

# %%
counts_per_cuisine = {item[0]: len(item[1])
 for item in sorted(recipes_per_cuisine.items(), 
      key=lambda x: len(x[1]), reverse=True)}

counts_per_cuisine
# Out:
# {'American': 2554,
#  'Italian': 1656,
#  'Central%20American': 1610,
#  'Latin%20American': 1610,
#  'South%20American': 1610,
#  'French': 1494,
#  'Asian': 631,
#  'Mediterranean': 460,
#  'Southern': 404,
#  'Mexican': 388,
#  'Chinese': 294,
#  'Indian': 287,
#  'Jewish': 217,
#  'Spanish': 202,
#  'British': 172,
#  'Greek': 170,
#  'Japanese': 139,
#  'Thai': 118,
#  'Caribbean': 116,
#  'Southwestern': 110,
#  'Moroccan': 105,
#  'Vietnamese': 99,
#  'Scandinavian': 95,
#  'African': 92,
#  'Korean': 92,
#  'German': 78,
#  'Irish': 60,
#  'Turkish': 60,
#  'Cajun': 54,
#  'Creole': 52,
#  'Russian': 52,
#  'Eastern%20European': 47,
#  'Portuguese': 42,
#  'Middle%20Eastern': 41,
#  'Indonesian': 28,
#  'Austrian': 25,
#  'Filipino': 24,
#  'Brazilian': 22,
#  'Cuban': 18,
#  'Provencal': 18,
#  'Canadian': 17,
#  'New%20England': 14,
#  'Belgian': 12,
#  'Australian': 11,
#  'Malaysian': 10,
#  'Pakistani': 4,
#  'Ethiopian': 2,
#  'Tibetan': 2,
#  'Icelandic': 1}

# %%
counts_per_cuisine_type = defaultdict(int)
for cuisine_type in ['west','non_west']:
    for cuisine in nyt_cuisine_types[cuisine_type]:
        counts_per_cuisine_type[cuisine_type] += \
        counts_per_cuisine[cuisine]
        
counts_per_cuisine_type
# Out:
# defaultdict(int, {'west': 7911, 'non_west': 7508})

# %% [markdown]
# ### Preprocess data

# %% [markdown]
# #### Regularize

# %%
def regularize_author(auth_str):
    if auth_str is not None:
        return auth_str.replace('Recipe from ','')
    return

import re
def regularize_title(title_str):
    if title_str is not None:
        return re.sub(r'[^a-zA-Z0-9]+',' ',title_str.lower())
    return

# %%
df['author'] = df['author'].apply(regularize_author)

# %%
df.loc[df['source']=='nyt']['author'].value_counts()
# Out:
# Martha Rose Shulman              1634
# Melissa Clark                     963
# Mark Bittman                      670
# David Tanis                       580
# Sam Sifton                        248
#                                  ...
# Bill Smith                          1
# Ree Drummond                        1
# Niloufer Ichaporia King             1
# "The Divvies Bakery Cookbook"       1
# Nate Dumas                          1
# Name: author, Length: 1755, dtype: int64

# %%
df['reg_title'] = df['title'].apply(regularize_title)

# %% [markdown]
# #### Deduplicate

# %% [markdown]
# Let's check for recipes from the same author with the same title (regardless of whether they're from BA or NYT):

# %%
df.loc[df.duplicated(subset=['author','reg_title'],keep='first')]
# Out:
#                                                                                           title  \
# http://www.bonappetit.com/recipe/chocolate-pizz...                                    Pizzettes
# http://www.bonappetit.com/recipe/buche-de-noel-...                                Bûche de Noël
# http://www.bonappetit.com/recipe/extra-buttery-...                Extra-Buttery Mashed Potatoes
# http://www.bonappetit.com/recipe/brads-campsite...                    Brad’s Campsite Jambalaya
# http://www.bonappetit.com/recipe/turmeric-tonic-2                                Turmeric Tonic
# ...                                                                                         ...
# http://cooking.nytimes.com//recipes/1014579-la-...     La Zucca Magica’s Orange and Olive Salad
# http://cooking.nytimes.com//recipes/1016526-cau...  Cauliflower Gratin with Goat Cheese Topping
# http://cooking.nytimes.com//recipes/1016147-sim...                        Simple Marinara Sauce
# http://cooking.nytimes.com//recipes/1016478-sim...                        Simple Marinara Sauce
# http://cooking.nytimes.com//recipes/1016148-fre...                           Fresh Tomato Sauce
#
#                                                                  author  \
# http://www.bonappetit.com/recipe/chocolate-pizz...        Chris Morocco
# http://www.bonappetit.com/recipe/buche-de-noel-...       Claire Saffitz
# http://www.bonappetit.com/recipe/extra-buttery-...           Dawn Perry
# http://www.bonappetit.com/recipe/brads-campsite...          Zach DeSart
# http://www.bonappetit.com/recipe/turmeric-tonic-2          Alison Roman
# ...                                                                 ...
# http://cooking.nytimes.com//recipes/1014579-la-...         Mark Bittman
# http://cooking.nytimes.com//recipes/1016526-cau...  Martha Rose Shulman
# http://cooking.nytimes.com//recipes/1016147-sim...  Martha Rose Shulman
# http://cooking.nytimes.com//recipes/1016478-sim...  Martha Rose Shulman
# http://cooking.nytimes.com//recipes/1016148-fre...  Martha Rose Shulman
#
#                                                                                           description  \
# http://www.bonappetit.com/recipe/chocolate-pizz...  The short bake time in this recipe isn’t a typ...
# http://www.bonappetit.com/recipe/buche-de-noel-...  A little oil in this bûche de noel recipe help...
# http://www.bonappetit.com/recipe/extra-buttery-...  For this mashed potato recipe, drying the cook...
# http://www.bonappetit.com/recipe/brads-campsite...  If you decide to make this best jambalaya reci...
# http://www.bonappetit.com/recipe/turmeric-tonic-2   Find turmeric at specialty, Asian, and health ...
# ...                                                                                               ...
# http://cooking.nytimes.com//recipes/1014579-la-...  The combination of sweet, juicy, tart (and col...
# http://cooking.nytimes.com//recipes/1016526-cau...  Of all of the many gratins that I make, this i...
# http://cooking.nytimes.com//recipes/1016147-sim...  Recipes hardly come easier. This marinara sauc...
# http://cooking.nytimes.com//recipes/1016478-sim...  This is the marinara sauce I make all winter. ...
# http://cooking.nytimes.com//recipes/1016148-fre...  This is a quick, simple marinara sauce that wi...
#
#                                                                                                 steps  \
# http://www.bonappetit.com/recipe/chocolate-pizz...  Preheat oven to 375°. Mix flour, chocolate chi...
# http://www.bonappetit.com/recipe/buche-de-noel-...  Preheat oven to 375°. Coat an 18x13" rimmed ba...
# http://www.bonappetit.com/recipe/extra-buttery-...  Place potatoes in a large pot and pour in cold...
# http://www.bonappetit.com/recipe/brads-campsite...  Prepare grill for high heat. Heat oil in a lar...
# http://www.bonappetit.com/recipe/turmeric-tonic-2   Pass turmeric, ginger, and lemon (with peel) t...
# ...                                                                                               ...
# http://cooking.nytimes.com//recipes/1014579-la-...  In a food processor, combine olives and thyme,...
# http://cooking.nytimes.com//recipes/1016526-cau...  Preheat the oven to 450ºF. Oil a 2-quart grati...
# http://cooking.nytimes.com//recipes/1016147-sim...  Pulse the chopped tomatoes in a food processor...
# http://cooking.nytimes.com//recipes/1016478-sim...  Pulse the chopped tomatoes in a food processor...
# http://cooking.nytimes.com//recipes/1016148-fre...  In a wide, nonstick frying pan, or in a 3-quar...
#
#                                                    source  \
# http://www.bonappetit.com/recipe/chocolate-pizz...     ba
# http://www.bonappetit.com/recipe/buche-de-noel-...     ba
# http://www.bonappetit.com/recipe/extra-buttery-...     ba
# http://www.bonappetit.com/recipe/brads-campsite...     ba
# http://www.bonappetit.com/recipe/turmeric-tonic-2      ba
# ...                                                   ...
# http://cooking.nytimes.com//recipes/1014579-la-...    nyt
# http://cooking.nytimes.com//recipes/1016526-cau...    nyt
# http://cooking.nytimes.com//recipes/1016147-sim...    nyt
# http://cooking.nytimes.com//recipes/1016478-sim...    nyt
# http://cooking.nytimes.com//recipes/1016148-fre...    nyt
#
#                                                                                       reg_title
# http://www.bonappetit.com/recipe/chocolate-pizz...                                    pizzettes
# http://www.bonappetit.com/recipe/buche-de-noel-...                                b che de no l
# http://www.bonappetit.com/recipe/extra-buttery-...                extra buttery mashed potatoes
# http://www.bonappetit.com/recipe/brads-campsite...                    brad s campsite jambalaya
# http://www.bonappetit.com/recipe/turmeric-tonic-2                                turmeric tonic
# ...                                                                                         ...
# http://cooking.nytimes.com//recipes/1014579-la-...     la zucca magica s orange and olive salad
# http://cooking.nytimes.com//recipes/1016526-cau...  cauliflower gratin with goat cheese topping
# http://cooking.nytimes.com//recipes/1016147-sim...                        simple marinara sauce
# http://cooking.nytimes.com//recipes/1016478-sim...                        simple marinara sauce
# http://cooking.nytimes.com//recipes/1016148-fre...                           fresh tomato sauce
#
# [108 rows x 6 columns]

# %% [markdown]
# There are 108 recipes with duplicate versions.

# %% [markdown]
# Let's save the regularized, deduplicated dataframe of recipes.

# %%
df = df.drop_duplicates(subset=['author','reg_title'],keep='first')
df.shape
# Out:
# (19066, 6)

# %%
df.to_csv('./data/recipes_df.tsv',sep='\t',header=True,index=True)

# %%
df = pd.read_csv('./data/recipes_df.tsv',sep='\t',index_col=0)
df.shape
# Out:
# (19066, 6)

# %%
df.head()
# Out:
#                                                                                     title  \
# http://www.bonappetit.com/recipe/rustic-shrimp-...                   Rustic Shrimp Toasts
# http://www.bonappetit.com/recipe/tomato-and-egg...        Tomato and Egg Drop Noodle Soup
# http://www.bonappetit.com/recipe/macadamia-and-...    Macadamia and Brown Butter Blondies
# http://www.bonappetit.com/recipe/grilled-mushro...  Grilled Mushrooms and Root Vegetables
# http://www.bonappetit.com/recipe/spiced-pecans                              Spiced Pecans
#
#                                                                      author  \
# http://www.bonappetit.com/recipe/rustic-shrimp-...  Christian David Reynoso
# http://www.bonappetit.com/recipe/tomato-and-egg...           Hetty McKinnon
# http://www.bonappetit.com/recipe/macadamia-and-...          Roxana Jullapat
# http://www.bonappetit.com/recipe/grilled-mushro...            Maricela Vega
# http://www.bonappetit.com/recipe/spiced-pecans                Maricela Vega
#
#                                                                                           description  \
# http://www.bonappetit.com/recipe/rustic-shrimp-...  This version of shrimp toast is inspired by my...
# http://www.bonappetit.com/recipe/tomato-and-egg...  The combination of tomato, egg, and noodles is...
# http://www.bonappetit.com/recipe/macadamia-and-...  At her L.A. bakery Friends and Family, Roxana ...
# http://www.bonappetit.com/recipe/grilled-mushro...  “My great-grandmothers were Indigenous and mos...
# http://www.bonappetit.com/recipe/spiced-pecans      Pecans are a favorite Southern source of prote...
#
#                                                                                                 steps  \
# http://www.bonappetit.com/recipe/rustic-shrimp-...  Heat broiler (set to low if you have that opti...
# http://www.bonappetit.com/recipe/tomato-and-egg...  Fill a small Dutch oven or large saucepan with...
# http://www.bonappetit.com/recipe/macadamia-and-...  Preheat oven to 350°. Lightly coat a 9"-diamet...
# http://www.bonappetit.com/recipe/grilled-mushro...  Purée Sesame Crème, Allium Confit, chopped her...
# http://www.bonappetit.com/recipe/spiced-pecans      Preheat oven to 350°. Grind fennel seeds in a ...
#
#                                                    source  \
# http://www.bonappetit.com/recipe/rustic-shrimp-...     ba
# http://www.bonappetit.com/recipe/tomato-and-egg...     ba
# http://www.bonappetit.com/recipe/macadamia-and-...     ba
# http://www.bonappetit.com/recipe/grilled-mushro...     ba
# http://www.bonappetit.com/recipe/spiced-pecans         ba
#
#                                                                                 reg_title
# http://www.bonappetit.com/recipe/rustic-shrimp-...                   rustic shrimp toasts
# http://www.bonappetit.com/recipe/tomato-and-egg...        tomato and egg drop noodle soup
# http://www.bonappetit.com/recipe/macadamia-and-...    macadamia and brown butter blondies
# http://www.bonappetit.com/recipe/grilled-mushro...  grilled mushrooms and root vegetables
# http://www.bonappetit.com/recipe/spiced-pecans                              spiced pecans

# %% [markdown]
# #### Use spaCy to tokenize, lemmatize, and parse titles, descriptions, & steps

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

import os
import glob

# %% [markdown]
# Can we use the final part of each recipe's URL as a GUID? (I.e., does each recipe have a distinct URL tail?) It appears so:

# %%
url_tails = [x.split('/')[-1] for x in df.index.values]
len(url_tails),len(set(url_tails))
# Out:
# (19174, 19174)

# %%
url_tails[:10]
# Out:
# ['rustic-shrimp-toasts',
#  'tomato-and-egg-drop-noodle-soup',
#  'macadamia-and-brown-butter-blondies',
#  'grilled-mushrooms-and-root-vegetables',
#  'spiced-pecans',
#  'granola-scones',
#  'chocolate-buckwheat-cake',
#  'pumpkin-hot-sauce',
#  'scratchy-throat-soother',
#  'blueberry-spelt-muffins']

# %%
url_tails[-10:]
# Out:
# ['7649-spicy-pork-belly-with-green-olives-and-lemon',
#  '1017675-clementine-clafoutis',
#  '1016062-red-lentil-soup-with-lemon',
#  '1016234-pernil',
#  '1292-gingerbread-apple-cocktail',
#  '1739-hootenholler-whiskey-quick-bread',
#  '1740-braised-chicken-with-artichokes-and-mushrooms',
#  '1878-roquefort-and-pear-eggnog',
#  '1877-1958-eggnog',
#  '1015818-white-bark-balls']

# %% [markdown]
# We'll save each spaCy-processed recipe to
# `./data/preprocessed/{GUID}.json`, with each `.json` having the structure
# ```
# {
#     'title': {
#         'tokens': ['rustic shrimp toasts'],
#         'lemmas': ['rustic','shrimp','toast'],
#         'pos': ['ADJ','NOUN','NOUN'],
#         'dep_label': ['amod','compound','ROOT'],
#         'head': ['toasts','toasts','toasts'],
#     },
#     'desc': {
#         'tokens': ['this','version','of','shrimp','toast','is',...]
#         'lemmas': ['this','version','of','shrimp','toast','be',...],
#         'pos': ['DET','NOUN','ADP','NOUN','NOUN','VERB',...],
#         'dep_label': ['det','nsubjpass','prep','compound','pobj','auxpass',...],
#         'head': ['version','inspired','version','toast','of','inspired',...],
#     },
#     'steps': {
#         'tokens': ['heat','broiler','(','set',...]
#         'lemmas': ['heat','broiler','(','set',...],
#         'pos': ['NOUN','NOUN','PUNCT','VERB',...],
#         'dep_label': ['compound','ROOT','punct','acl',...],
#         'head': ['broiler','broiler','broiler','broiler',...],
#     }
# }
# ```

# %%
from collections import defaultdict

# %%
progress = 0
for row_ix,row in df.iterrows():
    
    # Create json object to store results
    json_out = defaultdict(lambda: defaultdict(list))
    
    # Run spaCy pipeline for each of the 3 text components
    for obj in ['title', 'description', 'steps']:
        if row[obj] is not None:
            doc = nlp(row[obj].lower()) # convert to lowercase
            for token in doc:
                json_out[obj]['tokens'].append(token.text)
                json_out[obj]['lemmas'].append(token.lemma_)
                json_out[obj]['pos'].append(token.pos_)
                json_out[obj]['dep_label'].append(token.dep_)
                json_out[obj]['head'].append(token.head.text)
            
    # Write results
    fname = os.path.join('data','preprocessed',row_ix.split('/')[-1])       
    with open(fname, 'w') as outfile:
        json.dump(json_out, outfile)
    
    
    progress += 1
    if progress % 500 == 0:
        print('Processed {} out of {} rows.'.format(progress,len(df)))
# Out:
# Processed 500 out of 19174 rows.
# Processed 1000 out of 19174 rows.
# Processed 1500 out of 19174 rows.
# Processed 2000 out of 19174 rows.
# Processed 2500 out of 19174 rows.
# Processed 3000 out of 19174 rows.
# Processed 3500 out of 19174 rows.
# Processed 4000 out of 19174 rows.
# Processed 4500 out of 19174 rows.
# Processed 5000 out of 19174 rows.
# Processed 5500 out of 19174 rows.
# Processed 6000 out of 19174 rows.
# Processed 6500 out of 19174 rows.
# Processed 7000 out of 19174 rows.
# Processed 7500 out of 19174 rows.
# Processed 8000 out of 19174 rows.
# Processed 8500 out of 19174 rows.
# Processed 9000 out of 19174 rows.
# Processed 9500 out of 19174 rows.
# Processed 10000 out of 19174 rows.
# Processed 10500 out of 19174 rows.
# Processed 11000 out of 19174 rows.
# Processed 11500 out of 19174 rows.
# Processed 12000 out of 19174 rows.
# Processed 12500 out of 19174 rows.
# Processed 13000 out of 19174 rows.
# Processed 13500 out of 19174 rows.
# Processed 14000 out of 19174 rows.
# Processed 14500 out of 19174 rows.
# Processed 15000 out of 19174 rows.
# Processed 15500 out of 19174 rows.
# Processed 16000 out of 19174 rows.
# Processed 16500 out of 19174 rows.
# Processed 17000 out of 19174 rows.
# Processed 17500 out of 19174 rows.
# Processed 18000 out of 19174 rows.
# Processed 18500 out of 19174 rows.
# Processed 19000 out of 19174 rows.

# %% [markdown]
# ## Label recipes as W/NW

# %% [markdown]
# ### Approach 1: NYT existing cuisine labels

# %% [markdown]
# Add a column indicating W/NW label for each recipe, according to the following scheme:
#     <br>* if a recipe has one cuisine category, use that category's label
#     <br>* if a recipe has multiple cuisine categories, use the most majority label
#     <br>* if a recipe has multiple cuisine categories and there is a tie among majority labels, ignore

# %%
from collections import Counter

def get_nyt_cuisine_label(r):
    cuisine_cats = list(recipe2cuisine[r])
    #print('cuisine_cats:',cuisine_cats)
    if len(cuisine_cats) == 0:
        return
    elif len(cuisine_cats) == 1:
        return cuisine2type[cuisine_cats[0]]
    else:
        #print([cuisine2type[cuisine_cat]
        #                       for cuisine_cat in cuisine_cats])
        #print(Counter([cuisine2type[cuisine_cat]
        #                       for cuisine_cat in cuisine_cats]))
        c = Counter([cuisine2type[cuisine_cat]
                               for cuisine_cat in cuisine_cats]).\
                    most_common()
        if len(c) == 1:
            return c[0][0]
        else:
            majority_label = c[0][0]
            if majority_label != c[1][0]:
                return majority_label
            else:
                print('Tie')

# %%
df['cuisine_type'] = [get_nyt_cuisine_label(x) for x in df.index.values]

# %%
df['cuisine_type'].value_counts()
# Out:
# non_west    1847
# west        1550
# Name: cuisine_type, dtype: int64

# %%
df.loc[df['cuisine_type']=='west']#['title'].values
# Out:
#                                                                                             title  \
# http://cooking.nytimes.com//recipes/1021792-spi...                            Spicy Chorizo Pasta
# http://cooking.nytimes.com//recipes/1021774-sau...              Sauerkraut Jeon (Korean Pancakes)
# http://cooking.nytimes.com//recipes/1021791-che...                              Cheesy Beer Bread
# http://cooking.nytimes.com//recipes/1021775-ear...              Earlonne’s Chicken and Brown Rice
# http://cooking.nytimes.com//recipes/1021767-mul...  Mulling-Spice Cake With Cream-Cheese Frosting
# ...                                                                                           ...
# http://cooking.nytimes.com//recipes/1018618-mea...     Meatball Sausages (Soutzoukakia Smyrneika)
# http://cooking.nytimes.com//recipes/1015667-swe...                               Sweet Tart Crust
# http://cooking.nytimes.com//recipes/1015542-cri...  Crisp-Skinned Tilefish Over Provencal Cabbage
# http://cooking.nytimes.com//recipes/1017675-cle...                           Clementine Clafoutis
# http://cooking.nytimes.com//recipes/1739-hooten...               Hootenholler Whiskey Quick Bread
#
#                                                                   author  \
# http://cooking.nytimes.com//recipes/1021792-spi...            Ali Slagle
# http://cooking.nytimes.com//recipes/1021774-sau...    J. Kenji López-Alt
# http://cooking.nytimes.com//recipes/1021791-che...  Erin Jeanne McDowell
# http://cooking.nytimes.com//recipes/1021775-ear...          Samin Nosrat
# http://cooking.nytimes.com//recipes/1021767-mul...            Tara Bench
# ...                                                                  ...
# http://cooking.nytimes.com//recipes/1018618-mea...        Diane Kochilas
# http://cooking.nytimes.com//recipes/1015667-swe...          Mark Bittman
# http://cooking.nytimes.com//recipes/1015542-cri...          Mark Bittman
# http://cooking.nytimes.com//recipes/1017675-cle...          Mark Bittman
# http://cooking.nytimes.com//recipes/1739-hooten...          Alex Witchel
#
#                                                                                           description  \
# http://cooking.nytimes.com//recipes/1021792-spi...  Macaroni and chorizo is classic Spanish comfor...
# http://cooking.nytimes.com//recipes/1021774-sau...  Jeon are savory Korean vegetable, meat or seaf...
# http://cooking.nytimes.com//recipes/1021791-che...  This easy bread recipe uses beer and baking po...
# http://cooking.nytimes.com//recipes/1021775-ear...  Layered with savory, satisfying flavors, this ...
# http://cooking.nytimes.com//recipes/1021767-mul...  The spices in this cake from “Live Life Delici...
# ...                                                                                               ...
# http://cooking.nytimes.com//recipes/1018618-mea...  This is a soulful dish: handmade meatball saus...
# http://cooking.nytimes.com//recipes/1015667-swe...                                                NaN
# http://cooking.nytimes.com//recipes/1015542-cri...                                                NaN
# http://cooking.nytimes.com//recipes/1017675-cle...  Clafoutis is a classic French dessert most oft...
# http://cooking.nytimes.com//recipes/1739-hooten...  This recipe is adapted from the “I Hate to Coo...
#
#                                                                                                 steps  \
# http://cooking.nytimes.com//recipes/1021792-spi...  Bring a large pot of salted water to a boil. A...
# http://cooking.nytimes.com//recipes/1021774-sau...  Prepare the dipping sauce: In a small bowl, st...
# http://cooking.nytimes.com//recipes/1021791-che...  Heat the oven to 375 degrees. Lightly grease a...
# http://cooking.nytimes.com//recipes/1021775-ear...  Season the chicken generously with salt and pe...
# http://cooking.nytimes.com//recipes/1021767-mul...  Heat oven to 350 degrees. Prepare the cakes: C...
# ...                                                                                               ...
# http://cooking.nytimes.com//recipes/1018618-mea...  For the sauce: In a medium saucepan over mediu...
# http://cooking.nytimes.com//recipes/1015667-swe...  Combine the flour, salt, and sugar in the cont...
# http://cooking.nytimes.com//recipes/1015542-cri...  Turn the heat to medium-high under a heavy ski...
# http://cooking.nytimes.com//recipes/1017675-cle...  Heat oven to 350 degrees. Prepare a gratin dis...
# http://cooking.nytimes.com//recipes/1739-hooten...  First, take the bourbon out of the cupboard an...
#
#                                                    source  \
# http://cooking.nytimes.com//recipes/1021792-spi...    nyt
# http://cooking.nytimes.com//recipes/1021774-sau...    nyt
# http://cooking.nytimes.com//recipes/1021791-che...    nyt
# http://cooking.nytimes.com//recipes/1021775-ear...    nyt
# http://cooking.nytimes.com//recipes/1021767-mul...    nyt
# ...                                                   ...
# http://cooking.nytimes.com//recipes/1018618-mea...    nyt
# http://cooking.nytimes.com//recipes/1015667-swe...    nyt
# http://cooking.nytimes.com//recipes/1015542-cri...    nyt
# http://cooking.nytimes.com//recipes/1017675-cle...    nyt
# http://cooking.nytimes.com//recipes/1739-hooten...    nyt
#
#                                                                                         reg_title  \
# http://cooking.nytimes.com//recipes/1021792-spi...                            spicy chorizo pasta
# http://cooking.nytimes.com//recipes/1021774-sau...               sauerkraut jeon korean pancakes
# http://cooking.nytimes.com//recipes/1021791-che...                              cheesy beer bread
# http://cooking.nytimes.com//recipes/1021775-ear...              earlonne s chicken and brown rice
# http://cooking.nytimes.com//recipes/1021767-mul...  mulling spice cake with cream cheese frosting
# ...                                                                                           ...
# http://cooking.nytimes.com//recipes/1018618-mea...      meatball sausages soutzoukakia smyrneika
# http://cooking.nytimes.com//recipes/1015667-swe...                               sweet tart crust
# http://cooking.nytimes.com//recipes/1015542-cri...  crisp skinned tilefish over provencal cabbage
# http://cooking.nytimes.com//recipes/1017675-cle...                           clementine clafoutis
# http://cooking.nytimes.com//recipes/1739-hooten...               hootenholler whiskey quick bread
#
#                                                    cuisine_type
# http://cooking.nytimes.com//recipes/1021792-spi...         west
# http://cooking.nytimes.com//recipes/1021774-sau...         west
# http://cooking.nytimes.com//recipes/1021791-che...         west
# http://cooking.nytimes.com//recipes/1021775-ear...         west
# http://cooking.nytimes.com//recipes/1021767-mul...         west
# ...                                                         ...
# http://cooking.nytimes.com//recipes/1018618-mea...         west
# http://cooking.nytimes.com//recipes/1015667-swe...         west
# http://cooking.nytimes.com//recipes/1015542-cri...         west
# http://cooking.nytimes.com//recipes/1017675-cle...         west
# http://cooking.nytimes.com//recipes/1739-hooten...         west
#
# [1534 rows x 7 columns]

# %% [markdown]
# --> This doesn't seem to yield very much labeled data, and we still don't have a way of labeling the BA recipes. Moreover, the labels seem lacking in accuracy (e.g., Korean jeon is American). Results are noisy (see [Initial analysis](#Initial-analysis)).

# %%
recipe2cuisine['http://cooking.nytimes.com//recipes/1021774-sauerkraut-jeon-korean-pancakes']
# Out:
# {'American'}

# %% [markdown]
# ### Approach 2: Using explicit cues in recipe titles

# %% [markdown]
# Let's look for adjectives like "Turkish", "Argentine". First we'll get a big list of all such adjectives for different regions/countries from Wikipedia.

# %%
from urllib import request
from urllib.error import HTTPError, URLError
from bs4 import BeautifulSoup
import re

# %%
url = "https://en.wikipedia.org/wiki/Demonym#Suffixation"
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
}
soup = BeautifulSoup(request.urlopen(
        request.Request(url, headers=HEADERS)).read(), "html.parser")

# %%
demonyms = set(["African", "Antarctican", "Asian", "Australian", "European", "North American", 
                "South American", "Central American", "American", "Oceanian"])

divs = soup.find_all('div',attrs={'class':'div-col'})
for ix,div in enumerate(divs):
    #print(ix)
    uls = div.find_all('ul')
    for ul in uls:
        lis = ul.find_all('li')
        for li in lis:
            dems = re.split('also |more commonly|less commonly|/|or |Or |demonym|, ', li.text.split(' → ')[-1])
            #print('first pass:',dems)
            dems = [re.sub(r'[^ \-a-zA-Z0-9+]','',x) for x in dems]
            #print('sub punctuation:',dems)
            dems = set([x for x in dems if len(x) > 0 and x[0].isupper()])
            #print('final:', dems)
            
            demonyms |= dems

# %%
# Remove final -s and lowercase to get adjectival form

demonyms = [d[:-1].lower() for d in demonyms]
len(demonyms)
# Out:
# 844

# %%
demonyms[:5]
# Out:
# ['silhillian', 'calcuttan', 'dubaiite', 'palaungges', 'transnistrian']

# %% [markdown]
# Look for these adjectives in recipe titles:

# %%
def has_demonym(s):
    return len(set(s.lower().split()).intersection(demonyms)) > 0

def get_demonyms(s):
    return set(s.lower().split()).intersection(demonyms)

df['has_demonym'] = df['title'].apply(has_demonym)
df['demonyms'] = df['title'].apply(get_demonyms)

# %%
df['has_demonym'].value_counts()
# Out:
# False    18697
# True       369
# Name: has_demonym, dtype: int64

# %%
df.loc[df['has_demonym']].head(10)
# Out:
#                                                                                            title  \
# http://www.bonappetit.com/recipe/salvadoran-que...                         Salvadoran Quesadilla
# http://www.bonappetit.com/recipe/italian-choppe...                         Italian Chopped Salad
# http://www.bonappetit.com/recipe/jamaican-beef-...                         Jamaican Beef Patties
# http://www.bonappetit.com/recipe/thai-tea-ice-c...           Swirled No-Churn Thai Tea Ice Cream
# http://www.bonappetit.com/recipe/chrissy-teigen...   Chrissy Teigen’s Thai Soy-Garlic Fried Ribs
# http://www.bonappetit.com/recipe/italian-sundae...                  Italian Sundaes with Nutella
# http://www.bonappetit.com/recipe/arugula-with-i...       Arugula with Italian Plums and Parmesan
# http://www.bonappetit.com/recipe/german-apple-cake                     Buttery German Apple Cake
# http://www.bonappetit.com/recipe/smashed-cucumb...  Smashed Cucumber Salad with Italian Dressing
# http://www.bonappetit.com/recipe/weeknight-pad-...                            Weeknight Pad Thai
#
#                                                             author  \
# http://www.bonappetit.com/recipe/salvadoran-que...             NaN
# http://www.bonappetit.com/recipe/italian-choppe...   Chris Morocco
# http://www.bonappetit.com/recipe/jamaican-beef-...     Shani Jones
# http://www.bonappetit.com/recipe/thai-tea-ice-c...    Sarah Jampel
# http://www.bonappetit.com/recipe/chrissy-teigen...  Chrissy Teigen
# http://www.bonappetit.com/recipe/italian-sundae...  Ignacio Mattos
# http://www.bonappetit.com/recipe/arugula-with-i...  Ignacio Mattos
# http://www.bonappetit.com/recipe/german-apple-cake             NaN
# http://www.bonappetit.com/recipe/smashed-cucumb...   Chris Morocco
# http://www.bonappetit.com/recipe/weeknight-pad-...  Claire Saffitz
#
#                                                                                           description  \
# http://www.bonappetit.com/recipe/salvadoran-que...  Not to be confused with the Mexican dish by th...
# http://www.bonappetit.com/recipe/italian-choppe...  This winter salad with peak season chicories, ...
# http://www.bonappetit.com/recipe/jamaican-beef-...  These delectable flaky pastries from can be fo...
# http://www.bonappetit.com/recipe/thai-tea-ice-c...  The hardest part of this recipe is tracking do...
# http://www.bonappetit.com/recipe/chrissy-teigen...  Making ribs at home can be sooooo intimidating...
# http://www.bonappetit.com/recipe/italian-sundae...  Fior di latte (“milk flower”) is a fresh cow’s...
# http://www.bonappetit.com/recipe/arugula-with-i...  For the best play between sweet, hot, and salt...
# http://www.bonappetit.com/recipe/german-apple-cake  This gorgeous cake was unanimously crowned the...
# http://www.bonappetit.com/recipe/smashed-cucumb...  Smashing the cucumbers lets the crunchy veg so...
# http://www.bonappetit.com/recipe/weeknight-pad-...  We're all about taking shortcuts when it comes...
#
#                                                                                                 steps  \
# http://www.bonappetit.com/recipe/salvadoran-que...  Place a rack in middle of oven; preheat to 375...
# http://www.bonappetit.com/recipe/italian-choppe...  Heat butter and 2 Tbsp. oil in a large nonstic...
# http://www.bonappetit.com/recipe/jamaican-beef-...  Pulse flour, salt, and turmeric in a food proc...
# http://www.bonappetit.com/recipe/thai-tea-ice-c...  Bring 1½ cups cream to a bare simmer in a smal...
# http://www.bonappetit.com/recipe/chrissy-teigen...  Place ribs in a large bowl. Add soy sauce, gar...
# http://www.bonappetit.com/recipe/italian-sundae...  Place a scoop of gelato into each chilled bowl...
# http://www.bonappetit.com/recipe/arugula-with-i...  Toss plums, cocktail onions, lemon juice, and ...
# http://www.bonappetit.com/recipe/german-apple-cake  Preheat oven to 350°. Grease bottom and sides ...
# http://www.bonappetit.com/recipe/smashed-cucumb...  Gently smash cucumbers with a rolling pin or t...
# http://www.bonappetit.com/recipe/weeknight-pad-...  First, some prep: Cut 1 bunch scallions crossw...
#
#                                                    source  \
# http://www.bonappetit.com/recipe/salvadoran-que...     ba
# http://www.bonappetit.com/recipe/italian-choppe...     ba
# http://www.bonappetit.com/recipe/jamaican-beef-...     ba
# http://www.bonappetit.com/recipe/thai-tea-ice-c...     ba
# http://www.bonappetit.com/recipe/chrissy-teigen...     ba
# http://www.bonappetit.com/recipe/italian-sundae...     ba
# http://www.bonappetit.com/recipe/arugula-with-i...     ba
# http://www.bonappetit.com/recipe/german-apple-cake     ba
# http://www.bonappetit.com/recipe/smashed-cucumb...     ba
# http://www.bonappetit.com/recipe/weeknight-pad-...     ba
#
#                                                                                        reg_title  \
# http://www.bonappetit.com/recipe/salvadoran-que...                         salvadoran quesadilla
# http://www.bonappetit.com/recipe/italian-choppe...                         italian chopped salad
# http://www.bonappetit.com/recipe/jamaican-beef-...                         jamaican beef patties
# http://www.bonappetit.com/recipe/thai-tea-ice-c...           swirled no churn thai tea ice cream
# http://www.bonappetit.com/recipe/chrissy-teigen...   chrissy teigen s thai soy garlic fried ribs
# http://www.bonappetit.com/recipe/italian-sundae...                  italian sundaes with nutella
# http://www.bonappetit.com/recipe/arugula-with-i...       arugula with italian plums and parmesan
# http://www.bonappetit.com/recipe/german-apple-cake                     buttery german apple cake
# http://www.bonappetit.com/recipe/smashed-cucumb...  smashed cucumber salad with italian dressing
# http://www.bonappetit.com/recipe/weeknight-pad-...                            weeknight pad thai
#
#                                                     has_demonym      demonyms
# http://www.bonappetit.com/recipe/salvadoran-que...         True  {salvadoran}
# http://www.bonappetit.com/recipe/italian-choppe...         True     {italian}
# http://www.bonappetit.com/recipe/jamaican-beef-...         True    {jamaican}
# http://www.bonappetit.com/recipe/thai-tea-ice-c...         True        {thai}
# http://www.bonappetit.com/recipe/chrissy-teigen...         True        {thai}
# http://www.bonappetit.com/recipe/italian-sundae...         True     {italian}
# http://www.bonappetit.com/recipe/arugula-with-i...         True     {italian}
# http://www.bonappetit.com/recipe/german-apple-cake         True      {german}
# http://www.bonappetit.com/recipe/smashed-cucumb...         True     {italian}
# http://www.bonappetit.com/recipe/weeknight-pad-...         True        {thai}

# %%
from collections import Counter

counted_dems = Counter([item for sublist in df.loc[df['has_demonym']]['demonyms'].values for item in sublist])
sorted(counted_dems.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('italian', 54),
#  ('thai', 54),
#  ('moroccan', 46),
#  ('mexican', 33),
#  ('indian', 20),
#  ('japanese', 16),
#  ('sicilian', 14),
#  ('persian', 10),
#  ('tunisian', 10),
#  ('jamaican', 8),
#  ('roman', 8),
#  ('german', 7),
#  ('belgian', 6),
#  ('russian', 6),
#  ('cuban', 6),
#  ('hungarian', 6),
#  ('american', 5),
#  ('breton', 5),
#  ('peruvian', 4),
#  ('salvadoran', 3),
#  ('malaysian', 3),
#  ('colombian', 3),
#  ('brazilian', 3),
#  ('indonesian', 3),
#  ('hamburger', 2),
#  ('haitian', 2),
#  ('bangladeshi', 2),
#  ('andalusian', 2),
#  ('georgian', 2),
#  ('javanese', 1),
#  ('malagasy', 1),
#  ('libyan', 1),
#  ('syrian', 1),
#  ('singaporean', 1),
#  ('america', 1),
#  ('ghanaian', 1),
#  ('genovese', 1),
#  ('armenian', 1),
#  ('chilean', 1),
#  ('alaskan', 1),
#  ('egyptian', 1),
#  ('iranian', 1),
#  ('baja', 1),
#  ('victorian', 1),
#  ('valencian', 1),
#  ('algerian', 1),
#  ('bosnian', 1),
#  ('majorcan', 1),
#  ('macedonian', 1),
#  ('bohemian', 1),
#  ('ukrainian', 1),
#  ('bulgarian', 1),
#  ('liberian', 1),
#  ('ligurian', 1),
#  ('galician', 1)]

# %% [markdown]
# Now I'll code these for W/NW:

# %%
# with open('coded_demonyms.txt','w') as f:
#     for key in counted_dems:
#         f.write(key+'\t-1\n')

# %%
coded_demonyms = pd.read_csv('coded_demonyms.txt',sep='\t',header=None)
coded_demonyms.columns = ['demonym','label']
coded_demonyms['label'].value_counts()
# Out:
# nw    30
# w     24
# -1     1
# Name: label, dtype: int64

# %%
coded_demonyms = coded_demonyms.loc[coded_demonyms['label']!='-1']

# %%
dem_to_label = dict(zip(coded_demonyms['demonym'],coded_demonyms['label']))

# %%
dem_to_label
# Out:
# {'salvadoran': 'nw',
#  'italian': 'w',
#  'jamaican': 'nw',
#  'thai': 'nw',
#  'german': 'w',
#  'persian': 'nw',
#  'belgian': 'w',
#  'japanese': 'nw',
#  'russian': 'w',
#  'mexican': 'nw',
#  'moroccan': 'nw',
#  'indian': 'nw',
#  'american': 'w',
#  'cuban': 'nw',
#  'roman': 'w',
#  'malaysian': 'nw',
#  'colombian': 'nw',
#  'peruvian': 'nw',
#  'sicilian': 'w',
#  'breton': 'w',
#  'tunisian': 'nw',
#  'hungarian': 'w',
#  'javanese': 'nw',
#  'brazilian': 'nw',
#  'malagasy': 'nw',
#  'libyan': 'nw',
#  'syrian': 'nw',
#  'singaporean': 'nw',
#  'haitian': 'nw',
#  'indonesian': 'nw',
#  'america': 'w',
#  'bangladeshi': 'nw',
#  'ghanaian': 'nw',
#  'genovese': 'w',
#  'armenian': 'nw',
#  'chilean': 'nw',
#  'alaskan': 'w',
#  'andalusian': 'w',
#  'egyptian': 'nw',
#  'iranian': 'nw',
#  'baja': 'nw',
#  'victorian': 'w',
#  'valencian': 'w',
#  'algerian': 'nw',
#  'bosnian': 'w',
#  'majorcan': 'w',
#  'macedonian': 'w',
#  'bohemian': 'w',
#  'ukrainian': 'w',
#  'bulgarian': 'w',
#  'liberian': 'nw',
#  'georgian': 'w',
#  'ligurian': 'w',
#  'galician': 'w'}

# %% [markdown]
# Finally, I'll add a separate column to the df indicating whether it's W/NW based on these explicit indicators.

# %%
def get_demonym_label(dem_set):
    labels = [dem_to_label[dem] for dem in dem_set if dem != 'hamburger']
    if len(labels) > 0:
        if len(labels) == 1:
            return labels[0]
        else:
            c = Counter(labels).most_common()
            if len(c) == 1:
                return c[0][0]
            else:
                majority_label = c[0][0]
                if majority_label != c[1][0]:
                    return majority_label
                else:
                    print('Tie')
            return 

df['demonym_label'] = df['demonyms'].apply(get_demonym_label)

# %%
df.loc[df['demonym_label']=='nw']['source'].value_counts()/df['source'].value_counts()
# Out:
# ba     0.009335
# nyt    0.016200
# Name: source, dtype: float64

# %%
df.loc[df['demonym_label']=='w']['source'].value_counts()/df['source'].value_counts()
# Out:
# ba     0.005404
# nyt    0.008212
# Name: source, dtype: float64

# %% [markdown]
# ### Approach 3: Classifier trained on Wikipedia data

# %% [markdown]
# # Develop classifier

# %% [markdown]
# ### Get Wikipedia data

# %% [markdown]
# Root pages:
#     - W: https://en.wikipedia.org/wiki/European_cuisine
#     - NW: https://en.wikipedia.org/wiki/Asian_cuisine
#
# For each root page:
#     - A. Get all hyperlinks with anchor text matching the pattern "<X> cuisine"
#     - B. For each cuisine hyperlink:
#         - Grab all items occurring in a list -> individual dishes/ingredients
#         - Add to dictionary tracking ingredients/dishes of a cuisine

# %% [markdown]
# Part A.

# %%
from urllib import request
from urllib.error import HTTPError, URLError
from bs4 import BeautifulSoup

HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
}

root_wiki_pages = {
    'western': 'https://en.wikipedia.org/wiki/European_cuisine',
    'non_western': 'https://en.wikipedia.org/wiki/Asian_cuisine'
}

def get_cuisine_hyperlinks(root_page):
    """
    Retrieves all hyperlinks with anchor text matching the pattern 
    "<X> cuisine" from a wikipedia URL.
    @param root_page: str wiki URL
    """
    
    soup = BeautifulSoup(request.urlopen(
            request.Request(root_page, headers=HEADERS)).read(), 
                         "html.parser")
    main_div = soup.find('div',attrs={'class':'mw-parser-output'})
    uls = main_div.find_all('ul',recursive=False)
    lis = []
    for ul in uls:
        lis.extend(ul.find_all('li'))
    as_ = []
    for li in lis:
        as_.extend(li.find_all('a'))
    hyperlinks_and_anchors = [(a['href'],a['title']) for a in as_ 
                             if 'href' in a.attrs and 
                             'title' in a.attrs]
    cuisine_hyperlinks = [a[0] for a in hyperlinks_and_anchors
                         if a[1].endswith(' cuisine')]

    return ["https://en.wikipedia.org/"+x for x in cuisine_hyperlinks]

cuisine_hyperlinks = {}
for cuisine_type in ['western','non_western']:
    cuisine_hyperlinks[cuisine_type] = get_cuisine_hyperlinks(
        root_wiki_pages[cuisine_type])

# %% [markdown]
# Note: Russian cuisine is categorized as both W and NW; and Jewish cuisine is categorized as NW.

# %%
cuisine_hyperlinks['non_western']
# Out:
# ['https://en.wikipedia.org//wiki/Russian_cuisine',
#  'https://en.wikipedia.org//wiki/Chinese_cuisine',
#  'https://en.wikipedia.org//wiki/Taiwanese_cuisine',
#  'https://en.wikipedia.org//wiki/Taiwanese_cuisine',
#  'https://en.wikipedia.org//wiki/Japanese_cuisine',
#  'https://en.wikipedia.org//wiki/North_Korean_cuisine',
#  'https://en.wikipedia.org//wiki/South_Korean_cuisine',
#  'https://en.wikipedia.org//wiki/Singaporean_cuisine',
#  'https://en.wikipedia.org//wiki/Mongolian_cuisine',
#  'https://en.wikipedia.org//wiki/Indian_cuisine',
#  'https://en.wikipedia.org//wiki/Pakistani_cuisine',
#  'https://en.wikipedia.org//wiki/Bangladeshi_cuisine',
#  'https://en.wikipedia.org//wiki/Nepali_cuisine',
#  'https://en.wikipedia.org//wiki/Thai_cuisine',
#  'https://en.wikipedia.org//wiki/Malaysian_cuisine',
#  'https://en.wikipedia.org//wiki/Singaporean_cuisine',
#  'https://en.wikipedia.org//wiki/Filipino_cuisine',
#  'https://en.wikipedia.org//wiki/Vietnamese_cuisine',
#  'https://en.wikipedia.org//wiki/Indonesian_cuisine',
#  'https://en.wikipedia.org//wiki/Arab_cuisine',
#  'https://en.wikipedia.org//wiki/Jewish_cuisine',
#  'https://en.wikipedia.org//wiki/Iranian_cuisine']

# %%
set(cuisine_hyperlinks['western']).intersection(
set(cuisine_hyperlinks['non_western']))
# Out:
# {'https://en.wikipedia.org//wiki/Russian_cuisine'}

# %% [markdown]
# Part B.

# %%
def find_footer(el):
    h2s = el.find_all('h2')
    if len(h2s) > 0:
        ix = 0
        text = h2s[ix].text 
        while not (text.startswith('See also') or \
                  text.startswith('Bibliography') or \
                  text.startswith('External links') or \
                  text.startswith('Notes'))\
            and ix < len(h2s)-1:
            ix += 1
            text = h2s[ix].text

        return h2s[ix]
    else:
        return None

def get_cuisine_elements(cuisine_page):
    """
    Retrieves all dishes/ingredients of a cuisine.
    @param cuisine_page: str wiki URL for the cuisine of interest
    """
    
    soup = BeautifulSoup(request.urlopen(
            request.Request(cuisine_page, headers=HEADERS)).read(), 
                         "html.parser")
    main_div = soup.find('div',attrs={'class':'mw-parser-output'})
    
    # Get dishes in tables
    main_tabs = main_div.find_all('table',attrs={'class':'wikitable'})
    print('Found {} tables.'.format(len(main_tabs)))
    dishes = []
    for main_tab in main_tabs:
        trs = main_tab.find_all('tr')
        for tr in trs[1:]: # skip the table header
            td = tr.find('td')
            if td is not None:
                dishes.append(td.text.strip())
    print('Found {} dishes within tables.'.format(len(dishes)))
    
    # Get dishes in lists before 'See also/Bibligraphy/Notes' sections
    footer = find_footer(main_div)
    if footer is not None:
        last_ul_before_footer = footer.find_previous_sibling('ul')
        if last_ul_before_footer is not None:
            uls = main_div.find_all('ul',recursive=False)
            print("Found {} lists.".format(len(uls)))
            filtered_uls = []
            ix_ul = 0
            ul = uls[ix_ul]
            while ul is not last_ul_before_footer:
                filtered_uls.append(ul)
                ix_ul += 1
                ul = uls[ix_ul]
            filtered_uls.append(uls[ix_ul])

            lis = []
            for ul in filtered_uls:
                lis.extend([li for li in ul.find_all('li')
                           if ('class' not in li.attrs) or 
                           ('caption' not in li['class'][0])])

            # get only italicized portion if present
            for li in lis:
                try:
                    dish = li.find('i').text.strip()
                except AttributeError:
                    dish = li.text.strip()
                dishes.append(dish)  
        else:
            print("Found no lists before footer sections.")
    else:
        print("No footer found!")
    
    cleaned_dishes = [d.split(' - ')[0].split(': ')[0].split(' – ')[0]\
            .split(' is ')[0].split(', ')[0].split('\n')
            for d in dishes]
    
    return [item for sublist in cleaned_dishes for item in sublist
           if len(item) > 0]

def get_dishes(cuisine_url):
    """
    Wrapper function that gets dishes from 'X Cuisine' and 
    'List of X dishes' Wiki pages.
    @param cuisine_url: str Wikipedia url for the 'X Cuisine' page
    """
    url_cuisine = cuisine_url.split('/')[-1].split('_')[0] 
    print('Getting dishes for {} cuisine'.format(url_cuisine))
    out1 = set(get_cuisine_elements(cuisine_url))
    url2 = "https://en.wikipedia.org/wiki/List_of_{}_dishes".format(
                url_cuisine)
    try:
        out2 = set(get_cuisine_elements(url2))
    except HTTPError:
        out2 = set()
    
    print('Found {} dishes in List page.'.format(len(out2)))
    return list(out1 | out2)

# %%
#cuisine_elements = defaultdict(dict)
# for cuisine_type in ['non_western']:#['western','non_western']:
#     for cuisine_hyperlink in cuisine_hyperlinks[cuisine_type]:
#         cuisine_elements[cuisine_type][cuisine_hyperlink] = \
#             get_dishes(cuisine_hyperlink)

# %%
all_W_els = [item for sublist in cuisine_elements['western'].values() 
             for item in sublist]
all_W_els_set = set(all_W_els)

all_NW_els = [item for sublist in cuisine_elements['non_western'].values() 
             for item in sublist]
all_NW_els_set = set(all_NW_els)

len(all_W_els),len(all_W_els_set),len(all_NW_els),len(all_NW_els_set)
# Out:
# (5651, 5241, 3179, 3052)

# %%
# with open('./data/cuisine_labeled/wiki_western.txt','w') as f:
#     for el in all_W_els_set:
#         f.write(el+'\n')
        
# with open('./data/cuisine_labeled/wiki_nonwestern.txt','w') as f:
#     for el in all_NW_els_set:
#         f.write(el+'\n')

# %% [markdown]
# ### Qualitative exploration

# %%
with open('./data/cuisine_labeled/wiki_western.txt','r') as f:
    W_els = f.read().splitlines()
with open('./data/cuisine_labeled/wiki_nonwestern.txt','r') as f:
    NW_els = f.read().splitlines()
len(W_els),len(NW_els)
# Out:
# (5241, 3052)

# %% [markdown]
# Some observations:
# - Some imbalance in data available
# - Some dishes have rather long names; some also have descriptions attached that were not cleaned through rule-based heuristics (e.g., italics, colons, punctuation).
# - There is some overlap (N=113) in W/NW dishes due to some common food terms; Russian cuisine seems to be in both.

# %%
W_NW_overlap = set(W_els).intersection(set(NW_els))
len(W_NW_overlap)
# Out:
# 113

# %%
set(W_els).intersection(set(NW_els))
# Out:
# {'Baguette',
#  'Baranka',
#  'Beef Stroganoff',
#  'Beef Stroganoff served with rice',
#  'Beer',
#  'Bitterballen',
#  'Blini',
#  'Borodinsky bread',
#  'Borscht',
#  'Bublik',
#  'Buckwheat kasha',
#  'Caviar',
#  'Caviar butterbrot',
#  'Chicken Kiev',
#  'Chicken cutlets',
#  'Chilled soups based on kvass',
#  'Chocolate',
#  'Courgette caviar',
#  'Crêpes',
#  'Dressed Herring',
#  'Dressed herring (Seld pod shuboi)',
#  'Eastern European style sauerkraut',
#  'Escabeche',
#  'Firni',
#  'Fish soups such as ukha.',
#  'Fruits',
#  'Golubtsy',
#  'Grain- and vegetable-based soups.',
#  'Guriev porridge',
#  'Hutspot',
#  'Ice cream',
#  'Julienne',
#  'Kalach',
#  'Karavai',
#  'Karelsky pirog',
#  'Kasha',
#  'Kasha served with jam',
#  'Kasha with milk',
#  'Kholodets',
#  'Khren',
#  'Khrenovina',
#  'Kissel',
#  'Kissel served with bananas and grapes',
#  'Knish',
#  'Kompot',
#  'Kulich',
#  'Kulyebyaka',
#  'Kurnik',
#  'Kurnik (pirog)',
#  'Kutia',
#  'Kvass',
#  'Light soups and stews based on water and vegetables',
#  'Lor',
#  'Makarony po-flotski',
#  'Meat',
#  'Medovukha',
#  'Mimosa salad',
#  'Mors',
#  'Noodle soups with meat',
#  'Okroshka',
#  'Oladyi',
#  'Olivier salad',
#  'Olivier salad (Stolichniy salad)',
#  'Pan-fried crucian carps',
#  'Panada',
#  'Paskha',
#  'Pastila',
#  'Pelmeni',
#  'Pickled herring with sour cream',
#  'Pickled tomatoes',
#  'Pickles',
#  'Pirog',
#  'Pirozhki',
#  'Pizza',
#  'Poffertjes',
#  'Polvorón',
#  'Porridge',
#  'Pozharsky cutlet',
#  'Pryanik',
#  'Rassolnik',
#  'Rasstegai',
#  'Russian cuisine on a postage stamp sheet of Russia',
#  'Ryazhenka',
#  'Satay',
#  'Sbiten',
#  'Seafood',
#  'Shashlyk',
#  'Shchi',
#  'Smetana',
#  'Solyanka',
#  'Sorrel soup(green\xa0shchi)',
#  'Soups based on cabbage',
#  'Stroganina',
#  'Sushki',
#  'Svekolnik',
#  'Syrniki served with varenye',
#  'Syrniki(tvorozhniki)',
#  'Thick soups based on meat broth',
#  'Ukha',
#  'Varenets',
#  'Varenye',
#  'Vatrushka',
#  'Veal Orlov',
#  'Vegetables',
#  'Vinegret',
#  'Vodka',
#  'Zakuski',
#  'Zefir',
#  'a large boiled piece of meat cooked in a soup or porridge',
#  'miska',
#  'offal dishes (liver',
#  'tvorog',
#  'whole fowl dishes or parts of fowl (legs or breasts)'}

# %% [markdown]
# ### Train classifier

# %% [markdown]
# #### Create train, dev, test sets

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X, Y = np.array(W_els+NW_els), np.array(
    ['w']*len(W_els)+['nw']*len(NW_els))
X_train, X_dev_test, Y_train, Y_dev_test = train_test_split(
    X, Y, test_size=0.33, random_state=42)
X_dev, X_test, Y_dev, Y_test = train_test_split(
    X_dev_test, Y_dev_test, test_size=0.6, random_state=42)

assert len(X_train) == len(Y_train)
assert len(X_dev) == len(Y_dev)
assert len(X_test) == len(Y_test)

print("Created tr/de/te splits with {}/{}/{} examples.".format(
    len(X_train),len(X_dev),len(X_test)))

print("Writing to files...")
parent_dir = './data/classifier/wiki'
os.mkdir(parent_dir)
pd.DataFrame({'recipe_name': X_train, 'label': Y_train}).to_csv(
    parent_dir+'/train.tsv',sep='\t',header=True,index=False)
pd.DataFrame({'recipe_name': X_dev, 'label': Y_dev}).to_csv(
    parent_dir+'/dev.tsv',sep='\t',header=True,index=False)
pd.DataFrame({'recipe_name': X_test, 'label': Y_test}).to_csv(
    parent_dir+'/test.tsv',sep='\t',header=True,index=False)
# Out:
# Created tr/de/te splits with 5556/1094/1643 examples.
# Writing to files...

# %% [markdown]
# #### Create gold eval sets

# %% [markdown]
# * manually labeled sample of BA/NYT recipes (`gold_manual`)
# * `gold_manual`, but filtering to only nouns (`gold_manual_nouns`)
# * sample of BA/NYT recipes labeled via explicit demonym mentions (`gold_dem`)

# %%
# Create manually labeled OOD test set on BA/NYT recipes
# by randomly sample from recipes w/o a label
gold_manual = df.loc[pd.isnull(df['cuisine_type'])].sample(n=150)
gold_manual['source'].value_counts()
# Out:
# ba     107
# nyt     43
# Name: source, dtype: int64

# %%
# with open('./data/cuisine_labeled/gold_sample.tsv','w') as f:
#     f.write('title\tlabel\n')
#     for title in gold_manual['title'].values:
#         f.write(title+'\t'+str(-1)+'\n')

# %%
gold_manual = pd.read_csv('./data/cuisine_labeled/gold_sample.tsv',
                            sep='\t',header=0)
gold_manual.shape
# Out:
# (150, 3)

# %%
gold_manual['label'].value_counts()
# Out:
# w     119
# nw     31
# Name: label, dtype: int64

# %%
# Create `gold_manual_nouns`

def get_title_nouns(recipe_url):
    """Looks up the spaCy processed json given a recipe's URL and 
    returns the nouns in the recipe's title"""
    
    recipe_fname = os.path.join('data','preprocessed',recipe_url.split('/')[-1])
    with open(recipe_fname,'r') as f:
        json_obj = json.load(f)
    
    title_nouns = [l for ix_l,l in enumerate(json_obj['title']['lemmas'])
                    if json_obj['title']['pos'][ix_l] == 'NOUN']
    
    return ' '.join(title_nouns)

# %%
gold_manual['gold_manual_nouns'] = gold_manual['URL'].apply(lambda x: get_title_nouns(x))

# %%
gold_manual.head()
# Out:
#                                       title label  \
# 0  Large White Bean, Tuna and Spinach Salad     w
# 1        Smashed and Loaded Crispy Potatoes     w
# 2                                 Margarita     w
# 3                         Nita's Crazy Cake     w
# 4      Warm Apple-Cornmeal Upside-Down Cake     w
#
#                                                  URL        gold_manual_nouns
# 0  http://cooking.nytimes.com//recipes/1014616-la...  bean tuna spinach salad
# 1  http://www.bonappetit.com/recipe/smashed-and-l...                   potato
# 2  http://cooking.nytimes.com//recipes/1016358-ma...                margarita
# 3  http://www.bonappetit.com/recipe/nita-s-crazy-...                     cake
# 4  http://www.bonappetit.com/recipe/warm-apple-co...               apple cake

# %%
# Use explicit demonym indicators as another gold sample 
gold_dem = df.loc[~pd.isnull(df['demonym_label'])][['title','demonym_label']]
gold_dem.reset_index(drop=True,inplace=True)
gold_dem.shape
# Out:
# (367, 2)

# %%
gold_dem
# Out:
#                                            title demonym_label
# 0                          Salvadoran Quesadilla            nw
# 1                          Italian Chopped Salad             w
# 2                          Jamaican Beef Patties            nw
# 3            Swirled No-Churn Thai Tea Ice Cream            nw
# 4    Chrissy Teigen’s Thai Soy-Garlic Fried Ribs            nw
# ..                                           ...           ...
# 362                                White Russian             w
# 363            Italian Mushroom and Celery Salad             w
# 364             Italian Bread Salad (Panzanella)             w
# 365                  South Indian Eggplant Curry            nw
# 366                      Octopus, Galician Style             w
#
# [367 rows x 2 columns]

# %%
X_gold_manual, Y_gold_manual = np.array(gold_manual['title'].apply(
                                    lambda x: x.lower())), np.array(gold_manual['label'])

X_gold_manual_noun, Y_gold_manual_noun = np.array(gold_manual['gold_manual_nouns'].apply(
                                    lambda x: x.lower())), np.array(gold_manual['label'])

X_gold_dem, Y_gold_dem = np.array(gold_dem['title'].apply(
                                    lambda x: x.lower())), np.array(gold_dem['demonym_label'])

# %%
gold_data_dict = {
    'manual': {'X': X_gold_manual, 'Y': Y_gold_manual},
    'manual_nouns': {'X': X_gold_manual_noun, 'Y': Y_gold_manual_noun},
    'dem': {'X': X_gold_dem, 'Y': Y_gold_dem},
}

# %%
parent_dir = './data/classifier/GOLD'
os.mkdir(parent_dir)
for key in gold_data_dict:
    pd.DataFrame({'recipe_name': gold_data_dict[key]['X'],
                  'label': gold_data_dict[key]['Y']}).to_csv(parent_dir+'/'+key+'.tsv',
                                                    sep='\t',header=True,index=False)

# %% [markdown]
# #### Establish baselines

# %% [markdown]
# Baselines:
# - guess majority class (W)
# - Naive Bayes
# - linear SVM
# - logistic regression

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier, LogisticRegression

# %%
from sklearn.pipeline import Pipeline

NB_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB()),
])

SVM_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', SGDClassifier(loss='hinge', penalty='l2',
                          alpha=1e-3, random_state=42,
                          max_iter=5, tol=None)),
])

LR_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', LogisticRegression(random_state=42, 
                               class_weight='balanced')),
])

NB_clf.fit(X_train, Y_train)
SVM_clf.fit(X_train, Y_train)
LR_clf.fit(X_train, Y_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('clf',
#                  LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=42,
#                                     solver='warn', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
print('************* Test set performance *************')

MC_predicted = np.array(['w']*len(X_test))
print("\tMajority class acc: {0:10}".format(
    round(np.mean(MC_predicted == Y_test),3)))

NB_predicted = NB_clf.predict(X_test)
print("\tNaive Bayes acc: {0:12}".format(
    round(np.mean(NB_predicted == Y_test),3)))

SVM_predicted = SVM_clf.predict(X_test)
print("\tSVM acc: {0:21}".format(
    round(np.mean(SVM_predicted == Y_test),3)))

LR_predicted = LR_clf.predict(X_test)
print("\tLogistic Regression acc: {0:2}".format(
    round(LR_clf.score(X_test, Y_test),3)))

print('\n************ Gold sample (manual) performance ************')

MC_predicted = np.array(['w']*len(gold_data_dict['manual']['X']))
print("\tMajority class acc: {0:10}".format(
    round(np.mean(MC_predicted == gold_data_dict['manual']['Y']),3)))

NB_predicted = NB_clf.predict(gold_data_dict['manual']['X'])
print("\tNaive Bayes acc: {0:12}".format(
    round(np.mean(NB_predicted == gold_data_dict['manual']['Y']),3)))

SVM_predicted = SVM_clf.predict(gold_data_dict['manual']['X'])
print("\tSVM acc: {0:21}".format(
    round(np.mean(SVM_predicted == gold_data_dict['manual']['Y']),3)))

LR_predicted = LR_clf.predict(gold_data_dict['manual']['X'])
print("\tLogistic Regression acc: {0:2}".format(
    round(LR_clf.score(X_gold, gold_data_dict['manual']['Y']),3)))

print('\n************ Gold sample (manual, nouns only) performance ************')

MC_predicted = np.array(['w']*len(gold_data_dict['manual_nouns']['X']))
print("\tMajority class acc: {0:10}".format(
    round(np.mean(MC_predicted == gold_data_dict['manual_nouns']['Y']),3)))

NB_predicted = NB_clf.predict(gold_data_dict['manual_nouns']['X'])
print("\tNaive Bayes acc: {0:12}".format(
    round(np.mean(NB_predicted == gold_data_dict['manual_nouns']['Y']),3)))

SVM_predicted = SVM_clf.predict(gold_data_dict['manual_nouns']['X'])
print("\tSVM acc: {0:21}".format(
    round(np.mean(SVM_predicted == gold_data_dict['manual_nouns']['Y']),3)))

LR_predicted = LR_clf.predict(gold_data_dict['manual_nouns']['X'])
print("\tLogistic Regression acc: {0:2}".format(
    round(LR_clf.score(X_gold, gold_data_dict['manual_nouns']['Y']),3)))

print('\n************ Gold sample (demonym labelled) performance ************')

MC_predicted = np.array(['w']*len(gold_data_dict['dem']['X']))
print("\tMajority class acc: {0:10}".format(
    round(np.mean(MC_predicted == gold_data_dict['dem']['Y']),3)))

NB_predicted = NB_clf.predict(gold_data_dict['dem']['X'])
print("\tNaive Bayes acc: {0:12}".format(
    round(np.mean(NB_predicted == gold_data_dict['dem']['Y']),3)))

SVM_predicted = SVM_clf.predict(gold_data_dict['dem']['X'])
print("\tSVM acc: {0:21}".format(
    round(np.mean(SVM_predicted == gold_data_dict['dem']['Y']),3)))

LR_predicted = LR_clf.predict(gold_data_dict['dem']['X'])
print("\tLogistic Regression acc: {0:2}".format(
    round(LR_clf.score(X_gold_dem, gold_data_dict['dem']['Y']),3)))
# Out:
# ************* Test set performance *************
# 	Majority class acc:      0.644
# 	Naive Bayes acc:         0.82
# 	SVM acc:                 0.716
# 	Logistic Regression acc: 0.813
#
# ************ Gold sample (manual) performance ************
# 	Majority class acc:      0.793
# 	Naive Bayes acc:         0.82
# 	SVM acc:                 0.793
# 	Logistic Regression acc: 0.773
#
# ************ Gold sample (manual, nouns only) performance ************
# 	Majority class acc:      0.793
# 	Naive Bayes acc:         0.82
# 	SVM acc:                   0.8
# 	Logistic Regression acc: 0.773
#
# ************ Gold sample (demonym labelled) performance ************
# 	Majority class acc:      0.349
# 	Naive Bayes acc:        0.559
# 	SVM acc:                 0.447
# 	Logistic Regression acc: 0.629

# %% [markdown]
# #### BERT

# %% [markdown]
# # Initial analysis

# %% [markdown]
# ## Q: Which words occur most often in W vs. NW recipes?

# %%
import math

def compute_lor(c1, c2, smoothing=True):
    """
    Computes log odds ratios between words in Counted corpus 1 vs. 2.
    @param c1: Counter object of words in corpus 1.
    @param c2: Counter object of words in corpus 2.
    @smoothing: if True, applies +0.5 smoothing to difference between 
                words occurring in one corpus but not the other;
                if False, only looks at words occuring in both corpora
    """
    
    c1_vocab, c2_vocab = set(c1.keys()), set(c2.keys())
    
    if smoothing:
        joint_vocab = c1_vocab.union(c2_vocab)
        c1 = {w: c1[w]+0.5 for w in joint_vocab}
        c2 = {w: c2[w]+0.5 for w in joint_vocab}
    else:
        joint_vocab = c1_vocab.intersection(c2_vocab)
    
    # convert counts to frequencies
    N1, N2 = sum(c1.values()), sum(c2.values())
    f1, f2 = {w: c1[w]/N1 for w in joint_vocab}, {w: c2[w]/N2 
                                              for w in joint_vocab}
    
    # frequencies > odds
    o1, o2 = {w: f1[w]/(1-f1[w]) for w in f1}, {w: f2[w]/(1-f2[w]) 
                                                for w in f2}
    
    # odds > log odds ratios
    lor = {w: math.log(o1[w]/o2[w]) for w in joint_vocab}
    
#     print(c1,c2)
#     print(N1,N2)
#     print(f1,f2)
#     print(o1,o2)
    
    return lor

# %%
recipe_words = {'west': defaultdict(list),
                'non_west': defaultdict(list)}

for cuisine_type in ['west','non_west']:
    cuisine_df = df.loc[df['cuisine_type']==cuisine_type]
    #print(cuisine_df.shape)
    for ix_row,row in cuisine_df.iterrows():
        fname = ix_row.split('/')[-1]
        with open('./data/preprocessed/'+fname,'r') as file:
            json_obj = json.load(file)
            
            for field in ['title','description','steps']:
                if field in json_obj:
                    recipe_words[cuisine_type][field].extend(
                        json_obj[field]['lemmas'])

# %%
for key in recipe_words:
    for key2 in recipe_words[key]:
        print(key,key2,len(recipe_words[key][key2]))
# Out:
# west title 7686
# west description 145368
# west steps 398272
# non_west title 9572
# non_west description 206389
# non_west steps 475658

# %%
lor = compute_lor(Counter(recipe_words['non_west']['title']), 
                  Counter(recipe_words['west']['title']))

# %%
len(lor)
# Out:
# 2397

# %%
sorted(lor.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('stir', 4.503861836578962),
#  ('tofu', 4.180563009554212),
#  ('thai', 4.101295073425935),
#  ('burger', 3.4728147786587362),
#  ('indian', 3.420078034895612),
#  ('blueberry', 3.420078034895612),
#  ('mango', 3.364415182113205),
#  ('vietnamese', 3.364415182113205),
#  ('soba', 3.242868347797634),
#  ('turkish', 3.1760839976120367),
#  ('smoothie', 3.1760839976120367),
#  ('soy', 3.1045320665866414),
#  ('dal', 3.1045320665866414),
#  ('bowl', 3.1045320665866414),
#  ('choy', 3.027478067049331),
#  ('taco', 2.9746974948300253),
#  ('curry', 2.9460309734873875),
#  ('bok', 2.9440035083495584),
#  ('peanut', 2.8547798006349074),
#  ('mexican', 2.8529387890219655),
#  ('dumpling', 2.752762397980366),
#  ('pho', 2.752762397980366),
#  ('asian', 2.752762397980366),
#  ('hash', 2.641443839021169),
#  ('blini', 2.51618778085223),
#  ('quesadilla', 2.51618778085223),
#  ('dress', 2.51618778085223),
#  ('moroccan', 2.3740899217460094),
#  ('japanese', 2.3740899217460094),
#  ('five', 2.3729940306290582),
#  ('tamale', 2.3729940306290582),
#  ('thigh', 2.3729940306290582),
#  ('caviar', 2.3729940306290582),
#  ('new', 1.5427189821084424),
#  ('masala', 1.5427189821084424),
#  ('snap', 1.5427189821084424),
#  ('stuffing', 1.5427189821084424),
#  ('cooker', 1.521303713125961),
#  ('lime', 1.4948690049902709),
#  ('chutney', 1.4948690049902709),
#  ('sugar', 1.4948690049902709),
#  ('vegetarian', 1.4948690049902709),
#  ('caramel', 1.4178150054529601),
#  ('tamarind', 1.4174629239395031),
#  ('cheesecake', 1.4174629239395031),
#  ('pocket', 1.4171110455639093),
#  ('deep', 1.4171110455639093),
#  ('lucy', 1.4171110455639093),
#  ('streusel', 1.4171110455639093),
#  ('sodha', 1.4171110455639093),
#  ('tanis', 1.4171110455639093),
#  ('naan', 1.4171110455639093),
#  ('sushi', 1.4171110455639093),
#  ('mahi', 1.4171110455639093),
#  ('lassi', 1.4171110455639093),
#  ('cha', 1.4171110455639093),
#  ('vermicelli', 1.4171110455639093),
#  ('sichuan', 1.4171110455639093),
#  ('almost', 1.4171110455639093),
#  ('hummus', 1.4171110455639093),
#  ('yaki', 1.4171110455639093),
#  ('waldorf', 1.4171110455639093),
#  ('gochujang', 1.4171110455639093),
#  ('mafe', 1.4171110455639093),
#  ('shanghai', 1.4171110455639093),
#  ('chermoula', 1.4171110455639093),
#  ('meera', 1.4171110455639093),
#  ('paprika', 1.4171110455639093),
#  ('richard', 1.4171110455639093),
#  ('roy', 1.4171110455639093),
#  ('ambrosia', 1.4171110455639093),
#  ('scampi', 1.4171110455639093),
#  ('wedge', 1.4171110455639093),
#  ('brigadeiro', 1.4171110455639093),
#  ('bolognese', 1.4171110455639093),
#  ('broccolini', 1.4171110455639093),
#  ('taiwanese', 1.4171110455639093),
#  ('pop', 1.4171110455639093),
#  ('croquette', 1.4171110455639093),
#  ('deluxe', 1.4171110455639093),
#  ('thanksgive', 1.4171110455639093),
#  ('flay', 1.4171110455639093),
#  ('ki', 1.4171110455639093),
#  ('dan', 1.4171110455639093),
#  ('tarka', 1.4171110455639093),
#  ('t', 1.4171110455639093),
#  ('rendang', 1.4171110455639093),
#  ('hoisin', 1.4171110455639093),
#  ('open', 1.4171110455639093),
#  ('raita', 1.4171110455639093),
#  ('bibingka', 1.4171110455639093),
#  ('sopa', 1.4171110455639093),
#  ('jamaican', 1.4171110455639093),
#  ('sake', 1.4171110455639093),
#  ('lo', 1.4171110455639093),
#  ('pikliz', 1.4171110455639093),
#  ('khichdi', 1.4171110455639093),
#  ('popsicle', 1.4171110455639093),
#  ('amaranth', 1.4171110455639093),
#  ('okonomiyaki', 1.4171110455639093),
#  ('alfredo', 1.4171110455639093),
#  ('refrigerator', 1.4171110455639093),
#  ('matcha', 1.4171110455639093),
#  ('party', 1.4171110455639093),
#  ('pumpkinseed', 1.4171110455639093),
#  ('jamaica', 1.4171110455639093),
#  ('fast', 1.4171110455639093),
#  ('migas', 1.4171110455639093),
#  ('tandoori', 1.4171110455639093),
#  ('russian', 1.4171110455639093),
#  ('wasabi', 1.4171110455639093),
#  ('ma', 1.4171110455639093),
#  ('malai', 1.4171110455639093),
#  ('ginger', 1.2290046662865834),
#  ('pressure', 1.1721810539544548),
#  ('chile', 1.155842523588793),
#  ('muffin', 1.1430993363839954),
#  ('pumpkin', 1.1359136547543038),
#  ('avocado', 1.1359136547543038),
#  ('pickle', 1.1359136547543038),
#  ('pecan', 1.1078067627468533),
#  ('macaroni', 1.1071221911014983),
#  ('old', 1.1071221911014983),
#  (':', 1.1071221911014983),
#  ('wing', 1.1071221911014983),
#  ('guacamole', 1.1071221911014983),
#  ('cheesy', 1.1071221911014983),
#  ('doughnut', 1.1071221911014983),
#  ('three', 1.1071221911014983),
#  ('cucumber', 1.0743565378783746),
#  ('rice', 1.0582437905269166),
#  ('dukkah', 1.0317807774247982),
#  ('shiitake', 1.0317807774247982),
#  ('cookie', 1.0317807774247982),
#  ('spice', 0.9991071396012282),
#  ('cilantro', 0.9977556165384311),
#  ('short', 0.9977556165384311),
#  ('cooky', 0.9073562600010473),
#  ('rib', 0.9073562600010473),
#  ('dressing', 0.9071898215768622),
#  ('glaze', 0.9070234483308129),
#  ('dip', 0.9068571402223202),
#  ('chip', 0.9068571402223202),
#  ('blue', 0.9065247192558591),
#  ('relish', 0.9065247192558591),
#  ('frosting', 0.9065247192558591),
#  ('wrap', 0.9063586063169079),
#  ('seaweed', 0.9063586063169079),
#  ('granola', 0.9063586063169079),
#  ('double', 0.9063586063169079),
#  ('crunch', 0.9063586063169079),
#  ('crumble', 0.9063586063169079),
#  ('kimchi', 0.9063586063169079),
#  ('gumbo', 0.9063586063169079),
#  ('tea', 0.9063586063169079),
#  ('poblano', 0.9063586063169079),
#  ('daikon', 0.9063586063169079),
#  ('make', 0.9063586063169079),
#  ('albacore', 0.9061925583535467),
#  ('parm', 0.9061925583535467),
#  ('merguez', 0.9061925583535467),
#  ('boulevardier', 0.9061925583535467),
#  ('kosambari', 0.9061925583535467),
#  ('flor', 0.9061925583535467),
#  ('masa', 0.9061925583535467),
#  ('hearty', 0.9061925583535467),
#  ('mee', 0.9061925583535467),
#  ('yakisoba', 0.9061925583535467),
#  ('color', 0.9061925583535467),
#  ('frijol', 0.9061925583535467),
#  ('indiana', 0.9061925583535467),
#  ('fannie', 0.9061925583535467),
#  ('murgh', 0.9061925583535467),
#  ('vaquero', 0.9061925583535467),
#  ('chapli', 0.9061925583535467),
#  ('moulen', 0.9061925583535467),
#  ('saltimbocca', 0.9061925583535467),
#  ('taka', 0.9061925583535467),
#  ('fourth', 0.9061925583535467),
#  ('licorice', 0.9061925583535467),
#  ('evan', 0.9061925583535467),
#  ('bell', 0.9061925583535467),
#  ('jordan', 0.9061925583535467),
#  ('25', 0.9061925583535467),
#  ('own', 0.9061925583535467),
#  ('samuel', 0.9061925583535467),
#  ('edouardo', 0.9061925583535467),
#  ('melted', 0.9061925583535467),
#  ('massage', 0.9061925583535467),
#  ('sephardic', 0.9061925583535467),
#  ('harina', 0.9061925583535467),
#  ('deli', 0.9061925583535467),
#  ('makai', 0.9061925583535467),
#  ('louie', 0.9061925583535467),
#  ('boss', 0.9061925583535467),
#  ('dage', 0.9061925583535467),
#  ('o', 0.9061925583535467),
#  ('mrouzia', 0.9061925583535467),
#  ('snickerdoodle', 0.9061925583535467),
#  ('moqueca', 0.9061925583535467),
#  ('nwa', 0.9061925583535467),
#  ('alabama', 0.9061925583535467),
#  ('dodo', 0.9061925583535467),
#  ('agege', 0.9061925583535467),
#  ('award', 0.9061925583535467),
#  ('sherbet', 0.9061925583535467),
#  ('ghriba', 0.9061925583535467),
#  ('hummer', 0.9061925583535467),
#  ('combination', 0.9061925583535467),
#  ('lankan', 0.9061925583535467),
#  ('lablabi', 0.9061925583535467),
#  ('piccata', 0.9061925583535467),
#  ('vindaloo', 0.9061925583535467),
#  ('roadside', 0.9061925583535467),
#  ('seviyan', 0.9061925583535467),
#  ('guajillo', 0.9061925583535467),
#  ('iga', 0.9061925583535467),
#  ('batter', 0.9061925583535467),
#  ('bloomfield', 0.9061925583535467),
#  ('obe', 0.9061925583535467),
#  ('kee', 0.9061925583535467),
#  ('aguachile', 0.9061925583535467),
#  ('coloradito', 0.9061925583535467),
#  ('norteña', 0.9061925583535467),
#  ('pwa', 0.9061925583535467),
#  ('lalla', 0.9061925583535467),
#  ('lover', 0.9061925583535467),
#  ('american', 0.9061925583535467),
#  ('kua', 0.9061925583535467),
#  ('dhokla', 0.9061925583535467),
#  ('vongerichten', 0.9061925583535467),
#  ('baklazhannaia', 0.9061925583535467),
#  ('reuben', 0.9061925583535467),
#  ('churn', 0.9061925583535467),
#  ('&', 0.9061925583535467),
#  ('field', 0.9061925583535467),
#  ('peter', 0.9061925583535467),
#  ('malagasy', 0.9061925583535467),
#  ('soman', 0.9061925583535467),
#  ('sabut', 0.9061925583535467),
#  ('scream', 0.9061925583535467),
#  ('callaloo', 0.9061925583535467),
#  ('noir', 0.9061925583535467),
#  ('kichri', 0.9061925583535467),
#  ('bbq', 0.9061925583535467),
#  ('agrodolce', 0.9061925583535467),
#  ('parfait', 0.9061925583535467),
#  ('harira', 0.9061925583535467),
#  ('spit', 0.9061925583535467),
#  ('sos', 0.9061925583535467),
#  ('peláez', 0.9061925583535467),
#  ('khar', 0.9061925583535467),
#  ('chesapeake', 0.9061925583535467),
#  ('mall', 0.9061925583535467),
#  ('korma', 0.9061925583535467),
#  ('mac', 0.9061925583535467),
#  ('april', 0.9061925583535467),
#  ('kidney', 0.9061925583535467),
#  ('scalloped', 0.9061925583535467),
#  ('ton', 0.9061925583535467),
#  ('wong', 0.9061925583535467),
#  ('bistek', 0.9061925583535467),
#  ('enfrijolada', 0.9061925583535467),
#  ('nugget', 0.9061925583535467),
#  ('burfi', 0.9061925583535467),
#  ('balinese', 0.9061925583535467),
#  ('nam', 0.9061925583535467),
#  ('grass', 0.9061925583535467),
#  ('colada', 0.9061925583535467),
#  ('tarator', 0.9061925583535467),
#  ('puritan', 0.9061925583535467),
#  ('ong', 0.9061925583535467),
#  ('herring', 0.9061925583535467),
#  ('madhur', 0.9061925583535467),
#  ('40', 0.9061925583535467),
#  ('kari', 0.9061925583535467),
#  ('niku', 0.9061925583535467),
#  ('lion', 0.9061925583535467),
#  ('ghanaian', 0.9061925583535467),
#  ('dripping', 0.9061925583535467),
#  ('limber', 0.9061925583535467),
#  ('as', 0.9061925583535467),
#  ('glory', 0.9061925583535467),
#  ('bali', 0.9061925583535467),
#  ('honeycomb', 0.9061925583535467),
#  ('ssam', 0.9061925583535467),
#  ('moka', 0.9061925583535467),
#  ('star', 0.9061925583535467),
#  ('nuong', 0.9061925583535467),
#  ('pone', 0.9061925583535467),
#  ('pancit', 0.9061925583535467),
#  ('float', 0.9061925583535467),
#  ('louis', 0.9061925583535467),
#  ('cobb', 0.9061925583535467),
#  ('pinto', 0.9061925583535467),
#  ('udang', 0.9061925583535467),
#  ('creamsicle', 0.9061925583535467),
#  ('brittle', 0.9061925583535467),
#  ('monkey', 0.9061925583535467),
#  ('fatty', 0.9061925583535467),
#  ('sekihan', 0.9061925583535467),
#  ('chopped', 0.9061925583535467),
#  ('vertamae', 0.9061925583535467),
#  ('syrian', 0.9061925583535467),
#  ('cellophane', 0.9061925583535467),
#  ('reichl', 0.9061925583535467),
#  ("d'orange", 0.9061925583535467),
#  ('rajas', 0.9061925583535467),
#  ('liberian', 0.9061925583535467),
#  ('mercimek', 0.9061925583535467),
#  ('francese', 0.9061925583535467),
#  ('mission', 0.9061925583535467),
#  ('july', 0.9061925583535467),
#  ('ata', 0.9061925583535467),
#  ('methi', 0.9061925583535467),
#  ('halwa', 0.9061925583535467),
#  ('parathas', 0.9061925583535467),
#  ('juice', 0.9061925583535467),
#  ('lantern', 0.9061925583535467),
#  ('mussa', 0.9061925583535467),
#  ('jell', 0.9061925583535467),
#  ('braai', 0.9061925583535467),
#  ('mogul', 0.9061925583535467),
#  ('maduros', 0.9061925583535467),
#  ('delight', 0.9061925583535467),
#  ('dolester', 0.9061925583535467),
#  ('load', 0.9061925583535467),
#  ('egyptian', 0.9061925583535467),
#  ('tsaramaso', 0.9061925583535467),
#  ('sorta', 0.9061925583535467),
#  ('dab', 0.9061925583535467),
#  ('loaded', 0.9061925583535467),
#  ('link', 0.9061925583535467),
#  ('flageolet', 0.9061925583535467),
#  ('graham', 0.9061925583535467),
#  ('update', 0.9061925583535467),
#  ('icing', 0.9061925583535467),
#  ('matar', 0.9061925583535467),
#  ('sundal', 0.9061925583535467),
#  ('hock', 0.9061925583535467),
#  ('store', 0.9061925583535467),
#  ('flat', 0.9061925583535467),
#  ('bricklayer', 0.9061925583535467),
#  ('imm', 0.9061925583535467),
#  ('poke', 0.9061925583535467),
#  ('pide', 0.9061925583535467),
#  ('funke', 0.9061925583535467),
#  ('spareribs', 0.9061925583535467),
#  ('manhattan', 0.9061925583535467),
#  ('sister', 0.9061925583535467),
#  ('reinhart', 0.9061925583535467),
#  ('tanzeya', 0.9061925583535467),
#  ('nasi', 0.9061925583535467),
#  ('lane', 0.9061925583535467),
#  ('chimichangas', 0.9061925583535467),
#  ('dulce', 0.9061925583535467),
#  ('circus', 0.9061925583535467),
#  ('soi', 0.9061925583535467),
#  ('nimono', 0.9061925583535467),
#  ('batida', 0.9061925583535467),
#  ('gong', 0.9061925583535467),
#  ('kitchen', 0.9061925583535467),
#  ('glass', 0.9061925583535467),
#  ('negimaki', 0.9061925583535467),
#  ('jewish', 0.9061925583535467),
#  ('mulberry', 0.9061925583535467),
#  ('backyard', 0.9061925583535467),
#  ('mai', 0.9061925583535467),
#  ('muerto', 0.9061925583535467),
#  ('poor', 0.9061925583535467),
#  ('vepudu', 0.9061925583535467),
#  ('amandine', 0.9061925583535467),
#  ('feijoada', 0.9061925583535467),
#  ('mold', 0.9061925583535467),
#  ('calabacita', 0.9061925583535467),
#  ('suey', 0.9061925583535467),
#  ('fat', 0.9061925583535467),
#  ('flanken', 0.9061925583535467),
#  ('nana', 0.9061925583535467),
#  ('haitian', 0.9061925583535467),
#  ('ikra', 0.9061925583535467),
#  ('man', 0.9061925583535467),
#  ('toor', 0.9061925583535467),
#  ('tall', 0.9061925583535467),
#  ('spiced', 0.9061925583535467),
#  ('rigatoni', 0.9061925583535467),
#  ('roja', 0.9061925583535467),
#  ('will', 0.9061925583535467),
#  ('forbid', 0.9061925583535467),
#  ('mol', 0.9061925583535467),
#  ('compote', 0.9061925583535467),
#  ('gobi', 0.9061925583535467),
#  ('mississippi', 0.9061925583535467),
#  ('amaretti', 0.9061925583535467),
#  ('cue', 0.9061925583535467),
#  ('machaca', 0.9061925583535467),
#  ('blancmange', 0.9061925583535467),
#  ('tumis', 0.9061925583535467),
#  ('tin', 0.9061925583535467),
#  ('frite', 0.9061925583535467),
#  ('frito', 0.9061925583535467),
#  ('trini', 0.9061925583535467),
#  ('pla', 0.9061925583535467),
#  ('negro', 0.9061925583535467),
#  ('mumbai', 0.9061925583535467),
#  ('martinez', 0.9061925583535467),
#  ('sri', 0.9061925583535467),
#  ('popcorn', 0.9061925583535467),
#  ('dupont', 0.9061925583535467),
#  ('burrito', 0.9061925583535467),
#  ('herby', 0.9061925583535467),
#  ('hawker', 0.9061925583535467),
#  ('brie', 0.9061925583535467),
#  ('upperline', 0.9061925583535467),
#  ('sameh', 0.9061925583535467),
#  ('tosi', 0.9061925583535467),
#  ('jian', 0.9061925583535467),
#  ('omurice', 0.9061925583535467),
#  ('kolbasa', 0.9061925583535467),
#  ('chang', 0.9061925583535467),
#  ('chiffon', 0.9061925583535467),
#  ('bharta', 0.9061925583535467),
#  ('bao', 0.9061925583535467),
#  ('bamboo', 0.9061925583535467),
#  ('sabudana', 0.9061925583535467),
#  ('murg', 0.9061925583535467),
#  ('ande', 0.9061925583535467),
#  ('grainy', 0.9061925583535467),
#  ('hobo', 0.9061925583535467),
#  ('gajar', 0.9061925583535467),
#  ('mokonut', 0.9061925583535467),
#  ('juneteenth', 0.9061925583535467),
#  ('hill', 0.9061925583535467),
#  ('somali', 0.9061925583535467),
#  ('pungent', 0.9061925583535467),
#  ('20', 0.9061925583535467),
#  ('roulade', 0.9061925583535467),
#  ('cruda', 0.9061925583535467),
#  ('bhatti', 0.9061925583535467),
#  ('hua', 0.9061925583535467),
#  ('jack', 0.9061925583535467),
#  ('sambhar', 0.9061925583535467),
#  ('mollie', 0.9061925583535467),
#  ('pinot', 0.9061925583535467),
#  ('finger', 0.9061925583535467),
#  ('yakitori', 0.9061925583535467),
#  ('cantonese', 0.9061925583535467),
#  ('abuelo', 0.9061925583535467),
#  ('panko', 0.9061925583535467),
#  ('eventide', 0.9061925583535467),
#  ('gajak', 0.9061925583535467),
#  ('splay', 0.9061925583535467),
#  ('tiki', 0.9061925583535467),
#  ('superiority', 0.9061925583535467),
#  ('kejriwal', 0.9061925583535467),
#  ('mascarpone', 0.9061925583535467),
#  ('hotel', 0.9061925583535467),
#  ('samosa', 0.9061925583535467),
#  ('makkhani', 0.9061925583535467),
#  ('kuku', 0.9061925583535467),
#  ('health', 0.9061925583535467),
#  ('ombré', 0.9061925583535467),
#  ('devil’s', 0.9061925583535467),
#  ('chez', 0.9061925583535467),
#  ('jyaga', 0.9061925583535467),
#  ('koftesi', 0.9061925583535467),
#  ('farofa', 0.9061925583535467),
#  ('yolk', 0.9061925583535467),
#  ('steamed', 0.9061925583535467),
#  ('shiro', 0.9061925583535467),
#  ('joanne', 0.9061925583535467),
#  ('riro', 0.9061925583535467),
#  ('étouffée', 0.9061925583535467),
#  ('raspados', 0.9061925583535467),
#  ('gonzalo', 0.9061925583535467),
#  ('mughlai', 0.9061925583535467),
#  ('embutido', 0.9061925583535467),
#  ('morel', 0.9061925583535467),
#  ('palabok', 0.9061925583535467),
#  ('xeo', 0.9061925583535467),
#  ('minty', 0.9061925583535467),
#  ('romney', 0.9061925583535467),
#  ('frost', 0.9061925583535467),
#  ('elote', 0.9061925583535467),
#  ('delicata', 0.9061925583535467),
#  ('japan', 0.9061925583535467),
#  ('strained', 0.9061925583535467),
#  ('mott', 0.9061925583535467),
#  ('can', 0.9061925583535467),
#  ('crabmeat', 0.9061925583535467),
#  ('tante', 0.9061925583535467),
#  ('ethiopian', 0.9061925583535467),
#  ('ale', 0.9061925583535467),
#  ('berber', 0.9061925583535467),
#  ('paratha', 0.9061925583535467),
#  ('paneer', 0.9061925583535467),
#  ('guzmán', 0.9061925583535467),
#  ('brick', 0.9061925583535467),
#  ('buttercream', 0.9061925583535467),
#  ('mao', 0.9061925583535467),
#  ('kentang', 0.9061925583535467),
#  ('prik', 0.9061925583535467),
#  ('jap', 0.9061925583535467),
#  ('food', 0.9061925583535467),
#  ('goong', 0.9061925583535467),
#  ('charro', 0.9061925583535467),
#  ('kulfi', 0.9061925583535467),
#  ('din', 0.9061925583535467),
#  ('hijiki', 0.9061925583535467),
#  ('josé', 0.9061925583535467),
#  ('revuelto', 0.9061925583535467),
#  ('laddoo', 0.9061925583535467),
#  ('farfalle', 0.9061925583535467),
#  ('firehouse', 0.9061925583535467),
#  ('mashama', 0.9061925583535467),
#  ('famous', 0.9061925583535467),
#  ('street', 0.9061925583535467),
#  ('skirt', 0.9061925583535467),
#  ('tomatoe', 0.9061925583535467),
#  ('pearl', 0.9061925583535467),
#  ('bebinca', 0.9061925583535467),
#  ('mallorcas', 0.9061925583535467),
#  ('ripple', 0.9061925583535467),
#  ('brew', 0.9061925583535467),
#  ('crema', 0.9061925583535467),
#  ('joumou', 0.9061925583535467),
#  ('benedict', 0.9061925583535467),
#  ('mung', 0.9061925583535467),
#  ('saag', 0.9061925583535467),
#  ('kachori', 0.9061925583535467),
#  ('algerian', 0.9061925583535467),
#  ('jaffrey', 0.9061925583535467),
#  ('sangrita', 0.9061925583535467),
#  ('whoopie', 0.9061925583535467),
#  ('packet', 0.9061925583535467),
#  ('imam', 0.9061925583535467),
#  ('gooey', 0.9061925583535467),
#  ('tyson', 0.9061925583535467),
#  ('bing', 0.9061925583535467),
#  ('tray', 0.9061925583535467),
#  ('sand', 0.9061925583535467),
#  ('crudité', 0.9061925583535467),
#  ('bathe', 0.9061925583535467),
#  ('kombucha', 0.9061925583535467),
#  ('snow', 0.9061925583535467),
#  ('fonio', 0.9061925583535467),
#  ('grosvenor', 0.9061925583535467),
#  ('chivichangas', 0.9061925583535467),
#  ('bavette', 0.9061925583535467),
#  ('jean', 0.9061925583535467),
#  ('dust', 0.9061925583535467),
#  ('lu', 0.9061925583535467),
#  ('charmoula', 0.9061925583535467),
#  ('takeout', 0.9061925583535467),
#  ('nishime', 0.9061925583535467),
#  ('pastelitos', 0.9061925583535467),
#  ('leafy', 0.9061925583535467),
#  ('jerry', 0.9061925583535467),
#  ('dávila', 0.9061925583535467),
#  ('navy', 0.9061925583535467),
#  ('forest', 0.9061925583535467),
#  ('bit', 0.9061925583535467),
#  ('rasam', 0.9061925583535467),
#  ('keema', 0.9061925583535467),
#  ('opor', 0.9061925583535467),
#  ('thumbprint', 0.9061925583535467),
#  ('flannel', 0.9061925583535467),
#  ('quail', 0.9061925583535467),
#  ('skin', 0.9061925583535467),
#  ('baklava', 0.9061925583535467),
#  ('thiam', 0.9061925583535467),
#  ('tingly', 0.9061925583535467),
#  ('pawpaw', 0.9061925583535467),
#  ('stand', 0.9061925583535467),
#  ('moufleta', 0.9061925583535467),
#  ('royale', 0.9061925583535467),
#  ('aromatic', 0.9061925583535467),
#  ('park', 0.9061925583535467),
#  ('stout', 0.9061925583535467),
#  ('malt', 0.9061925583535467),
#  ('england', 0.9061925583535467),
#  ('alphabet', 0.9061925583535467),
#  ('california', 0.9061925583535467),
#  ('bombay', 0.9061925583535467),
#  ('ravaiya', 0.9061925583535467),
#  ('barii', 0.9061925583535467),
#  ('katzen', 0.9061925583535467),
#  ('tatemada', 0.9061925583535467),
#  ('campechana', 0.9061925583535467),
#  ('festival', 0.9061925583535467),
#  ('gillette', 0.9061925583535467),
#  ('prime', 0.9061925583535467),
#  ('giuseppe', 0.9061925583535467),
#  ('wheel', 0.9061925583535467),
#  ('marshmallow', 0.9061925583535467),
#  ('treat', 0.9061925583535467),
#  ('caldo', 0.9061925583535467),
#  ('mile', 0.9061925583535467),
#  ('borek', 0.9061925583535467),
#  ('fryer', 0.9061925583535467),
#  ('blister', 0.9061925583535467),
#  ('clay', 0.9061925583535467),
#  ('chepa', 0.9061925583535467),
#  ('ann', 0.9061925583535467),
#  ('paka', 0.9061925583535467),
#  ('mandarin', 0.9061925583535467),
#  ('lumpia', 0.9061925583535467),
#  ('gogola', 0.9061925583535467),
#  ('chakundari', 0.9061925583535467),
#  ('blackout', 0.9061925583535467),
#  ('whelk', 0.9061925583535467),
#  ('speculoo', 0.9061925583535467),
#  ('wrapper', 0.9061925583535467),
#  ('polish', 0.9061925583535467),
#  ('tom', 0.9061925583535467),
#  ('shred', 0.9061925583535467),
#  ('morning', 0.9061925583535467),
#  ('maida', 0.9061925583535467),
#  ('tumble', 0.9061925583535467),
#  ('faced', 0.9061925583535467),
#  ('bihari', 0.9061925583535467),
#  ('horowitz', 0.9061925583535467),
#  ('crinkle', 0.9061925583535467),
#  ('pepperoni', 0.9061925583535467),
#  ('moong', 0.9061925583535467),
#  ('popper', 0.9061925583535467),
#  ('ozoni', 0.9061925583535467),
#  ('ember', 0.9061925583535467),
#  ('gassi', 0.9061925583535467),
#  ('sink', 0.9061925583535467),
#  ('longevity', 0.9061925583535467),
#  ('oyakodon', 0.9061925583535467),
#  ('tostone', 0.9061925583535467),
#  ('meen', 0.9061925583535467),
#  ('bratwurst', 0.9061925583535467),
#  ('efo', 0.9061925583535467),
#  ('collier', 0.9061925583535467),
#  ('medallion', 0.9061925583535467),
#  ('flag', 0.9061925583535467),
#  ('ranchero', 0.9061925583535467),
#  ('papantla', 0.9061925583535467),
#  ('gzik', 0.9061925583535467),
#  ('chew', 0.9061925583535467),
#  ('diana', 0.9061925583535467),
#  ('delhi', 0.9061925583535467),
#  ('pinakbet', 0.9061925583535467),
#  ('ginataang', 0.9061925583535467),
#  ('shalom', 0.9061925583535467),
#  ('coronation', 0.9061925583535467),
#  ('chae', 0.9061925583535467),
#  ('mayi', 0.9061925583535467),
#  ('sukhe', 0.9061925583535467),
#  ('crockpot', 0.9061925583535467),
#  ('festive', 0.9061925583535467),
#  ('greg', 0.9061925583535467),
#  ('original', 0.9061925583535467),
#  ('lac', 0.9061925583535467),
#  ('pakistani', 0.9061925583535467),
#  ('mom', 0.9061925583535467),
#  ('mofongo', 0.9061925583535467),
#  ('atole', 0.9061925583535467),
#  ('eagle', 0.9061925583535467),
#  ('biriyani', 0.9061925583535467),
#  ('agave', 0.9061925583535467),
#  ('singaporean', 0.9061925583535467),
#  ('hyderabad', 0.9061925583535467),
#  ('sprinkle', 0.9061925583535467),
#  ('nomad', 0.9061925583535467),
#  ('gyoza', 0.9061925583535467),
#  ('shiso', 0.9061925583535467),
#  ('microwave', 0.9061925583535467),
#  ('macha', 0.9061925583535467),
#  ('krispie', 0.9061925583535467),
#  ('portobello', 0.9061925583535467),
#  ('argan', 0.9061925583535467),
#  ('polkane', 0.9061925583535467),
#  ('christina', 0.9061925583535467),
#  ('pao', 0.9061925583535467),
#  ('dudhi', 0.9061925583535467),
#  ('spare', 0.9061925583535467),
#  ('fatima', 0.9061925583535467),
#  ('jewel', 0.9061925583535467),
#  ('po', 0.9061925583535467),
#  ('hungarian', 0.9061925583535467),
#  ('maque', 0.9061925583535467),
#  ('goop', 0.9061925583535467),
#  ('kombu', 0.9061925583535467),
#  ('silog', 0.9061925583535467),
#  ('moorish', 0.9061925583535467),
#  ('nutella', 0.9061925583535467),
#  ('marble', 0.9061925583535467),
#  ('kao', 0.9061925583535467),
#  ('chiller', 0.9061925583535467),
#  ('khatti', 0.9061925583535467),
#  ('jajangmyeon', 0.9061925583535467),
#  ('ruth', 0.9061925583535467),
#  ('scrapple', 0.9061925583535467),
#  ('piece', 0.9061925583535467),
#  ('surnoli', 0.9061925583535467),
#  ('excellent', 0.9061925583535467),
#  ('loco', 0.9061925583535467),
#  ('s’mor', 0.9061925583535467),
#  ('rutabaga', 0.9061925583535467),
#  ('makroud', 0.9061925583535467),
#  ('hanger', 0.9061925583535467),
#  ('fluffy', 0.9061925583535467),
#  ('khao', 0.9061925583535467),
#  ('maharashtrian', 0.9061925583535467),
#  ('drunkard', 0.9061925583535467),
#  ('moco', 0.9061925583535467),
#  ('satay', 0.9061925583535467),
#  ('chadburn', 0.9061925583535467),
#  ('blotkake', 0.9061925583535467),
#  ('flank', 0.9061925583535467),
#  ('yassa', 0.9061925583535467),
#  ('deathbed', 0.9061925583535467),
#  ('pav', 0.9061925583535467),
#  ('copper', 0.9061925583535467),
#  ('ji', 0.9061925583535467),
#  ('massaman', 0.9061925583535467),
#  ('kringle', 0.9061925583535467),
#  ('baingan', 0.9061925583535467),
#  ('finnish', 0.9061925583535467),
#  ('monsieur', 0.9061925583535467),
#  ('maracujá', 0.9061925583535467),
#  ('albóndigas', 0.9061925583535467),
#  ('ara', 0.9061925583535467),
#  ('anselm', 0.9061925583535467),
#  ('base', 0.9061925583535467),
#  ('serve', 0.9061925583535467),
#  ('ssamjang', 0.9061925583535467),
#  ('karaage', 0.9061925583535467),
#  ('mocha', 0.9061925583535467),
#  ('tetrazzini', 0.9061925583535467),
#  ('chia', 0.9061925583535467),
#  ('seeded', 0.9061925583535467),
#  ('alkaline', 0.9061925583535467),
#  ('nage', 0.9061925583535467),
#  ('chilean', 0.9061925583535467),
#  ('turlu', 0.9061925583535467),
#  ('machuca', 0.9061925583535467),
#  ('norteño', 0.9061925583535467),
#  ('atlantic', 0.9061925583535467),
#  ('shoofly', 0.9061925583535467),
#  ('air', 0.9061925583535467),
#  ('day', 0.9061925583535467),
#  ('xo', 0.9061925583535467),
#  ('barszcz', 0.9061925583535467),
#  ('stingray', 0.9061925583535467),
#  ('sooji', 0.9061925583535467),
#  ('donald', 0.9061925583535467),
#  ('rocky', 0.9061925583535467),
#  ('luc', 0.9061925583535467),
#  ('lucky', 0.9061925583535467),
#  ('tambo', 0.9061925583535467),
#  ('buffett', 0.9061925583535467),
#  ('7up', 0.9061925583535467),
#  ('enoki', 0.9061925583535467),
#  ('babi', 0.9061925583535467),
#  ('ganache', 0.9061925583535467),
#  ('doro', 0.9061925583535467),
#  ('head', 0.9061925583535467),
#  ('pasty', 0.9061925583535467),
#  ('pocky', 0.9061925583535467),
#  ('15-grain', 0.9061925583535467),
#  ('masoor', 0.9061925583535467),
#  ('hudutu', 0.9061925583535467),
#  ('cowboy', 0.9061925583535467),
#  ('crop', 0.9061925583535467),
#  ('america', 0.9061925583535467),
#  ('puebla', 0.9061925583535467),
#  ('kentucky', 0.9061925583535467),
#  ('harbin', 0.9061925583535467),
#  ('fingerling', 0.9061925583535467),
#  ('smart', 0.9061925583535467),
#  ('auntie', 0.9061925583535467),
#  ('paloma', 0.9061925583535467),
#  ('seekh', 0.9061925583535467),
#  ('yen', 0.9061925583535467),
#  ('prietoni', 0.9061925583535467),
#  ('toll', 0.9061925583535467),
#  ('raan', 0.9061925583535467),
#  ('makhani', 0.9061925583535467),
#  ('palak', 0.9061925583535467),
#  ('iceberg', 0.9061925583535467),
#  ('jus', 0.9061925583535467),
#  ('matador', 0.9061925583535467),
#  ('nogada', 0.9061925583535467),
#  ('canapés', 0.9061925583535467),
#  ('suya', 0.9061925583535467),
#  ('cosmopolitan', 0.9061925583535467),
#  ('kling', 0.9061925583535467),
#  ('hainanese', 0.9061925583535467),
#  ('spumoni', 0.9061925583535467),
#  ('crudités', 0.9061925583535467),
#  ('clear', 0.9061925583535467),
#  ('victorian', 0.9061925583535467),
#  ('jumble', 0.9061925583535467),
#  ('tone', 0.9061925583535467),
#  ('pibil', 0.9061925583535467),
#  ('frank', 0.9061925583535467),
#  ('window', 0.9061925583535467),
#  ('carnita', 0.9061925583535467),
#  ('gyudon', 0.9061925583535467),
#  ('helva', 0.9061925583535467),
#  ('shawarma', 0.9061925583535467),
#  ('flip', 0.9061925583535467),
#  ('l.', 0.9061925583535467),
#  ('danish', 0.9061925583535467),
#  ('restaurant', 0.9061925583535467),
#  ('jour', 0.9061925583535467),
#  ('helen', 0.9061925583535467),
#  ('tamagoyaki', 0.9061925583535467),
#  ('popover', 0.9061925583535467),
#  ('rancho', 0.9061925583535467),
#  ('frejon', 0.9061925583535467),
#  ('baja', 0.9061925583535467),
#  ('gajjara', 0.9061925583535467),
#  ('cochinita', 0.9061925583535467),
#  ('blistered', 0.9061925583535467),
#  ('china', 0.9061925583535467),
#  ('manchurian', 0.9061925583535467),
#  ('starter', 0.9061925583535467),
#  ('zuni', 0.9061925583535467),
#  ('ca', 0.9061925583535467),
#  ('relleno', 0.9061925583535467),
#  ('belgian', 0.9061925583535467),
#  ('s’more', 0.9061925583535467),
#  ('tiger', 0.9061925583535467),
#  ('sofrito', 0.9061925583535467),
#  ('seelbach', 0.9061925583535467),
#  ('pastor', 0.9061925583535467),
#  ('real', 0.9061925583535467),
#  ('saratoga', 0.9061925583535467),
#  ('nem', 0.9061925583535467),
#  ('twinkie', 0.9061925583535467),
#  ('iskukaris', 0.9061925583535467),
#  ...]

# %%
sorted(lor.items(), key=lambda x: x[1], reverse=False)
# Out:
# [('matzo', -3.6908227608807125),
#  ('provençal', -3.4898138276341766),
#  ('gazpacho', -3.329245749244246),
#  ('quiche', -3.329245749244246),
#  ('sicilian', -3.2381612759350022),
#  ('kugel', -3.1379651349732582),
#  ('tart', -1.1417630415454518),
#  ('beet', -1.136803570353545),
#  ('for', -1.080438090764135),
#  ('pistachio', -1.080438090764135),
#  ('pizza', -1.0743820037103915),
#  ('french', -1.0626830294939535),
#  ('bed', -1.0400553334575806),
#  ('gingerbread', -1.0400553334575806),
#  ('venison', -1.0400553334575806),
#  ('fajita', -1.0400553334575806),
#  ('whip', -1.0400553334575806),
#  ('texas', -1.0400553334575806),
#  ('root', -1.0400553334575806),
#  ('crostini', -1.0400553334575806),
#  ('hole', -1.0400553334575806),
#  ('ring', -1.0400553334575806),
#  ('caramelized', -1.0400553334575806),
#  ('potpie', -1.0400553334575806),
#  ('rustic', -1.0400553334575806),
#  ('choux', -1.0400553334575806),
#  ('bass', -1.0400553334575806),
#  ('herbed', -1.0400553334575806),
#  ('mini', -1.0400553334575806),
#  ('ragoût', -1.0400553334575806),
#  ('recipe', -1.0400553334575806),
#  ('english', -1.0400553334575806),
#  ('master', -1.0400553334575806),
#  ('calamari', -1.0400553334575806),
#  ('.', -1.0400553334575806),
#  ('linguine', -1.0400553334575806),
#  ('crêpe', -1.0400553334575806),
#  ('fresh', -0.9998010936551086),
#  ('biscuit', -0.9958789090681086),
#  ('millet', -0.9813471952164526),
#  ('custard', -0.9813471952164526),
#  ('torte', -0.9813471952164526),
#  ('rabe', -0.9813471952164526),
#  ('free', -0.9813471952164526),
#  ('sea', -0.9813471952164526),
#  ('lobster', -0.9813471952164526),
#  ('radicchio', -0.9813471952164526),
#  ('olive', -0.9762750121164618),
#  ('walnut', -0.9562031340032374),
#  ('yellow', -0.9551622907942944),
#  ('plum', -0.9551622907942944),
#  ('savory', -0.9551622907942944),
#  ('rise', -0.9551622907942944),
#  ('tomato', -0.9482689565348658),
#  ('omelet', -0.9403690866075072),
#  ('chorizo', -0.9403690866075072),
#  ('artichoke', -0.9194892792707822),
#  ("'s", -0.8628870537095952),
#  ('caramelize', -0.8568663367234272),
#  ('a', -0.852685158844937),
#  ('pear', -0.839801642784661),
#  ('e', -0.8290307817884148),
#  ('horseradish', -0.8290307817884148),
#  ('poach', -0.8290307817884148),
#  ('fruit', -0.8119488028279599),
#  ('eyed', -0.8119488028279599),
#  ('stewed', -0.8119488028279599),
#  ('zucchini', -0.8045010491433585),
#  ('leek', -0.7942332211018427),
#  ('bun', -0.7805638808004122),
#  ('two', -0.7805638808004122),
#  ('pomegranate', -0.7805638808004122),
#  ('norma', -0.7805638808004122),
#  ('drop', -0.7805638808004122),
#  ('easy', -0.7805638808004122),
#  ('punch', -0.7805638808004122),
#  ('prune', -0.7805638808004122),
#  ('eggplant', -0.7651261729508657),
#  ('parsley', -0.7637391334790715),
#  ('feta', -0.760007293331578),
#  ('mussel', -0.7396055018229167),
#  ('goat', -0.7216991042860977),
#  ('cod', -0.703754981818574),
#  ('dill', -0.703754981818574),
#  ('buttered', -0.703470503242824),
#  ('tatin', -0.703470503242824),
#  ('easter', -0.703470503242824),
#  ('scent', -0.703470503242824),
#  ('sear', -0.703470503242824),
#  ('chestnut', -0.703470503242824),
#  ('schmaltz', -0.703470503242824),
#  ('aunt', -0.703470503242824),
#  ('upside', -0.703470503242824),
#  ('marjoram', -0.703470503242824),
#  ('wellington', -0.703470503242824),
#  ('crush', -0.703470503242824),
#  ('ziti', -0.703470503242824),
#  ('caprese', -0.703470503242824),
#  ('loin', -0.703470503242824),
#  ('waffle', -0.703470503242824),
#  ('cooked', -0.703470503242824),
#  ('middle', -0.703470503242824),
#  ('challah', -0.703470503242824),
#  ('german', -0.703470503242824),
#  (' ', -0.703470503242824),
#  ('macaron', -0.703470503242824),
#  ('stalk', -0.703470503242824),
#  ('shave', -0.703470503242824),
#  ('pâté', -0.703470503242824),
#  ('  ', -0.703470503242824),
#  ('claiborne', -0.703470503242824),
#  ('empanada', -0.703470503242824),
#  ('swedish', -0.703470503242824),
#  ('gorgonzola', -0.703470503242824),
#  ('carpaccio', -0.703470503242824),
#  ('gougère', -0.703470503242824),
#  ('craig', -0.703470503242824),
#  ('crowd', -0.703470503242824),
#  ('flaky', -0.703470503242824),
#  ('tomate', -0.703470503242824),
#  ('curried', -0.703470503242824),
#  ('farmer', -0.703470503242824),
#  ('down', -0.703470503242824),
#  ('onion', -0.6959880300534665),
#  ('of', -0.6829146621426457),
#  ('chard', -0.6689425740039849),
#  ('quinoa', -0.6558574034768909),
#  ('lettuce', -0.6447820865264475),
#  ('ragout', -0.6447820865264475),
#  ('basic', -0.6447820865264475),
#  ('crunchy', -0.6447820865264475),
#  ('endive', -0.6447820865264475),
#  ('shell', -0.6447820865264475),
#  ('chickpea', -0.6132599387741661),
#  ('wild', -0.5724585192080837),
#  ('whole', -0.5611705460490146),
#  ('apricot', -0.5605414938522394),
#  ('dough', -0.5605414938522394),
#  ('con', -0.5605414938522394),
#  ('crumb', -0.5605414938522394),
#  ('lentil', -0.5297853800743939),
#  ('clam', -0.5294609099466563),
#  ('carne', -0.529136846247218),
#  ('lemony', -0.529136846247218),
#  ('filling', -0.529136846247218),
#  ('cure', -0.529136846247218),
#  ('beer', -0.529136846247218),
#  ('chowder', -0.529136846247218),
#  ('crouton', -0.529136846247218),
#  ('pepe', -0.529136846247218),
#  ('bitter', -0.529136846247218),
#  ('layer', -0.529136846247218),
#  ('marinate', -0.529136846247218),
#  ('balsamic', -0.529136846247218),
#  ('mousse', -0.529136846247218),
#  ('toffee', -0.529136846247218),
#  ('seafood', -0.529136846247218),
#  ('gravy', -0.5029913970339835),
#  ('saffron', -0.5029913970339835),
#  ('arugula', -0.49528932508696066),
#  ('classic', -0.4729574949339269),
#  ('tuna', -0.46746508287194977),
#  ('sauce', -0.4658819818132861),
#  ('basil', -0.4443624534760946),
#  ('veal', -0.44399877211040706),
#  ('-PRON-', -0.44399877211040706),
#  ('good', -0.44399877211040706),
#  ('smash', -0.44399877211040706),
#  ('garlicky', -0.44399877211040706),
#  ('duck', -0.42926476898491217),
#  ('chop', -0.4042048517777171),
#  ('asparagus', -0.39377810915795464),
#  ('country', -0.3933747775507272),
#  ('orange', -0.38906388812959136),
#  ('white', -0.3700777345559096),
#  ('crust', -0.35977790906764906),
#  ('oyster', -0.35977790906764906),
#  ('summer', -0.34139487264783597),
#  ('kale', -0.34139487264783597),
#  ('ham', -0.3358444144191505),
#  ('pepper', -0.33537465491600793),
#  ('roasted', -0.324107561126551),
#  ('ball', -0.3179264641658198),
#  ('mint', -0.31439509932609083),
#  ('vinaigrette', -0.3040087108159727),
#  ('or', -0.30128743052245094),
#  ('herb', -0.278330734476562),
#  ('and', -0.2742498519288385),
#  ('stuff', -0.27168420224711837),
#  ('lemon', -0.2568450726142414),
#  ('almond', -0.24853090024033814),
#  ('sausage', -0.24064849580666542),
#  ('garlic', -0.22356375450896684),
#  (',', -0.21477277016978769),
#  ('’s', -0.19360287100609494),
#  ('spinach', -0.19320497304553136),
#  ('cherry', -0.19274941380298508),
#  ('smoked', -0.19265066419597887),
#  ('cook', -0.19261119276613675),
#  ('smoky', -0.19261119276613675),
#  ('’', -0.19261119276613675),
#  ('puff', -0.1925914631346868),
#  ('raspberry', -0.1925914631346868),
#  ('southern', -0.1925914631346868),
#  ('fritter', -0.19257173755721288),
#  ('rum', -0.19257173755721288),
#  ('giant', -0.19257173755721288),
#  ('caesar', -0.19257173755721288),
#  ('scramble', -0.19257173755721288),
#  ('pull', -0.19257173755721288),
#  ('enchilada', -0.19257173755721288),
#  ('rye', -0.19257173755721288),
#  ('carbonara', -0.19257173755721288),
#  ('boil', -0.19257173755721288),
#  ('cacio', -0.19255201603246153),
#  ('strip', -0.19255201603246153),
#  ('pilaf', -0.19255201603246153),
#  ('turmeric', -0.19255201603246153),
#  ('panzanella', -0.19255201603246153),
#  ('pudde', -0.19255201603246153),
#  ('pico', -0.19255201603246153),
#  ('long', -0.19255201603246153),
#  ('butterscotch', -0.19255201603246153),
#  ('gruyère', -0.19255201603246153),
#  ('puréed', -0.19255201603246153),
#  ('skewer', -0.19255201603246153),
#  ('coriander', -0.19255201603246153),
#  ('pimento', -0.19255201603246153),
#  ('sous', -0.19255201603246153),
#  ('molasse', -0.19255201603246153),
#  ('south', -0.19255201603246153),
#  ('rugelach', -0.19255201603246153),
#  ('brûlée', -0.19255201603246153),
#  ('swordfish', -0.19255201603246153),
#  ('shortbread', -0.19255201603246153),
#  ('garden', -0.19255201603246153),
#  ('crepe', -0.19255201603246153),
#  ('seven', -0.19253229855918003),
#  ('lech', -0.19253229855918003),
#  ('foil', -0.19253229855918003),
#  ('chouriço', -0.19253229855918003),
#  ('norwegian', -0.19253229855918003),
#  ...]

# %%
lor_desc = compute_lor(Counter(recipe_words['non_west']['description']), 
                  Counter(recipe_words['west']['description']))
len(lor_desc)
# Out:
# 11982

# %%
sorted(lor_desc.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('mango', 4.334354845285789),
#  ('filipino', 3.8661244400967356),
#  ('dal', 3.8661244400967356),
#  ('tamarind', 3.668736750632716),
#  ('chaat', 3.511532330683479),
#  ('ghee', 3.3249275390310467),
#  ('dosa', 3.2722790965830564),
#  ('soba', 3.2722790965830564),
#  ('pho', 3.2722790965830564),
#  ('nigerian', 3.2722790965830564),
#  ('choy', 3.216704536487851),
#  ('soy', 3.1702099988714756),
#  ('bok', 3.157859327546698),
#  ('haitian', 3.095334261669317),
#  ('thai', 3.04260167041034),
#  ('dashi', 3.0286381782967724),
#  ('charcoal', 2.9571745054629277),
#  ('indian', 2.9373543593457874),
#  ('mochi', 2.8802087554972733),
#  ('hash', 2.8802087554972733),
#  ('raman', 2.8802087554972733),
#  ('kombu', 2.8802087554972733),
#  ('understand', 2.796822437750869),
#  ('philippine', 2.796822437750869),
#  ('ramadan', 2.796822437750869),
#  ('din', 2.796822437750869),
#  ('cashews', 2.796822437750869),
#  ('jamaica', 2.796822437750869),
#  ('mirin', 2.796822437750869),
#  ('thailand', 2.796822437750869),
#  ('roti', 2.796822437750869),
#  ('habanero', 2.705845950759962),
#  ('indonesian', 2.705845950759962),
#  ('crisps', 2.705845950759962),
#  ('komolafe', 2.705845950759962),
#  ('yewande', 2.705845950759962),
#  ('francisco', 2.705845950759962),
#  ('tartness', 2.705845950759962),
#  ('coleslaw', 2.705845950759962),
#  ('pozole', 2.705845950759962),
#  ('tejal', 2.705845950759962),
#  ('bonito', 2.705845950759962),
#  ('china', 2.6058406468762043),
#  ('angela', 2.605757783439971),
#  ('jaffrey', 2.605757783439971),
#  ('cupcake', 2.605757783439971),
#  ('palm', 2.605757783439971),
#  ('dimayuga', 2.605757783439971),
#  ('count', 2.605757783439971),
#  ('teriyaki', 2.605757783439971),
#  ('cashew', 2.605757783439971),
#  ('asada', 2.605757783439971),
#  ('ina', 2.605757783439971),
#  ('tostada', 2.605757783439971),
#  ('miso', 2.4946743354683516),
#  ('cob', 2.494527439588911),
#  ('jamaican', 2.494527439588911),
#  ('salsas', 2.494527439588911),
#  ('nuoc', 2.494527439588911),
#  ('shaved', 2.494527439588911),
#  ('choi', 2.494527439588911),
#  ('pad', 2.494527439588911),
#  ('western', 2.494527439588911),
#  ('suvir', 2.494527439588911),
#  ('ton', 2.494527439588911),
#  ('grass', 2.494527439588911),
#  ('thiam', 2.494527439588911),
#  ('sodha', 2.494527439588911),
#  ('mapo', 2.494527439588911),
#  ('sake', 2.494527439588911),
#  ('bo', 2.494527439588911),
#  ('native', 2.4545908406367527),
#  ('america', 2.3695516815206408),
#  ('tamale', 2.369423614171736),
#  ('guacamole', 2.369423614171736),
#  ('—hannah', 2.3693595879162417),
#  ('truck', 2.3693595879162417),
#  ('saran', 2.3693595879162417),
#  ('julie', 2.3693595879162417),
#  ('reinhart', 2.3693595879162417),
#  ('jollof', 2.3693595879162417),
#  ('congee', 2.3693595879162417),
#  ('your', 2.3693595879162417),
#  ('sahni', 2.3693595879162417),
#  ('papaya', 2.3693595879162417),
#  ('popover', 2.3693595879162417),
#  ('naan', 2.3693595879162417),
#  ('sherbet', 2.3693595879162417),
#  ('reflect', 2.3693595879162417),
#  ('aisle', 2.3693595879162417),
#  ('margarita', 2.3693595879162417),
#  ('cham', 2.3693595879162417),
#  ('alaska', 2.3693595879162417),
#  ('shre', 2.3693595879162417),
#  ('kirshner', 2.3693595879162417),
#  ('madhur', 2.3693595879162417),
#  ('tanginess', 2.3693595879162417),
#  ('tequila', 2.3693595879162417),
#  ('adam', 2.3693595879162417),
#  ('warming', 2.3693595879162417),
#  ('tomatillo', 2.286091908415229),
#  ('indirect', 2.226254035579077),
#  ('cantonese', 2.226254035579077),
#  ('sharma', 2.226254035579077),
#  ('paratha', 2.226254035579077),
#  ('hong', 2.226254035579077),
#  ('independence', 2.226254035579077),
#  ('buckle', 2.226254035579077),
#  ('hakka', 2.226254035579077),
#  ('jerk', 2.226254035579077),
#  ('bronx', 2.226254035579077),
#  ('kong', 2.226254035579077),
#  ('joanna', 2.226254035579077),
#  ('global', 2.226254035579077),
#  ('blt', 2.226254035579077),
#  ('quarantine', 2.226254035579077),
#  ('prove', 2.226254035579077),
#  ('peter', 2.226254035579077),
#  ('meera', 2.226254035579077),
#  ('jaggery', 2.226254035579077),
#  ('chain', 2.226254035579077),
#  ('snow', 2.226254035579077),
#  ('taqueria', 2.226254035579077),
#  ('katsu', 2.226254035579077),
#  ('cortland', 2.226254035579077),
#  ('zip', 2.226254035579077),
#  ('doneness', 2.226254035579077),
#  ('brazilian', 2.226254035579077),
#  ('honest', 2.226254035579077),
#  ('samuel', 2.226254035579077),
#  ('freshen', 2.226254035579077),
#  ('helpful', 2.226254035579077),
#  ('patel', 2.226254035579077),
#  ('waldorf', 2.226254035579077),
#  ('appetite', 2.226254035579077),
#  ('gaine', 2.226254035579077),
#  ('fermented', 2.226254035579077),
#  ('matcha', 2.226254035579077),
#  ('bobby', 2.226254035579077),
#  ('paneer', 2.226254035579077),
#  ('indonesia', 2.226254035579077),
#  ('chewiness', 2.226254035579077),
#  ('gado', 2.226254035579077),
#  ('seriously', 2.226254035579077),
#  ('vessel', 2.226254035579077),
#  ('seaweed', 2.173660201062319),
#  ('basmati', 2.1180856409671143),
#  ('wrapper', 2.1180856409671143),
#  ('tofu', 2.1014666187819433),
#  ('ranch', 2.0950084162139353),
#  ('kimchi', 2.0592404320259607),
#  ('mainstream', 2.0591952422415907),
#  ('exception', 2.0591952422415907),
#  ('massage', 2.0591952422415907),
#  ('sqirl', 2.0591952422415907),
#  ('notion', 2.0591952422415907),
#  ('escape', 2.0591952422415907),
#  ('fenugreek', 2.0591952422415907),
#  ('flay', 2.0591952422415907),
#  ('rendang', 2.0591952422415907),
#  ('necessarily', 2.0591952422415907),
#  ('pectin', 2.0591952422415907),
#  ('tepary', 2.0591952422415907),
#  ('puréee', 2.0591952422415907),
#  ('xo', 2.0591952422415907),
#  ('eddie', 2.0591952422415907),
#  ('charred', 2.0591952422415907),
#  ('fresca', 2.0591952422415907),
#  ('soybean', 2.0591952422415907),
#  ('refrigerated', 2.0591952422415907),
#  ('o', 2.0591952422415907),
#  ('lassi', 2.0591952422415907),
#  ('celebratory', 2.0591952422415907),
#  ('ata', 2.0591952422415907),
#  ('broccolini', 2.0591952422415907),
#  ('ranchera', 2.0591952422415907),
#  ('mumbai', 2.0591952422415907),
#  ('individually', 2.0591952422415907),
#  ('chopstick', 2.0591952422415907),
#  ('galangal', 2.0591952422415907),
#  ('kulfi', 2.0591952422415907),
#  ('negroni', 2.0591952422415907),
#  ('eid', 2.0591952422415907),
#  ('hazel', 2.0591952422415907),
#  ('tostone', 2.0591952422415907),
#  ('biryani', 2.0591952422415907),
#  ('hernandez', 2.0591952422415907),
#  ('punchy', 2.0591952422415907),
#  ('lahlou', 2.0591952422415907),
#  ('kentucky', 2.0591952422415907),
#  ('kefir', 2.0591952422415907),
#  ('gala', 2.0591952422415907),
#  ('nuttiness', 2.0591952422415907),
#  ('iced', 2.0591952422415907),
#  ('junk', 2.0591952422415907),
#  ('raghavan', 2.0591952422415907),
#  ('index', 2.0591952422415907),
#  ('spit', 2.0591952422415907),
#  ('chad', 2.0591952422415907),
#  ('tarka', 2.0591952422415907),
#  ('wu', 2.0591952422415907),
#  ('tiki', 2.0591952422415907),
#  ('chilaquile', 2.0591952422415907),
#  ('cone', 2.0591952422415907),
#  ('sky', 2.0591952422415907),
#  ('whelk', 2.0591952422415907),
#  ('gomez', 2.0591952422415907),
#  ('gyoza', 2.0591952422415907),
#  ('ruth', 2.0591952422415907),
#  ('basting', 2.0591952422415907),
#  ('zuni', 2.0591952422415907),
#  ('lugaw', 2.0591952422415907),
#  ('bangkok', 2.0591952422415907),
#  ('kerala', 2.0591952422415907),
#  ('heatter', 2.0591952422415907),
#  ('mala', 2.0591952422415907),
#  ('parm', 2.0591952422415907),
#  ('weave', 2.0591952422415907),
#  ('freedom', 2.0591952422415907),
#  ('credit', 2.0591952422415907),
#  ('sambhar', 2.0591952422415907),
#  ('grownup', 2.0591952422415907),
#  ('phosphate', 2.0591952422415907),
#  ('usha', 2.0591952422415907),
#  ('globe', 2.0591952422415907),
#  ('nomad', 2.0591952422415907),
#  ('weary', 2.0591952422415907),
#  ('fix', 2.0591952422415907),
#  ('endlessly', 2.0591952422415907),
#  ('garten', 2.0591952422415907),
#  ('springy', 2.0591952422415907),
#  ('jersey', 2.0591952422415907),
#  ('booklet', 2.0591952422415907),
#  ('soul', 2.022239643629391),
#  ('japan', 2.022239643629391),
#  ('roux', 2.022239643629391),
#  ('india', 1.9968415314179881),
#  ('delightfully', 1.99671536614858),
#  ('krishna', 1.99671536614858),
#  ('marshmallow', 1.99671536614858),
#  ('—priya', 1.99671536614858),
#  ('nachos', 1.99671536614858),
#  ('burger', 1.937567089742342),
#  ('masa', 1.930019282776035),
#  ('takeout', 1.930019282776035),
#  ('sichuan', 1.902081204500473),
#  ('masala', 1.902081204500473),
#  ('mexican', 1.893342155043578),
#  ('vietnamese', 1.889884411584228),
#  ('blueberry', 1.8586271588292713),
#  ('blini', 1.8585556099421907),
#  ('wafer', 1.8585556099421907),
#  ('microwave', 1.8585556099421907),
#  ('1/4', 1.8585556099421907),
#  ('sonora', 1.8585198381272914),
#  ('lin', 1.8585198381272914),
#  ('alton', 1.8585198381272914),
#  ('alford', 1.8585198381272914),
#  ('chauhan', 1.8585198381272914),
#  ('peartree', 1.8585198381272914),
#  ('chinese', 1.8231096337445885),
#  ('shiitake', 1.813124300403617),
#  ('wok', 1.7930204579082838),
#  ('chutney', 1.7816877665473367),
#  ('smoothy', 1.781589859976536),
#  ('soupy', 1.781589859976536),
#  ('nation', 1.781589859976536),
#  ('coconut', 1.7768690758392418),
#  ('peanut', 1.7605657251852975),
#  ('american', 1.748375742738319),
#  ('lisa', 1.6982035422301318),
#  ('potter', 1.6982035422301318),
#  ('asia', 1.6982035422301318),
#  ('jasmine', 1.6982035422301318),
#  ('lemongrass', 1.6982035422301318),
#  ('garam', 1.6982035422301318),
#  ('teacher', 1.6982035422301318),
#  ('moroccan', 1.6688734350880987),
#  ('steamed', 1.6628279704000501),
#  ('plantain', 1.6472898101226583),
#  ('flatbread', 1.6472898101226583),
#  ('curry', 1.6284959800363574),
#  ('turkey', 1.6251890978980392),
#  ('douse', 1.6072270552392245),
#  ('dab', 1.6072270552392245),
#  ('—sara', 1.6072270552392245),
#  ('bonisteel', 1.6072270552392245),
#  ('clarkson', 1.6072270552392245),
#  ('carve', 1.6072270552392245),
#  ('offset', 1.6072270552392245),
#  ('—mayukh', 1.6072007012164082),
#  ('chapli', 1.6072007012164082),
#  ('sasaki', 1.6072007012164082),
#  ('coolness', 1.6072007012164082),
#  ('jok', 1.6072007012164082),
#  ('resolution', 1.6072007012164082),
#  ('unbelievably', 1.6072007012164082),
#  ('award', 1.6072007012164082),
#  ('geechee', 1.6072007012164082),
#  ('urad', 1.6072007012164082),
#  ('raicilla', 1.6072007012164082),
#  ('oversize', 1.6072007012164082),
#  ('kogi', 1.6072007012164082),
#  ('happiness', 1.6072007012164082),
#  ('response', 1.6072007012164082),
#  ('—kayla', 1.6072007012164082),
#  ('creamsicle', 1.6072007012164082),
#  ('sekihan', 1.6072007012164082),
#  ('visual', 1.6072007012164082),
#  ('bruce', 1.6072007012164082),
#  ('uniquely', 1.6072007012164082),
#  ('brigadeiro', 1.6072007012164082),
#  ('goddess', 1.6072007012164082),
#  ('stewart', 1.6072007012164082),
#  ('honeycrisp', 1.6072007012164082),
#  ('spiced', 1.6072007012164082),
#  ('ana', 1.6072007012164082),
#  ('forbid', 1.6072007012164082),
#  ('official', 1.6072007012164082),
#  ('ghillie', 1.6072007012164082),
#  ('aggressive', 1.6072007012164082),
#  ('goldfarb', 1.6072007012164082),
#  ('scandinavian', 1.6072007012164082),
#  ('macoun', 1.6072007012164082),
#  ('cassava', 1.6072007012164082),
#  ('shulman', 1.6072007012164082),
#  ('dehydrate', 1.6072007012164082),
#  ('350', 1.6072007012164082),
#  ('1990', 1.6072007012164082),
#  ('reduction', 1.6072007012164082),
#  ('ombré', 1.6072007012164082),
#  ('suited', 1.6072007012164082),
#  ('mourad', 1.6072007012164082),
#  ('nyt', 1.6072007012164082),
#  ('similien', 1.6072007012164082),
#  ('user', 1.6072007012164082),
#  ('ambitious', 1.6072007012164082),
#  ('hijiki', 1.6072007012164082),
#  ('pump', 1.6072007012164082),
#  ('ripple', 1.6072007012164082),
#  ('savoriness', 1.6072007012164082),
#  ('kenji', 1.6072007012164082),
#  ('kombucha', 1.6072007012164082),
#  ('huli', 1.6072007012164082),
#  ('asafetida', 1.6072007012164082),
#  ('sandy', 1.6072007012164082),
#  ('farmhouse', 1.6072007012164082),
#  ('prospect', 1.6072007012164082),
#  ('tod', 1.6072007012164082),
#  ('gimlet', 1.6072007012164082),
#  ('isa', 1.6072007012164082),
#  ('laos', 1.6072007012164082),
#  ('horowitz', 1.6072007012164082),
#  ('ganaway', 1.6072007012164082),
#  ('grinding', 1.6072007012164082),
#  ('application', 1.6072007012164082),
#  ('tired', 1.6072007012164082),
#  ('pakistani', 1.6072007012164082),
#  ('mofongo', 1.6072007012164082),
#  ('koji', 1.6072007012164082),
#  ('exuberant', 1.6072007012164082),
#  ('record', 1.6072007012164082),
#  ('alternate', 1.6072007012164082),
#  ('manila', 1.6072007012164082),
#  ('velasco', 1.6072007012164082),
#  ('rapidly', 1.6072007012164082),
#  ('detroit', 1.6072007012164082),
#  ('assure', 1.6072007012164082),
#  ('yassa', 1.6072007012164082),
#  ('reserved', 1.6072007012164082),
#  ('zealand', 1.6072007012164082),
#  ('meanwhile', 1.6072007012164082),
#  ('argentina', 1.6072007012164082),
#  ('sakai', 1.6072007012164082),
#  ('nik', 1.6072007012164082),
#  ('helen', 1.6072007012164082),
#  ('profile', 1.6072007012164082),
#  ('tandoor', 1.6072007012164082),
#  ('mun', 1.6072007012164082),
#  ('indiana', 1.6072007012164082),
#  ('pulse', 1.6072007012164082),
#  ('asha', 1.6072007012164082),
#  ('exquisitely', 1.6072007012164082),
#  ('belt', 1.6072007012164082),
#  ('leela', 1.6072007012164082),
#  ('vast', 1.6072007012164082),
#  ('conte', 1.6072007012164082),
#  ('doenjang', 1.6072007012164082),
#  ('wallop', 1.6072007012164082),
#  ('rewarding', 1.6072007012164082),
#  ('sen', 1.6072007012164082),
#  ('burfi', 1.6072007012164082),
#  ('wealth', 1.6072007012164082),
#  ('flush', 1.6072007012164082),
#  ('eric', 1.6072007012164082),
#  ('division', 1.6072007012164082),
#  ('ambrosia', 1.6072007012164082),
#  ('tangerine', 1.6072007012164082),
#  ('social', 1.6072007012164082),
#  ('fragile', 1.6072007012164082),
#  ('plop', 1.6072007012164082),
#  ('$', 1.6072007012164082),
#  ('niven', 1.6072007012164082),
#  ('cheeseburger', 1.6072007012164082),
#  ('ultimately', 1.6072007012164082),
#  ('soothe', 1.6072007012164082),
#  ('vivian', 1.6072007012164082),
#  ('hydrate', 1.6072007012164082),
#  ('superiority', 1.6072007012164082),
#  ('medley', 1.6072007012164082),
#  ('karnataka', 1.6072007012164082),
#  ('samuelsson', 1.6072007012164082),
#  ('deceptively', 1.6072007012164082),
#  ('t.', 1.6072007012164082),
#  ('fuji', 1.6072007012164082),
#  ('gingery', 1.6072007012164082),
#  ('doubanjiang', 1.6072007012164082),
#  ('lumpia', 1.6072007012164082),
#  ('chapter', 1.6072007012164082),
#  ('singular', 1.6072007012164082),
#  ('cotton', 1.6072007012164082),
#  ('djan', 1.6072007012164082),
#  ('fitr', 1.6072007012164082),
#  ('calabaza', 1.6072007012164082),
#  ('pole', 1.6072007012164082),
#  ('harvey', 1.6072007012164082),
#  ('wakefield', 1.6072007012164082),
#  ('scoby', 1.6072007012164082),
#  ('doro', 1.6072007012164082),
#  ('restorative', 1.6072007012164082),
#  ('packer', 1.6072007012164082),
#  ('fingerling', 1.6072007012164082),
#  ('serf', 1.6072007012164082),
#  ('malaysia', 1.6072007012164082),
#  ('campari', 1.6072007012164082),
#  ('amanda', 1.6072007012164082),
#  ('boring', 1.6072007012164082),
#  ('noticeable', 1.6072007012164082),
#  ('courtesy', 1.6072007012164082),
#  ('foster', 1.6072007012164082),
#  ('jiggly', 1.6072007012164082),
#  ('300', 1.6072007012164082),
#  ('leiber', 1.6072007012164082),
#  ('alt', 1.6072007012164082),
#  ('anymore', 1.6072007012164082),
#  ('understanding', 1.6072007012164082),
#  ('invention', 1.6072007012164082),
#  ('linda', 1.6072007012164082),
#  ('anusasananan', 1.6072007012164082),
#  ('nam', 1.6072007012164082),
#  ('related', 1.6072007012164082),
#  ('lunchbox', 1.6072007012164082),
#  ('bran', 1.6072007012164082),
#  ('tadka', 1.6072007012164082),
#  ('parathas', 1.6072007012164082),
#  ('connect', 1.6072007012164082),
#  ('entry', 1.6072007012164082),
#  ('adda', 1.6072007012164082),
#  ('carolyn', 1.6072007012164082),
#  ('dan', 1.6072007012164082),
#  ('brining', 1.6072007012164082),
#  ('margarine', 1.6072007012164082),
#  ('lo', 1.6072007012164082),
#  ('rockwell', 1.6072007012164082),
#  ('attraction', 1.6072007012164082),
#  ('helper', 1.6072007012164082),
#  ('manzke', 1.6072007012164082),
#  ('cater', 1.6072007012164082),
#  ('kashmiri', 1.6072007012164082),
#  ('chandra', 1.6072007012164082),
#  ('farofa', 1.6072007012164082),
#  ('turnover', 1.6072007012164082),
#  ('gel', 1.6072007012164082),
#  ('fonio', 1.6072007012164082),
#  ('lu', 1.6072007012164082),
#  ('fiercely', 1.6072007012164082),
#  ('timer', 1.6072007012164082),
#  ('chana', 1.6072007012164082),
#  ('toasting', 1.6072007012164082),
#  ('marcus', 1.6072007012164082),
#  ('1/2-inch', 1.6072007012164082),
#  ('president', 1.6072007012164082),
#  ('lotus', 1.6072007012164082),
#  ('hondashi', 1.6072007012164082),
#  ('prabakaran', 1.6072007012164082),
#  ('crosswise', 1.6072007012164082),
#  ('flare', 1.6072007012164082),
#  ('seize', 1.6072007012164082),
#  ('drown', 1.6072007012164082),
#  ('nate', 1.6072007012164082),
#  ('portland', 1.6072007012164082),
#  ('squishy', 1.6072007012164082),
#  ('pandya', 1.6072007012164082),
#  ('mullet', 1.6072007012164082),
#  ('puebla', 1.6072007012164082),
#  ('pont', 1.6072007012164082),
#  ('prohibition', 1.6072007012164082),
#  ('join', 1.6072007012164082),
#  ('occupy', 1.6072007012164082),
#  ('hasselback', 1.6072007012164082),
#  ('sleek', 1.6072007012164082),
#  ('yakisoba', 1.6072007012164082),
#  ('quicker', 1.6072007012164082),
#  ('flight', 1.6072007012164082),
#  ('manicotti', 1.6072007012164082),
#  ('wat', 1.6072007012164082),
#  ('stuffing', 1.5851309946729102),
#  ('blue', 1.5851309946729102),
#  ('turmeric', 1.5656023609393304),
#  ('8', 1.5484082013636915),
#  ('sambal', 1.5484082013636915),
#  ('west', 1.541699422643796),
#  ('caribbean', 1.522112539948324),
#  ('frosting', 1.522112539948324),
#  ('dr', 1.507138887919234),
#  ('chilie', 1.507138887919234),
#  ('birthday', 1.507138887919234),
#  ('national', 1.507138887919234),
#  ('brother', 1.507138887919234),
#  ('duty', 1.507138887919234),
#  ('kebab', 1.507138887919234),
#  ('favor', 1.507138887919234),
#  ('daikon', 1.507138887919234),
#  ('crucial', 1.507138887919234),
#  ('griddle', 1.485883135486311),
#  ('asian', 1.4768017153183086),
#  ('smoothie', 1.4766454568424743),
#  ('jalapeño', 1.4714857456240793),
#  ('mexico', 1.4420235439176958),
#  ('weibel', 1.4191870521137657),
#  ('—alexa', 1.4191870521137657),
#  ('carne', 1.395908544068174),
#  ('sushi', 1.395908544068174),
#  ('austin', 1.395908544068174),
#  ('quesadilla', 1.395908544068174),
#  ('foie', 1.395908544068174),
#  ('unripe', 1.395908544068174),
#  ('commercial', 1.395908544068174),
#  ('multiple', 1.395908544068174),
#  ('lucky', 1.395908544068174),
#  ('amaranth', 1.395908544068174),
#  ('sub', 1.395908544068174),
#  ('julienne', 1.395908544068174),
#  ('derive', 1.395908544068174),
#  ('smoking', 1.395908544068174),
#  ('bluefish', 1.395908544068174),
#  ('edamame', 1.395908544068174),
#  ('los', 1.3869163905742385),
#  ('ferment', 1.3789975692868979),
#  ('impart', 1.3789975692868979),
#  ('cutlet', 1.3789975692868979),
#  ('ginger', 1.3682996933005245),
#  ('chile', 1.351787717576998),
#  ('dipping', 1.3477233792799215),
#  ('atlantic', 1.3477233792799215),
#  ('mimic', 1.3477233792799215),
#  ('korean', 1.3410221201544106),
#  ('lime', 1.3404133039590476),
#  ('frying', 1.3263491268389076),
#  ('rao', 1.3168537938054947),
#  ('pop', 1.3065312348989193),
#  ('cooker', 1.2830478487075427),
#  ('doughnut', 1.2707745667437023),
#  ('tenderize', 1.2707576293142668),
#  ('queen', 1.2707576293142668),
#  ('park', 1.2707576293142668),
#  ('lard', 1.2707576293142668),
#  ('hamburger', 1.2707576293142668),
#  ('sized', 1.2707406923955045),
#  ('grace', 1.2707406923955045),
#  ('tapioca', 1.2707406923955045),
#  ('decorative', 1.2707406923955045),
#  ('radical', 1.2707406923955045),
#  ('pulp', 1.2707406923955045),
#  ('—steven', 1.2707406923955045),
#  ('ripen', 1.2707406923955045),
#  ('zingy', 1.2707406923955045),
#  ('aluminum', 1.2707406923955045),
#  ('readily', 1.2707406923955045),
#  ('burrito', 1.2707406923955045),
#  ('elsewhere', 1.2707406923955045),
#  ('value', 1.2707406923955045),
#  ('beach', 1.2707406923955045),
#  ('hefty', 1.2707406923955045),
#  ('carcass', 1.2707406923955045),
#  ('picadillo', 1.2707406923955045),
#  ('whichever', 1.2707406923955045),
#  ('undoubtedly', 1.2707237559873894),
#  ('hewitt', 1.2707237559873894),
#  ('145', 1.2707237559873894),
#  ('shawarma', 1.2707237559873894),
#  ('retailer', 1.2707237559873894),
#  ('saltie', 1.2707237559873894),
#  ('tamagoyaki', 1.2707237559873894),
#  ('thawing', 1.2707237559873894),
#  ('midwinter', 1.2707237559873894),
#  ...]

# %%
sorted(lor_desc.items(), key=lambda x: x[1], reverse=False)
# Out:
# [('provençal', -4.8049158263371625),
#  ('kugel', -4.189023143960974),
#  ('ratatouille', -3.772809885453966),
#  ('trahana', -3.7061119034915024),
#  ('biscotti', -3.7061119034915024),
#  ('edna', -3.6346463320892246),
#  ('sicily', -3.6346463320892246),
#  ('spaetzle', -3.6346463320892246),
#  ('tapas', -3.6346463320892246),
#  ('watson', -3.474290467304752),
#  ('babka', -3.474290467304752),
#  ('trifle', -3.383312081809864),
#  ('pimentón', -3.2832220160073757),
#  ('provence', -3.2476181619407662),
#  ('quiche', -3.24043310212017),
#  ('quealy', -3.1719897736953016),
#  ('burrata', -3.1719897736953016),
#  ('orecchiette', -3.1719897736953016),
#  ('apulia', -3.1719897736953016),
#  ('pâte', -3.1719897736953016),
#  ('madeleine', -3.1719897736953016),
#  ('antipasto', -3.1719897736953016),
#  ('combo', -3.1719897736953016),
#  ('clafoutis', -3.1719897736953016),
#  ('paella', -3.0904061467294004),
#  ('rillette', -3.0469144269765835),
#  ('bud', -3.0468200235831002),
#  ('homey', -3.0468200235831002),
#  ('caponata', -3.0468200235831002),
#  ('coq', -3.0468200235831002),
#  ('sheep', -3.0468200235831002),
#  ('puttanesca', -3.0468200235831002),
#  ('salade', -3.0468200235831002),
#  ('vin', -3.0468200235831002),
#  ('matzo', -3.0278652921640052),
#  ('definitive', -3.0014454451304107),
#  ('sardine', -2.903793760158651),
#  ('brei', -2.903712572827886),
#  ('lardon', -2.903712572827886),
#  ('macau', -2.903712572827886),
#  ('lyon', -2.903712572827886),
#  ('umbria', -2.903712572827886),
#  ('penne', -2.903712572827886),
#  ('pistou', -2.903712572827886),
#  ('batali', -2.903712572827886),
#  ('basque', -2.903712572827886),
#  ('strudel', -2.903712572827886),
#  ('bulb', -2.903712572827886),
#  ('ireland', -2.903712572827886),
#  ('log', -2.903712572827886),
#  ('marrow', -2.903712572827886),
#  ('runner', -2.7366518810938327),
#  ('ray', -2.7366518810938327),
#  ('guava', -2.7366518810938327),
#  ('marinière', -2.7366518810938327),
#  ('pittsburgh', -2.7366518810938327),
#  ('austrian', -2.7366518810938327),
#  ('anti', -2.7366518810938327),
#  ('buford', -2.7366518810938327),
#  ('colored', -2.7366518810938327),
#  ('trimming', -2.7366518810938327),
#  ('boulud', -2.7366518810938327),
#  ('taralli', -2.7366518810938327),
#  ('nordic', -2.7366518810938327),
#  ('kasha', -2.7366518810938327),
#  ('moule', -2.7366518810938327),
#  ('yukon', -2.7366518810938327),
#  ('mingling', -2.7366518810938327),
#  ('kenney', -2.7366518810938327),
#  ('roberta', -2.7366518810938327),
#  ('clot', -2.7366518810938327),
#  ('fudge', 2.868147112496643),
#  ('cutout', 2.868147112496643),
#  ('bagel', 2.868147112496643),
#  ('brie', 2.868147112496643),
#  ('cashews', 2.8359255533683942),
#  ('lemongrass', 2.7680987773580923),
#  ('croquette', 2.768061564189052),
#  ('popsicle', 2.768061564189052),
#  ('basmati', 2.768061564189052),
#  ('blini', 2.768061564189052),
#  ('ranch', 2.768061564189052),
#  ('lumpia', 2.768061564189052),
#  ('urge', 2.768061564189052),
#  ('catfish', 2.768061564189052),
#  ('soy', 2.735029082811449),
#  ('masala', 2.680158859528987),
#  ('naan', 2.656833839332585),
#  ('sushi', 2.656833839332585),
#  ('tadka', 2.656833839332585),
#  ('tarka', 2.656833839332585),
#  ('embutido', 2.656833839332585),
#  ('asafetida', 2.656833839332585),
#  ('khoya', 2.656833839332585),
#  ('tandoor', 2.656833839332585),
#  ('laddoo', 2.656833839332585),
#  ('kachori', 2.656833839332585),
#  ('wonton', 2.656833839332585),
#  ('coconut', 2.6139355245109375),
#  ('burger', 2.5580457132981036),
#  ('broiling', 2.531668606636704),
#  ('vermicelli', 2.531668606636704),
#  ('nachos', 2.531668606636704),
#  ('wasabi', 2.531668606636704),
#  ('chimney', 2.531668606636704),
#  ('1/3-inch', 2.531668606636704),
#  ('portobello', 2.531668606636704),
#  ('makrut', 2.531668606636704),
#  ('reddish', 2.531668606636704),
#  ('satoimo', 2.531668606636704),
#  ('galangal', 2.531668606636704),
#  ('considerably', 2.531668606636704),
#  ('shiso', 2.531668606636704),
#  ('hibiscus', 2.531668606636704),
#  ('gougère', 2.531668606636704),
#  ('miso', 2.5168562872686784),
#  ('garam', 2.5046955528513903),
#  ('masa', 2.4769138988801562),
#  ('dashi', 2.4386028577163823),
#  ('poblano', 2.3885903473474404),
#  ('zu', 2.3885656732585225),
#  ('dumple', 2.3885656732585225),
#  ('messy', 2.3885656732585225),
#  ('tian', 2.3885656732585225),
#  ('roulade', 2.3885656732585225),
#  ('acetate', 2.3885656732585225),
#  ('paratha', 2.3885656732585225),
#  ('kombucha', 2.3885656732585225),
#  ('saltine', 2.3885656732585225),
#  ('moufleta', 2.3885656732585225),
#  ('pozole', 2.3885656732585225),
#  ('festival', 2.3885656732585225),
#  ('anaheim', 2.3885656732585225),
#  ('attention', 2.3885656732585225),
#  ('pumpkinseed', 2.3885656732585225),
#  ('paneer', 2.3885656732585225),
#  ('gumbo', 2.3885656732585225),
#  ('70', 2.3885656732585225),
#  ('lean', 2.3885656732585225),
#  ('bonito', 2.3885656732585225),
#  ('wok', 2.366275366571712),
#  ('arm', 2.335944524072105),
#  ('chutney', 2.32509743675687),
#  ('indirect', 2.280372583131748),
#  ('hoisin', 2.280372583131748),
#  ('soba', 2.280372583131748),
#  ('cheesecake', 2.280372583131748),
#  ('sesame', 2.2219194874189663),
#  ('mani', 2.2215094988622153),
#  ('super', 2.2215094988622153),
#  ('spongy', 2.2215094988622153),
#  ('puck', 2.2215094988622153),
#  ('indefinitely', 2.2215094988622153),
#  ('poultry', 2.2215094988622153),
#  ('yaki', 1.7695201956659767),
#  ('refuel', 1.7695201956659767),
#  ('tempering', 1.7695201956659767),
#  ('roof', 1.7695201956659767),
#  ('broccolini', 1.7695201956659767),
#  ('plop', 1.7695201956659767),
#  ('8-by-15-inch', 1.7695201956659767),
#  ('goma', 1.7695201956659767),
#  ('unmixed', 1.7695201956659767),
#  ('mild', 1.7695201956659767),
#  ('muslin', 1.7695201956659767),
#  ('egusi', 1.7695201956659767),
#  ('reusable', 1.7695201956659767),
#  ('mojo', 1.7695201956659767),
#  ('kefta', 1.7695201956659767),
#  ('daylily', 1.7695201956659767),
#  ('energetically', 1.7695201956659767),
#  ('berbere', 1.7695201956659767),
#  ('negi', 1.7695201956659767),
#  ('3/8', 1.7695201956659767),
#  ('minimum', 1.7695201956659767),
#  ('matcha', 1.7695201956659767),
#  ('live', 1.7695201956659767),
#  ('domed', 1.7695201956659767),
#  ('bronze', 1.7695201956659767),
#  ('intensify', 1.7695201956659767),
#  ('newsprint', 1.7695201956659767),
#  ('bebinca', 1.7695201956659767),
#  ('brew', 1.7695201956659767),
#  ('crispness', 1.7695201956659767),
#  ('unused', 1.7695201956659767),
#  ('tteok', 1.7695201956659767),
#  ('obsessive', 1.7695201956659767),
#  ('andouille', 1.7695201956659767),
#  ('refreeze', 1.7695201956659767),
#  ('splitting', 1.7695201956659767),
#  ('rangiri', 1.7695201956659767),
#  ('nibs', 1.7695201956659767),
#  ('ripen', 1.7695201956659767),
#  ('biryani', 1.7695201956659767),
#  ('accumulated', 1.7695201956659767),
#  ('blowtorch', 1.7695201956659767),
#  ('tempura', 1.7695201956659767),
#  ('refry', 1.7695201956659767),
#  ('38', 1.7695201956659767),
#  ('kick', 1.7695201956659767),
#  ('fix', 1.7695201956659767),
#  ('chia', 1.7695201956659767),
#  ('humid', 1.7695201956659767),
#  ('enoki', 1.7695201956659767),
#  ('tricky', 1.7695201956659767),
#  ('suya', 1.7695201956659767),
#  ('resistant', 1.7695201956659767),
#  ('colby', 1.7695201956659767),
#  ('inward', 1.7695201956659767),
#  ('nilla', 1.7695201956659767),
#  ('peeking', 1.7695201956659767),
#  ('bead', 1.7695201956659767),
#  ('turkey', 1.7052547528377962),
#  ('shiitake', 1.701378490998275),
#  ('serrano', 1.6694790101347399),
#  ('balance', 1.6694467826816226),
#  ('snow', 1.6694467826816226),
#  ('hash', 1.6694467826816226),
#  ('lumpy', 1.6694467826816226),
#  ('condensed', 1.6694467826816226),
#  ('healthy', 1.6694467826816226),
#  ('clementine', 1.6694467826816226),
#  ('dumpling', 1.6633100856980374),
#  ('adobo', 1.6481794299579657),
#  ('nori', 1.6481794299579657),
#  ('doughnut', 1.6389301504198006),
#  ('lime', 1.6228401451241794),
#  ('pliable', 1.591300011631898),
#  ('jelly', 1.5814859656868487),
#  ('frosting', 1.5749723470725505),
#  ('frost', 1.5651817800911447),
#  ('cilantro', 1.5651304437641678),
#  ('tomatillo', 1.5582751544809963),
#  ('cardboard', 1.5582190578251562),
#  ('malt', 1.5582190578251562),
#  ('dulse', 1.4330458693247234),
#  ('hanout', 1.4330458693247234),
#  ('carton', 1.4330458693247234),
#  ('strongly', 1.4330458693247234),
#  ('remelt', 1.4330458693247234),
#  ('zap', 1.4330458693247234),
#  ('175', 1.4330458693247234),
#  ('adjustment', 1.4330458693247234),
#  ('sec', 1.4330458693247234),
#  ('belacan', 1.4330458693247234),
#  ('unmelted', 1.4330458693247234),
#  ('\n\n    ', 1.4330458693247234),
#  ('popover', 1.4330458693247234),
#  ('attentively', 1.4330458693247234),
#  ('freehand', 1.4330458693247234),
#  ('crowding', 1.4330458693247234),
#  ('twinkie', 1.4330458693247234),
#  ('shichimi', 1.4330458693247234),
#  ('kefir', 1.4330458693247234),
#  ('smoothie', 1.4330458693247234),
#  ('425-degree', 1.4330458693247234),
#  ('pointy', 1.4330458693247234),
#  ('kamado', 1.4330458693247234),
#  ('popping', 1.4330458693247234),
#  ('appreciate', 1.4330458693247234),
#  ('bless', 1.4330458693247234),
#  ('bagoong', 1.4330458693247234),
#  ('1-tablespoon', 1.4330458693247234),
#  ('curry', 1.4201759316348757),
#  ('jalapeño', 1.4086278855122145),
#  ('apply', 1.374227147243151),
#  ('salsa', 1.3706423672910593),
#  ('meld', 1.3695760202851572),
#  ('banana', 1.3598998449628859),
#  ('handheld', 1.3496780823383931),
#  ('hit', 1.3496780823383931),
#  ('9-by-5-inch', 1.3496780823383931),
#  ('blackberry', 1.3496780823383931),
#  ('chopstick', 1.3399830904930299),
#  ('barbecue', 1.3362375101796116),
#  ('canola', 1.3330315238202428),
#  ('coal', 1.3308082660782996),
#  ('plantain', 1.311752035460755),
#  ('function', 1.3117047004850055),
#  ('clear', 1.3079359262820192),
#  ('darken', 1.3005917939613723),
#  ('radish', 1.2900296493360248),
#  ('area', 1.289970580124088),
#  ('cup/120', 1.2899508917510938),
#  ('upward', 1.2899508917510938),
#  ('bend', 1.2899508917510938),
#  ('caviar', 1.2899508917510938),
#  ('¾', 1.2899508917510938),
#  ('rip', 1.2899508917510938),
#  ('clumpy', 1.2899508917510938),
#  ('sign', 1.2899508917510938),
#  ('refried', 1.2899508917510938),
#  ('disperse', 1.2899508917510938),
#  ('gizzard', 1.2899508917510938),
#  ('smoker', 1.2758917065814988),
#  ('14-inch', 1.2736751090506737),
#  ('fluff', 1.2587356358284216),
#  ('okra', 1.2587356358284216),
#  ('block', 1.25870421437769),
#  ('defrost', 1.25870421437769),
#  ('coin', 1.25870421437769),
#  ('vary', 1.25870421437769),
#  ('torch', 1.25870421437769),
#  ('trace', 1.25870421437769),
#  ('decrease', 1.25870421437769),
#  ('pinche', 1.2373247568487522),
#  ('scallion', 1.2350436081773553),
#  ('carve', 1.2289857103383564),
#  ('granulate', 1.2217954391926815),
#  ('cornstarch', 1.2138203309313684),
#  ('pudding', 1.1951320726887746),
#  ('such', 1.186940040954605),
#  ('caramel', 1.1837778964322274),
#  ('left', 1.1817528159083954),
#  ('edamame', 1.1817528159083954),
#  ('cranberry', 1.1795093276857365),
#  ('¼-inch', 1.173550182463666),
#  ('matchstick', 1.173550182463666),
#  ('strand', 1.173550182463666),
#  ('macaroni', 1.173550182463666),
#  ('mousse', 1.173550182463666),
#  ('peek', 1.1586186660700988),
#  ('golf', 1.1586186660700988),
#  ('crema', 1.1586186660700988),
#  ('baked', 1.1505099152602596),
#  ('maple', 1.1229567551878619),
#  ('snap', 1.1229257353262787),
#  ('spicy', 1.1229257353262787),
#  ('queso', 1.122910226104283),
#  ('pointed', 1.1228947173547863),
#  ('leak', 1.1228947173547863),
#  ('snack', 1.1228947173547863),
#  ('spinner', 1.1228947173547863),
#  ('randomly', 1.1228947173547863),
#  ('⅓', 1.1228947173547863),
#  ('9-by-13', 1.1228947173547863),
#  ('closed', 1.1228947173547863),
#  ('bittersweet', 1.1228947173547863),
#  ('porridge', 1.1228947173547863),
#  ('usual', 1.1228947173547863),
#  ('replenish', 1.1228947173547863),
#  ('tenderness', 1.1228947173547863),
#  ('crudités', 1.1228947173547863),
#  ('dash', 1.1228947173547863),
#  ('abundant', 1.1228947173547863),
#  ('halibut', 1.1228947173547863),
#  ('dirt', 1.1228947173547863),
#  ('boneless', 1.1228947173547863),
#  ('tequila', 1.1228947173547863),
#  ('standing', 1.1228947173547863),
#  ('23', 1.1228947173547863),
#  ('blitz', 1.1228947173547863),
#  ('support', 1.1228947173547863),
#  ('9-by-9-inch', 1.1228947173547863),
#  ('fry', 1.1224420694238617),
#  ('marinate', 1.116137869175492),
#  ('interior', 1.1088351290479417),
#  ('shred', 1.099224321655714),
#  ('pourable', 1.0965870515638272),
#  ('romaine', 1.0965870515638272),
#  ('patty', 1.0938997697186983),
#  ('crunchy', 1.0892973917977604),
#  ('contact', 1.0892973917977604),
#  ('chip', 1.0680494657792878),
#  ('puréed', 1.0653479273008206),
#  ('gas', 1.0604301284568163),
#  ('splatter', 1.0603877793461371),
#  ('condense', 1.0603877793461371),
#  ('pop', 1.0569597395610473),
#  ('avocado', 1.0474831956914379),
#  ('mayo', 1.0473909412136322),
#  ('mole', 1.0473909412136322),
#  ('uneven', 1.0473909412136322),
#  ('burrito', 1.0473909412136322),
#  ('forth', 1.0473909412136322),
#  ('5-inch', 1.0473909412136322),
#  ('heaped', 1.0473909412136322),
#  ('creamed', 1.0473909412136322),
#  ('fermentation', 1.0473909412136322),
#  ('regularly', 1.0473909412136322),
#  ('dome', 1.0473909412136322),
#  ('sweetness', 1.0473909412136322),
#  ('cracker', 1.0418094306028498),
#  ('blue', 1.036651568522425),
#  ('blacken', 1.0334802719207516),
#  ('cutlet', 1.0334802719207516),
#  ('brisket', 1.0305084821332244),
#  ('noodle', 1.0207689821938029),
#  ('jiggly', 1.013203352865433),
#  ('fresco', 1.013203352865433),
#  ('12-cup', 1.013203352865433),
#  ('sunflower', 1.013203352865433),
#  ('japanese', 1.013203352865433),
#  ('tortilla', 1.0109444165805623),
#  ('near', 1.00564757572334),
#  ('guest', 0.9977600994894532),
#  ('bamboo', 0.9936943150750204),
#  ('star', 0.9900789199317948),
#  ('shredded', 0.9900789199317948),
#  ('quiche', -3.24043310212017),
#  ('quealy', -3.1719897736953016),
#  ('burrata', -3.1719897736953016),
#  ('orecchiette', -3.1719897736953016),
#  ('apulia', -3.1719897736953016),
#  ('pâte', -3.1719897736953016),
#  ('madeleine', -3.1719897736953016),
#  ('antipasto', -3.1719897736953016),
#  ('combo', -3.1719897736953016),
#  ('clafoutis', -3.1719897736953016),
#  ('paella', -3.0904061467294004),
#  ('rillette', -3.0469144269765835),
#  ('bud', -3.0468200235831002),
#  ('homey', -3.0468200235831002),
#  ('caponata', -3.0468200235831002),
#  ('coq', -3.0468200235831002),
#  ('sheep', -3.0468200235831002),
#  ('puttanesca', -3.0468200235831002),
#  ('salade', -3.0468200235831002),
#  ('vin', -3.0468200235831002),
#  ('matzo', -3.0278652921640052),
#  ('definitive', -3.0014454451304107),
#  ('sardine', -2.903793760158651),
#  ('brei', -2.903712572827886),
#  ('lardon', -2.903712572827886),
#  ('macau', -2.903712572827886),
#  ('lyon', -2.903712572827886),
#  ('umbria', -2.903712572827886),
#  ('penne', -2.903712572827886),
#  ('pistou', -2.903712572827886),
#  ('batali', -2.903712572827886),
#  ('basque', -2.903712572827886),
#  ('strudel', -2.903712572827886),
#  ('bulb', -2.903712572827886),
#  ('ireland', -2.903712572827886),
#  ('log', -2.903712572827886),
#  ('marrow', -2.903712572827886),
#  ('runner', -2.7366518810938327),
#  ('ray', -2.7366518810938327),
#  ('guava', -2.7366518810938327),
#  ('marinière', -2.7366518810938327),
#  ('pittsburgh', -2.7366518810938327),
#  ('austrian', -2.7366518810938327),
#  ('anti', -2.7366518810938327),
#  ('buford', -2.7366518810938327),
#  ('colored', -2.7366518810938327),
#  ('trimming', -2.7366518810938327),
#  ('boulud', -2.7366518810938327),
#  ('taralli', -2.7366518810938327),
#  ('nordic', -2.7366518810938327),
#  ('kasha', -2.7366518810938327),
#  ('moule', -2.7366518810938327),
#  ('yukon', -2.7366518810938327),
#  ('mingling', -2.7366518810938327),
#  ('kenney', -2.7366518810938327),
#  ('roberta', -2.7366518810938327),
#  ('clot', -2.7366518810938327),
#  ('aioli', -2.699739949921056),
#  ('pesto', -2.674383615434158),
#  ('trout', -2.6741928882223918),
#  ('gazpacho', -2.6074949062599284),
#  ('bistro', -2.6074949062599284),
#  ('underrated', -2.535974578604447),
#  ('pimm', -2.535974578604447),
#  ('portugal', -2.535974578604447),
#  ('fromage', -2.535974578604447),
#  ('brisée', -2.535974578604447),
#  ('barney', -2.535974578604447),
#  ('dynamic', -2.535974578604447),
#  ('insanely', -2.535974578604447),
#  ('manzanilla', -2.535974578604447),
#  ('soufflés', -2.535974578604447),
#  ('modest', -2.535974578604447),
#  ('blanc', -2.535974578604447),
#  ('polpettone', -2.535974578604447),
#  ('montreal', -2.535974578604447),
#  ('smoothly', -2.535974578604447),
#  ('sprig', -2.535974578604447),
#  ('risina', -2.535974578604447),
#  ('parbake', -2.535974578604447),
#  ('historically', -2.535974578604447),
#  ('tabasco', -2.535974578604447),
#  ('jinich', -2.535974578604447),
#  ('breac', -1.4373424691165477),
#  ('margot', -1.4373424691165477),
#  ('taleggio', -1.4373424691165477),
#  ('photogenic', -1.4373424691165477),
#  ('swoop', -1.4373424691165477),
#  ('synagogue', -1.4373424691165477),
#  ('dover', -1.4373424691165477),
#  ('mûre', -1.4373424691165477),
#  ('marzano', -1.4373424691165477),
#  ('fanciful', -1.4373424691165477),
#  ('overture', -1.4373424691165477),
#  ('activist', -1.4373424691165477),
#  ('turin', -1.4373424691165477),
#  ('magnificently', -1.4373424691165477),
#  ('pauvre', -1.4373424691165477),
#  ...]

# %%
lor['easy']
# Out:
# -0.7805638808004122

# %%
lor['weeknight']
# Out:
# 1.4171110455639093

# %%
lor['simple']
# Out:
# 0.04392395293215739

# %%
lor['spicy']
# Out:
# 0.6021711164252307

# %%
lor['goddess']
# Out:
# 1.7536761542539143

# %%
lor['humble']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-647-3935a4d489c5> in <module>
# ----> 1 lor['humble']
#
# KeyError: 'humble'

# %%
lor_desc['easy']
# Out:
# -0.07758974599004735

# %%
lor_desc['weeknight']
# Out:
# 0.15290602051926946

# %%
lor_desc['simple']
# Out:
# 0.06363119326268343

# %%
lor_desc['substitute']
# Out:
# 0.1234448266003417

# %%
lor_desc['substitution']
# Out:
# 0.28032406583492797

# %%
lor_desc['spicy']
# Out:
# 0.8911380367621159

# %%
lor_desc['goddess']
# Out:
# 1.6072007012164082

# %%
lor_desc['travel']
# Out:
# -0.12742024933952922

# %%
lor_desc['strange']
# Out:
# -0.3387254718849736

# %%
lor_desc['unfamiliar']
# Out:
# 0.24906871194428504

# %%
lor_desc['comfort']
# Out:
# -0.11808106424902055

# %%
lor_desc['humble']
# Out:
# -1.638093438219648

# %%
lor_desc['familiar']
# Out:
# 0.17211230550998355

# %%
lor_desc['tasty']
# Out:
# -0.05914364326770409

# %%
lor_desc['delicious']
# Out:
# -0.11155703037071332

# %%
lor_desc['fatty']
# Out:
# -0.14767600466069639

# %% [markdown]
# ## Q: Do modifiers like "simple", "easy", "weeknight", "quick" tend to be applied to NW dishes?

# %%
from collections import Counter

# %%
def collect_pos(pos_label, field='title', lemmas=True):
    matches = []
    fnames = glob.glob('./data/preprocessed/*')
    
    for ix_fname, fname in enumerate(fnames):
        with open(fname, 'r') as file:
            json_obj = json.load(file)
            pos_match_ixs = [pos_ix for pos_ix,pos in 
                             enumerate(json_obj[field]['pos'])
                            if pos==pos_label]
            if lemmas:
                matches.extend(
                    [json_obj[field]['lemmas'][pos_match_ix]
                    for pos_match_ix in pos_match_ixs])
            else:
                matches.extend(
                    [json_obj[field]['tokens'][pos_match_ix]
                     for pos_match_ix in pos_match_ixs])
        
        if ix_fname % 500 == 0:
            print('Searched through {} files out of {} total.'.format(
                ix_fname, len(fnames)))
    
    return matches

def collect_modifiees(adj_set, field='title', lemmas=True):
    """
    Retrieves nouns modified by a set of adjectives within recipes
    @param adj_set: set of adjectives
    @param field: str part of a recipe to look for modified nouns 
                  possible values: {'title','description','steps'}
    @param lemmas: boolean for whether to return lemmas or original tokens
    """
    matches = []
    fnames = glob.glob('./data/preprocessed/*')
    
    for ix_fname, fname in enumerate(fnames):
        with open(fname, 'r') as file:
            json_obj = json.load(file)
            
            if field in json_obj:
            
                # find ixs of lemmas in adj_set with 'amod' dep. label
                match_ixs = [ix for ix,dep in 
                                 enumerate(json_obj[field]['dep_label'])
                                if dep=='amod' and \
                             json_obj[field]['lemmas'][ix] in adj_set]

                # return heads of those ixs
                matches.extend(
                        [json_obj[field]['head'][match_ix]
                        for match_ix in match_ixs])
        
        if ix_fname % 500 == 0:
            print('Searched through {} files out of {} total.'.format(
                ix_fname, len(fnames)))
    
    return matches

# %%
fnames = glob.glob('./data/preprocessed/*')
with open(fnames[0], 'r') as file:
    json_obj = json.load(file)

# %%
test = "This recipe is easy."
doc = nlp(test)
for tok in doc:
    print(tok.text,tok.pos_,tok.dep_,tok.head)
# Out:
# This DET det recipe
# recipe NOUN nsubj is
# is VERB ROOT is
# easy ADJ acomp is
# . PUNCT punct is

# %%
# title_easy_heads = collect_modifiees(set(
#     ['simple','easy','quick','weeknight']), field='title')

description_easy_heads = collect_modifiees(set(
    ['simple','easy','quick','weeknight']), field='description')
# Out:
# Searched through 0 files out of 19174 total.
# Searched through 500 files out of 19174 total.
# Searched through 1000 files out of 19174 total.
# Searched through 1500 files out of 19174 total.
# Searched through 2000 files out of 19174 total.
# Searched through 2500 files out of 19174 total.
# Searched through 3000 files out of 19174 total.
# Searched through 3500 files out of 19174 total.
# Searched through 4000 files out of 19174 total.
# Searched through 4500 files out of 19174 total.
# Searched through 5000 files out of 19174 total.
# Searched through 5500 files out of 19174 total.
# Searched through 6000 files out of 19174 total.
# Searched through 6500 files out of 19174 total.
# Searched through 7000 files out of 19174 total.
# Searched through 7500 files out of 19174 total.
# Searched through 8000 files out of 19174 total.
# Searched through 8500 files out of 19174 total.
# Searched through 9000 files out of 19174 total.
# Searched through 9500 files out of 19174 total.
# Searched through 10000 files out of 19174 total.
# Searched through 10500 files out of 19174 total.
# Searched through 11000 files out of 19174 total.
# Searched through 11500 files out of 19174 total.
# Searched through 12000 files out of 19174 total.
# Searched through 12500 files out of 19174 total.
# Searched through 13000 files out of 19174 total.
# Searched through 13500 files out of 19174 total.
# Searched through 14000 files out of 19174 total.
# Searched through 14500 files out of 19174 total.
# Searched through 15000 files out of 19174 total.
# Searched through 15500 files out of 19174 total.
# Searched through 16000 files out of 19174 total.
# Searched through 16500 files out of 19174 total.
# Searched through 17000 files out of 19174 total.
# Searched through 17500 files out of 19174 total.
# Searched through 18000 files out of 19174 total.
# Searched through 18500 files out of 19174 total.
# Searched through 19000 files out of 19174 total.

# %%
len(title_easy_heads),len(description_easy_heads)
# Out:
# (163, 1662)

# %%
sorted(Counter(title_easy_heads).items(), 
       key=lambda x: x[1], reverse=True)
# Out:
# [('sauce', 15),
#  ('bread', 9),
#  ('soup', 9),
#  ('syrup', 6),
#  ('chicken', 5),
#  ('pickles', 5),
#  ('cake', 4),
#  ('pudding', 3),
#  ('tomatillo', 3),
#  ('dressing', 3),
#  ('kimchi', 3),
#  ('stock', 2),
#  ('gratin', 2),
#  ('turkey', 2),
#  ('steak', 2),
#  ('cream', 2),
#  ('tart', 2),
#  ('lamb', 2),
#  ('aioli', 2),
#  ('mousse', 2),
#  ('ribs', 2),
#  ('fish', 1),
#  ('grilled', 1),
#  ('confit', 1),
#  ('fudge', 1),
#  ('bouillabaisse', 1),
#  ('chops', 1),
#  ('ginger', 1),
#  ('potatoes', 1),
#  ('fries', 1),
#  ('asparagus', 1),
#  ('quesadilla', 1),
#  ('slaw', 1),
#  ('kebabs', 1),
#  ('pasta', 1),
#  ('salad', 1),
#  ('clams', 1),
#  ('scallops', 1),
#  ('flounder', 1),
#  ('patties', 1),
#  ('yeasted', 1),
#  ('mushrooms', 1),
#  ('grits', 1),
#  ('dough', 1),
#  ('beans', 1),
#  ('salmon', 1),
#  ('shrimp', 1),
#  ('peaches', 1),
#  ('sardines', 1),
#  ('kulfi', 1),
#  ('minestrone', 1),
#  ('baklava', 1),
#  ('yogurt', 1),
#  ('rhubarb', 1),
#  ('bean', 1),
#  ('jam', 1),
#  ('amba', 1),
#  ('matzo', 1),
#  ('broth', 1),
#  ('punch', 1),
#  ('caramel', 1),
#  ('adobo', 1),
#  ('gyros', 1),
#  ('spice', 1),
#  ('masala', 1),
#  ('pie', 1),
#  ('flatbread', 1),
#  ('gomae', 1),
#  ('focaccia', 1),
#  ('sheet', 1),
#  ('rice', 1),
#  ('summer', 1),
#  ('crust', 1),
#  ('calzones', 1),
#  ('loaf', 1),
#  ('squash', 1),
#  ('pizza', 1),
#  ('garnie', 1),
#  ('plum', 1),
#  ('cioppino', 1),
#  ('greens', 1),
#  ('pancakes', 1),
#  ('granola', 1),
#  ('tarts', 1),
#  ('bolognese', 1),
#  ('sausage', 1),
#  ('kale', 1),
#  ('marmalade', 1),
#  ('gravy', 1),
#  ('sorbet', 1),
#  ('peel', 1),
#  ('carbonara', 1),
#  ('cookies', 1),
#  ('khichari', 1),
#  ('thighs', 1),
#  ('ribollita', 1),
#  ('yule', 1),
#  ('tiramisù', 1),
#  ('curry', 1)]

# %%
sorted(Counter(description_easy_heads).items(), 
       key=lambda x: x[1], reverse=True)
# Out:
# [('dish', 102),
#  ('recipe', 77),
#  ('sauce', 65),
#  ('salad', 57),
#  ('way', 48),
#  ('meal', 42),
#  ('syrup', 41),
#  ('dinner', 38),
#  ('cooking', 32),
#  ('soup', 31),
#  ('version', 23),
#  ('cake', 23),
#  ('work', 21),
#  ('—', 20),
#  ('meals', 19),
#  ('method', 19),
#  ('recipes', 19),
#  ('pasta', 17),
#  ('bread', 15),
#  ('dessert', 15),
#  ('broth', 15),
#  ('dressing', 12),
#  ('dishes', 12),
#  ('one', 12),
#  ('’s', 12),
#  ('glaze', 12),
#  ('chicken', 11),
#  ('vinaigrette', 10),
#  ('combination', 10),
#  ('ingredients', 10),
#  ('fry', 9),
#  ('marinade', 9),
#  ('stew', 9),
#  ('dough', 9),
#  ('breads', 9),
#  ('technique', 9),
#  ('mixture', 8),
#  ('pastas', 8),
#  ('drink', 8),
#  ('stocks', 8),
#  ('breakfast', 7),
#  ('pleasure', 7),
#  ('supper', 7),
#  ('appetizer', 7),
#  ('dip', 7),
#  ('preparation', 7),
#  ('tart', 7),
#  ('time', 7),
#  ('salads', 6),
#  ('crust', 6),
#  ('form', 6),
#  ('stock', 6),
#  ('sauté', 6),
#  ('process', 6),
#  ('steps', 6),
#  ('menu', 6),
#  ('salsa', 5),
#  ('topping', 5),
#  ('tacos', 5),
#  ('cocktail', 5),
#  ('ways', 5),
#  ('side', 5),
#  ('project', 5),
#  ('as', 5),
#  ('cookies', 5),
#  ('lunch', 5),
#  ('mix', 5),
#  ('snack', 5),
#  ('slaw', 4),
#  ('step', 4),
#  ('compote', 4),
#  ('thing', 4),
#  ('curry', 4),
#  ('base', 4),
#  ('take', 4),
#  ('things', 4),
#  ('desserts', 4),
#  ('’', 4),
#  ('affair', 4),
#  ('food', 4),
#  ('cream', 4),
#  ('course', 4),
#  ('treat', 4),
#  ('pickles', 4),
#  ('braise', 4),
#  ('sear', 4),
#  ('trip', 4),
#  ('broil', 4),
#  ('joys', 4),
#  ('seafood', 3),
#  ('roast', 3),
#  ('formula', 3),
#  ('skillet', 3),
#  ('cousin', 3),
#  ('bowl', 3),
#  ('gratin', 3),
#  ('pudding', 3),
#  ('toss', 3),
#  ('something', 3),
#  ('jam', 3),
#  ('omelet', 3),
#  ('bake', 3),
#  ('variation', 3),
#  ('favorite', 3),
#  ('task', 3),
#  ('riff', 3),
#  ('casserole', 3),
#  ('techniques', 3),
#  ('confection', 3),
#  ('crackers', 3),
#  ('staple', 3),
#  ('shortbread', 3),
#  ('simmer', 3),
#  ('pan', 3),
#  ('fish', 3),
#  ('meats', 3),
#  ('rice', 3),
#  ('roux', 3),
#  ('rinse', 3),
#  ('batter', 3),
#  ('meatballs', 3),
#  ('frittata', 2),
#  ('soups', 2),
#  ('pilaf', 2),
#  ('noodles', 2),
#  ('hors', 2),
#  ('suppers', 2),
#  ('word', 2),
#  ('substitution', 2),
#  ('condiment', 2),
#  ('purée', 2),
#  ('accompaniment', 2),
#  ('classic', 2),
#  ('ragout', 2),
#  ('equation', 2),
#  ('presentation', 2),
#  ('stir', 2),
#  ('snacks', 2),
#  ('pesto', 2),
#  ('treatment', 2),
#  ('slicing', 2),
#  ('pot', 2),
#  ('addition', 2),
#  ('loaf', 2),
#  ('fix', 2),
#  ('gravy', 2),
#  ('twist', 2),
#  ('idea', 2),
#  ('egg', 2),
#  ('carrots', 2),
#  ('greens', 2),
#  ('part', 2),
#  ('pies', 2),
#  ('approach', 2),
#  ('substitute', 2),
#  ('flavors', 2),
#  ('ribs', 2),
#  ('endeavor', 2),
#  ('tasks', 2),
#  ('can', 2),
#  ('sides', 2),
#  ('kind', 2),
#  ('oil', 2),
#  ('filling', 2),
#  ('cleanup', 2),
#  ('rub', 2),
#  ('use', 2),
#  ('baked', 2),
#  ('pickle', 2),
#  ('bars', 2),
#  ('pairs', 2),
#  ('foods', 2),
#  ('lentils', 2),
#  ('sandwiches', 2),
#  ('seared', 2),
#  ('char', 2),
#  ('structure', 2),
#  ('drinking', 2),
#  ('topper', 2),
#  ('cracker', 1),
#  ('masquerades', 1),
#  ('legumes', 1),
#  ('soak', 1),
#  ('quick', 1),
#  ('lot', 1),
#  ('flavor', 1),
#  ('cooked', 1),
#  ('study', 1),
#  ('minestrone', 1),
#  ('hour', 1),
#  ('philosophy', 1),
#  ('confectioners', 1),
#  ('caramels', 1),
#  ('removal', 1),
#  ('mixtures', 1),
#  ('brunch', 1),
#  ('finger', 1),
#  ('crêpes', 1),
#  ('lemon', 1),
#  ('better', 1),
#  ('variety', 1),
#  ('muffin', 1),
#  ('moist', 1),
#  ('sizzle', 1),
#  ('cornmeal', 1),
#  ('business', 1),
#  ('versions', 1),
#  ('served', 1),
#  ('fare', 1),
#  ('bite', 1),
#  ('syrups', 1),
#  ('peeler', 1),
#  ('garnish', 1),
#  ('whirl', 1),
#  ('none', 1),
#  ('blini', 1),
#  ('cornbread', 1),
#  ('soufflé', 1),
#  ('whisking', 1),
#  ('tenderloin', 1),
#  ('halves', 1),
#  ('anything', 1),
#  ('scallops', 1),
#  ('relies', 1),
#  ('beyond', 1),
#  ('aperitif', 1),
#  ('raita', 1),
#  ('classics', 1),
#  ('dinners', 1),
#  ('up', 1),
#  ('lunches', 1),
#  ('potage', 1),
#  ('matter', 1),
#  ('make', 1),
#  ('backdrop', 1),
#  ('wonder', 1),
#  ('peppers', 1),
#  ('cutting', 1),
#  ('bowls', 1),
#  ('highball', 1),
#  ('introduction', 1),
#  ('maker', 1),
#  ('trout', 1),
#  ('caramelized', 1),
#  ('greek', 1),
#  ('fact', 1),
#  ('tangle', 1),
#  ('pricy', 1),
#  ('pizza', 1),
#  ('dirt', 1),
#  ('filtering', 1),
#  ('concept', 1),
#  ('primavera', 1),
#  ('counterpoints', 1),
#  ('choice', 1),
#  ('fudge', 1),
#  ('option', 1),
#  ('order', 1),
#  ('porridge', 1),
#  ('veal', 1),
#  ('parts', 1),
#  ('mushroom', 1),
#  ('tian.reader', 1),
#  ('beans', 1),
#  ('charm', 1),
#  ('torte', 1),
#  ('turn', 1),
#  ('spritz', 1),
#  ('bean', 1),
#  ('pastry', 1),
#  ('together', 1),
#  ('kebab', 1),
#  ('everyday', 1),
#  ('appeal', 1),
#  ('works', 1),
#  ('many', 1),
#  ('reheat', 1),
#  ('delight', 1),
#  ('meat', 1),
#  ('whisk', 1),
#  ('infusion', 1),
#  ('is', 1),
#  ('slurry', 1),
#  ('for', 1),
#  ('change', 1),
#  ('alternative', 1),
#  ('delicious', 1),
#  ('tapenade', 1),
#  ('knot', 1),
#  ('sweet', 1),
#  ('slice', 1),
#  ('trick', 1),
#  ('sausage', 1),
#  ('scrambled', 1),
#  ('custard', 1),
#  ('paste', 1),
#  ('sell', 1),
#  ('toast', 1),
#  ('elegance', 1),
#  ('juice', 1),
#  ('chop', 1),
#  ('caramel', 1),
#  ('winner', 1),
#  ('chips', 1),
#  ('pumpkin', 1),
#  ('vanilla', 1),
#  ('shrimp', 1),
#  ('primer', 1),
#  ('kombu', 1),
#  ('are', 1),
#  ('eating', 1),
#  ('cook', 1),
#  ('jus', 1),
#  ('adaptation', 1),
#  ('cut', 1),
#  ('upgrade', 1),
#  ('sauces', 1),
#  ('scooping', 1),
#  ('pleaser', 1),
#  ('honey', 1),
#  ('quesadilla', 1),
#  ('beautiful', 1),
#  ('weeknight', 1),
#  ('baths', 1),
#  ('bouillon', 1),
#  ('frosting', 1),
#  ('stop', 1),
#  ('service', 1),
#  ('pozole', 1),
#  ('prospect', 1),
#  ('pie', 1),
#  ('shortcut', 1),
#  ('scramble', 1),
#  ('cone', 1),
#  ('tweaks', 1),
#  ('turmeric', 1),
#  ('ones', 1),
#  ('balances', 1),
#  ('lightning', 1),
#  ('butter', 1),
#  ('comfort', 1),
#  ('made', 1),
#  ('gremolata', 1),
#  ('rounds', 1),
#  ('bath', 1),
#  ('staples', 1),
#  ('assortment', 1),
#  ('doubles', 1),
#  ('brussels', 1),
#  ('crush', 1),
#  ('cubano', 1),
#  ('confections', 1),
#  ('piece', 1),
#  ('steam', 1),
#  ('press', 1),
#  ('’re', 1),
#  ('flatbread', 1),
#  ('boil', 1),
#  ('fold', 1),
#  ('seasonings', 1),
#  ('route', 1),
#  ('practice', 1),
#  ('anchor', 1),
#  ('sugar', 1),
#  ('components', 1),
#  ('comforting', 1),
#  ('vegetable', 1),
#  ('corn', 1),
#  ('summer', 1),
#  ('serve', 1),
#  ('move', 1),
#  ('job', 1),
#  ('risotto', 1),
#  ('salt', 1),
#  ('starch', 1),
#  ('this', 1),
#  ('blanching', 1),
#  ('coulis', 1),
#  ('beazley', 1),
#  ('aromatics', 1),
#  ('features', 1),
#  ('courses', 1),
#  ('richness', 1),
#  ('cooker', 1),
#  ('seasons', 1),
#  ('bakes', 1),
#  ('juk', 1),
#  ('answer', 1),
#  ('chocolate', 1),
#  ('paellas', 1),
#  ('cocktails', 1),
#  ('elements', 1),
#  ('gratins', 1),
#  ('luxurious', 1),
#  ('yams', 1),
#  ('mac', 1),
#  ('swirling', 1),
#  ('sunday', 1),
#  ('crepes', 1),
#  ('combo', 1),
#  ('joy', 1),
#  ('fat', 1),
#  ('sidekick', 1),
#  ('bistro', 1),
#  ('number', 1),
#  ('pear', 1),
#  ('tool', 1),
#  ('tostadas', 1),
#  ('chutney', 1),
#  ('note', 1),
#  ('punch', 1),
#  ('cauliflower', 1),
#  ('fillet', 1),
#  ('flip', 1),
#  ('banchan', 1),
#  ('whack', 1),
#  ('packing', 1),
#  ('flatbreads', 1),
#  ('knots', 1),
#  ('tips', 1),
#  ('amaro', 1),
#  ('nabe', 1),
#  ('chops', 1),
#  ('steaks', 1),
#  ('pieces', 1),
#  ('skewer', 1),
#  ('hearty', 1),
#  ('than', 1),
#  ('kale', 1),
#  ('mash', 1),
#  ('path', 1),
#  ('browning', 1),
#  ('granola', 1),
#  ('variations', 1),
#  ('leaves', 1),
#  ('molding', 1),
#  ('plate', 1),
#  ('aperitivo', 1),
#  ('simple', 1),
#  ('peeling', 1),
#  ('pickling', 1),
#  ('shot', 1),
#  ('boost', 1),
#  ('sautéed', 1),
#  ('marks', 1),
#  ('swaps', 1),
#  ('ceviche', 1),
#  ('soffritto', 1),
#  ('go', 1),
#  ('guacamole', 1),
#  ('walnuts', 1),
#  ('cheese', 1),
#  ('nod', 1),
#  ('means', 1),
#  ('apple', 1)]

# %% [markdown]
# ## Most common adjectives occurring in recipe titles

# %%
title_adjs = collect_pos('ADJ', field='title')
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000

# %%
len(title_adjs)
# Out:
# 13788

# %%
counted_title_adjs = Counter(title_adjs)

# %%
sorted(counted_title_adjs.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('roasted', 828),
#  ('red', 501),
#  ('green', 472),
#  ('sweet', 404),
#  ('spicy', 393),
#  ('garlic', 307),
#  ('black', 267),
#  ('fresh', 258),
#  ('white', 251),
#  ('brown', 198),
#  ('eggplant', 177),
#  ('cranberry', 169),
#  ('parmesan', 161),
#  ('rosemary', 151),
#  ('hot', 149),
#  ('crispy', 146),
#  ('broccoli', 141),
#  ('orange', 133),
#  ('whole', 133),
#  ('creamy', 126),
#  ('sour', 124),
#  ('smoked', 124),
#  ('baked', 121),
#  ('pecan', 120),
#  ('wild', 110),
#  ('avocado', 110),
#  ('sesame', 108),
#  ('warm', 103),
#  ('classic', 97),
#  ('chili', 94),
#  ('almond', 94),
#  ('blue', 91),
#  ('good', 91),
#  ('mixed', 90),
#  ('couscous', 84),
#  ('seared', 83),
#  ('olive', 82),
#  ('mango', 77),
#  ('chile', 77),
#  ('short', 73),
#  ('french', 70),
#  ('swiss', 69),
#  ('chipotle', 68),
#  ('thai', 67),
#  ('quick', 67),
#  ('italian', 65),
#  ('pomegranate', 65),
#  ('horseradish', 63),
#  ('smoky', 60),
#  ('simple', 60),
#  ('crisp', 59),
#  ('free', 59),
#  ('new', 59),
#  ('crème', 57),
#  ('strawberry', 57),
#  ('asian', 56),
#  ('moroccan', 55),
#  ('dark', 52),
#  ('cold', 52),
#  ('crunchy', 51),
#  ('turmeric', 50),
#  ('golden', 50),
#  ('homemade', 49),
#  ('garlicky', 49),
#  ('tahini', 49),
#  ('tomato', 48),
#  ('snap', 47),
#  ('endive', 47),
#  ('citrus', 47),
#  ('oatmeal', 46),
#  ('maple', 45),
#  ('old', 45),
#  ('easy', 43),
#  ('balsamic', 43),
#  ('soft', 42),
#  ('mexican', 42),
#  ('sticky', 42),
#  ('tomatillo', 41),
#  ('shiitake', 39),
#  ('yellow', 38),
#  ('double', 38),
#  ('slow', 37),
#  ('fava', 35),
#  ('raspberry', 35),
#  ('fashioned', 34),
#  ('chinese', 34),
#  ('chorizo', 34),
#  ('vegetarian', 34),
#  ('chive', 34),
#  ('collard', 33),
#  ('cornmeal', 33),
#  ('greek', 32),
#  ('basic', 32),
#  ('apricot', 32),
#  ('frozen', 31),
#  ('korean', 31),
#  ('bittersweet', 31),
#  ('japanese', 29),
#  ('turkish', 28),
#  ('caramelized', 28),
#  ('pan', 28),
#  ('vietnamese', 28),
#  ('indian', 28),
#  ('mini', 28),
#  ('squid', 26),
#  ('spanish', 25),
#  ('toasted', 25),
#  ('poppy', 24),
#  ('celery', 24),
#  ('perfect', 24),
#  ('cooked', 23),
#  ('eyed', 23),
#  ('orzo', 22),
#  ('ragù', 22),
#  ('triple', 22),
#  ('rustic', 21),
#  ('persian', 21),
#  ('giant', 21),
#  ('pickled', 21),
#  ('crumb', 21),
#  ('ancho', 21),
#  ('bitter', 20),
#  ('irish', 20),
#  ('raw', 20),
#  ('big', 20),
#  ('blackberry', 20),
#  ('pink', 19),
#  ('andouille', 19),
#  ('oven', 18),
#  ('stewed', 18),
#  ('tropical', 18),
#  ('cannellini', 17),
#  ('sicilian', 17),
#  ('miso', 17),
#  ('instant', 17),
#  ('flaky', 16),
#  ('tart', 16),
#  ('buttered', 16),
#  ('toffee', 15),
#  ('currant', 14),
#  ('brandied', 14),
#  ('orecchiette', 14),
#  ('gruyère', 14),
#  ('rhubarb', 14),
#  ('arctic', 14),
#  ('little', 14),
#  ('grand', 14),
#  ('cashew', 14),
#  ('pine', 14),
#  ('dry', 14),
#  ('extra', 14),
#  ('sous', 13),
#  ('semolina', 13),
#  ('hominy', 13),
#  ('-', 13),
#  ('poached', 13),
#  ('frisée', 13),
#  ('salty', 13),
#  ('spiced', 13),
#  ('savory', 13),
#  ('sautéed', 13),
#  ('open', 13),
#  ('dulce', 12),
#  ('tunisian', 12),
#  ('shaved', 12),
#  ('millet', 12),
#  ('lasagna', 12),
#  ('farfalle', 12),
#  ('southern', 12),
#  ('lemony', 11),
#  ('eastern', 11),
#  ('acorn', 11),
#  ('curried', 11),
#  ('bucatini', 11),
#  ('brittle', 11),
#  ('english', 11),
#  ('ultimate', 11),
#  ('israeli', 11),
#  ('charred', 11),
#  ('buttery', 11),
#  ('bloody', 11),
#  ('swordfish', 11),
#  ('lima', 10),
#  ('asparagus', 10),
#  ('lentil', 10),
#  ('anchovy', 10),
#  ('molten', 10),
#  ('escarole', 10),
#  ('aromatic', 10),
#  ('okra', 10),
#  ('spiked', 10),
#  ('key', 10),
#  ('david', 10),
#  ('cheesy', 10),
#  ('harissa', 10),
#  ('blistered', 10),
#  ('nutmeg', 9),
#  ('fancy', 9),
#  ('vegetable', 9),
#  ('middle', 9),
#  ('biscotti', 9),
#  ('cuban', 9),
#  ('tuscan', 9),
#  ('haroseth', 9),
#  ('cornish', 9),
#  ('german', 9),
#  ('tangy', 9),
#  ('shredded', 9),
#  ('chunky', 9),
#  ('grated', 9),
#  ('salted', 9),
#  ('sambal', 9),
#  ('amaranth', 9),
#  ('iced', 9),
#  ('grilled', 9),
#  ('mezcal', 9),
#  ('graham', 9),
#  ('juicy', 9),
#  ('gingersnap', 9),
#  ('manchego', 9),
#  ('top', 8),
#  ('mediterranean', 8),
#  ('bisque', 8),
#  ('iceberg', 8),
#  ('basmati', 8),
#  ('south', 8),
#  ('purple', 8),
#  ('southwestern', 8),
#  ('hearty', 8),
#  ('lemon', 8),
#  ('jerk', 8),
#  ('portuguese', 8),
#  ('cook', 8),
#  ('dutch', 8),
#  ('tatin', 8),
#  ('leche', 8),
#  ('lebanese', 7),
#  ('hungarian', 7),
#  ('real', 7),
#  ('roman', 7),
#  ('honeyed', 7),
#  ('boozy', 7),
#  ('flourless', 7),
#  ('melted', 7),
#  ('sundae', 7),
#  ('royal', 7),
#  ('veggie', 7),
#  ('dirty', 7),
#  ('american', 7),
#  ('deep', 7),
#  ('antipasto', 7),
#  ('fluffy', 7),
#  ('turkey', 7),
#  ('queso', 7),
#  ('creamed', 7),
#  ('grey', 7),
#  ('caramel', 7),
#  ('gingerbread', 7),
#  ('individual', 7),
#  ('artichoke', 6),
#  ('prime', 6),
#  ('lazy', 6),
#  ('rich', 6),
#  ('small', 6),
#  ('hard', 6),
#  ('favorite', 6),
#  ('well', 6),
#  ('seedy', 6),
#  ('belgian', 6),
#  ('swedish', 6),
#  ('refried', 6),
#  ('caprese', 6),
#  ('overnight', 6),
#  ('rocky', 6),
#  ('saffron', 6),
#  ('herbed', 6),
#  ('filet', 6),
#  ('snapper', 6),
#  ('indonesian', 5),
#  ('african', 5),
#  ('pacific', 5),
#  ('mojito', 5),
#  ('nduja', 5),
#  ('pappardelle', 5),
#  ('mussel', 5),
#  ('southwest', 5),
#  ('jamaican', 5),
#  ('sprouted', 5),
#  ('original', 5),
#  ('shortcut', 5),
#  ('colombian', 5),
#  ('russian', 5),
#  ('sloppy', 5),
#  ('rösti', 5),
#  ('braised', 5),
#  ('beet', 5),
#  ('traditional', 5),
#  ('noodle', 5),
#  ('brioche', 5),
#  ('brazilian', 5),
#  ('celeriac', 5),
#  ('great', 5),
#  ('twice', 5),
#  ('thin', 5),
#  ('sourdough', 5),
#  ('norwegian', 5),
#  ('calabrian', 5),
#  ('udon', 5),
#  ('bbq', 5),
#  ('pecorino', 5),
#  ('beurre', 5),
#  ('mary', 5),
#  ('taiwanese', 5),
#  ('multi', 5),
#  ('praline', 5),
#  ('fontina', 5),
#  ('light', 4),
#  ('malaysian', 4),
#  ('leafy', 4),
#  ('minted', 4),
#  ('bluefish', 4),
#  ('california', 4),
#  ('edamame', 4),
#  ('long', 4),
#  ('gooey', 4),
#  ('sardine', 4),
#  ('bagna', 4),
#  ('fragrant', 4),
#  ('super', 4),
#  ('michael', 4),
#  ('charmoula', 4),
#  ('skinned', 4),
#  ('gravlax', 4),
#  ('miniature', 4),
#  ('gingered', 4),
#  ('sazerac', 4),
#  ('lobster', 4),
#  ('“', 4),
#  ('seeded', 4),
#  ('slab', 4),
#  ('craig', 4),
#  ('smothered', 4),
#  ('burmese', 4),
#  ('modern', 4),
#  ('danish', 4),
#  ('sole', 4),
#  ('peruvian', 4),
#  ('hawaiian', 4),
#  ('loaded', 4),
#  ('okonomiyaki', 4),
#  ('fried', 4),
#  ('fennel', 4),
#  ('chaat', 4),
#  ('brothy', 4),
#  ('cacao', 4),
#  ('campanelle', 4),
#  ('kale', 4),
#  ('chocolate', 4),
#  ('daikon', 4),
#  ('stormy', 4),
#  ('tapenade', 4),
#  ('smashed', 4),
#  ('late', 4),
#  ('low', 4),
#  ('grain', 4),
#  ('nori', 4),
#  ('yucatecan', 4),
#  ('punjabi', 3),
#  ('shulman', 3),
#  ('urchin', 3),
#  ('west', 3),
#  ('young', 3),
#  ('steamed', 3),
#  ('chouriço', 3),
#  ('georgian', 3),
#  ('fiery', 3),
#  ('nana', 3),
#  ('general', 3),
#  ('monte', 3),
#  ('calvados', 3),
#  ('brooklyn', 3),
#  ('mung', 3),
#  ('venetian', 3),
#  ('preserved', 3),
#  ('pickle', 3),
#  ('rose', 3),
#  ('flax', 3),
#  ('penne', 3),
#  ('london', 3),
#  ('north', 3),
#  ('migas', 3),
#  ('uncooked', 3),
#  ('malai', 3),
#  ('quinoa', 3),
#  ('seasoned', 3),
#  ('fizzy', 3),
#  ('outdoor', 3),
#  ('rican', 3),
#  ('last', 3),
#  ('hush', 3),
#  ('provencal', 3),
#  ('vegan', 3),
#  ('brisket', 3),
#  ('tiny', 3),
#  ('todd', 3),
#  ('laurie', 3),
#  ('speedy', 3),
#  ('high', 3),
#  ('din', 3),
#  ('foster', 3),
#  ('cool', 3),
#  ('du', 3),
#  ('fat', 3),
#  ('feuille', 3),
#  ('park', 3),
#  ('pollo', 3),
#  ('crushed', 3),
#  ('delicata', 3),
#  ('glazed', 3),
#  ('filipino', 3),
#  ('aligot', 3),
#  ('magic', 3),
#  ('corned', 3),
#  ('neapolitan', 3),
#  ('seasonal', 3),
#  ('sunny', 3),
#  ('drunken', 3),
#  ('split', 3),
#  ('umami', 3),
#  ('challah', 3),
#  ('crawfish', 3),
#  ('citrusy', 3),
#  ('adaptable', 3),
#  ('asada', 3),
#  ('chopped', 3),
#  ('loaf', 3),
#  ('puerto', 3),
#  ('marshmallow', 3),
#  ('sliced', 3),
#  ('crusted', 3),
#  ('carmelized', 3),
#  ('blt', 3),
#  ('healthyish', 3),
#  ('halvah', 3),
#  ('chai', 3),
#  ('ready', 3),
#  ('taco', 3),
#  ('porcini', 3),
#  ('wonton', 3),
#  ('madeira', 3),
#  ('nutty', 3),
#  ('veal', 3),
#  ('salvadoran', 3),
#  ('chianti', 2),
#  ('magica', 2),
#  ('southeast', 2),
#  ('galician', 2),
#  ('pimentón', 2),
#  ('more', 2),
#  ('15-minute', 2),
#  ('mustardy', 2),
#  ('sopa', 2),
#  ('serious', 2),
#  ('heavenly', 2),
#  ('sushi', 2),
#  ('yucatan', 2),
#  ('naked', 2),
#  ('manhattan', 2),
#  ('maria', 2),
#  ('potted', 2),
#  ('lox', 2),
#  ('majorcan', 2),
#  ('pungent', 2),
#  ('happy', 2),
#  ('bangladeshi', 2),
#  ('yuzu', 2),
#  ('guajillo', 2),
#  ('involtini', 2),
#  ('andean', 2),
#  ('large', 2),
#  ('momofuku', 2),
#  ('carolina', 2),
#  ('blanched', 2),
#  ('trini', 2),
#  ('susan', 2),
#  ('ravioli', 2),
#  ('tian', 2),
#  ('deconstructed', 2),
#  ('seitan', 2),
#  ('tempura', 2),
#  ('broiled', 2),
#  ('cultured', 2),
#  ('autumnal', 2),
#  ('ann', 2),
#  ('special', 2),
#  ('melissa', 2),
#  ('organic', 2),
#  ('april', 2),
#  ('sablefish', 2),
#  ('petal', 2),
#  ('boulevardi', 2),
#  ('simmered', 2),
#  ('deluxe', 2),
#  ('moong', 2),
#  ('clear', 2),
#  ('nashville', 2),
#  ('rosie', 2),
#  ('mule', 2),
#  ('laced', 2),
#  ('only', 2),
#  ('burst', 2),
#  ('bright', 2),
#  ('fast', 2),
#  ('tepary', 2),
#  ('poor', 2),
#  ('flavorful', 2),
#  ('texas', 2),
#  ('haitian', 2),
#  ('delicious', 2),
#  ('maureen', 2),
#  ('east', 2),
#  ('crusty', 2),
#  ('oleo', 2),
#  ('shanghai', 2),
#  ('wet', 2),
#  ('ripple', 2),
#  ('kosher', 2),
#  ('yemeni', 2),
#  ('famous', 2),
#  ('spare', 2),
#  ('dish', 2),
#  ('noyaux', 2),
#  ('atlantic', 2),
#  ('omelet', 2),
#  ('scratchy', 2),
#  ('jian', 2),
#  ('reverse', 2),
#  ('eton', 2),
#  ('faced', 2),
#  ('everyday', 2),
#  ('goose', 2),
#  ('reuben', 2),
#  ('salsa', 2),
#  ('pistachio', 2),
#  ('flat', 2),
#  ('runny', 2),
#  ('insalata', 2),
#  ('vide', 2),
#  ('embutido', 2),
#  ('popped', 2),
#  ('ube', 2),
#  ('northern', 2),
#  ('standard', 2),
#  ('ropa', 2),
#  ('oaxacan', 2),
#  ('caviar', 2),
#  ('gruyere', 2),
#  ('latin', 2),
#  ('vieux', 2),
#  ('125th', 2),
#  ('saba', 2),
#  ('provençale', 2),
#  ('puffy', 2),
#  ('acai', 2),
#  ('marmalade', 2),
#  ('antipasti', 2),
#  ('argentinian', 2),
#  ('artisanal', 2),
#  ('vinegar', 2),
#  ('basque', 2),
#  ('cornbread', 2),
#  ('aged', 2),
#  ('nice', 2),
#  ('blind', 2),
#  ('croissant', 2),
#  ('campsite', 2),
#  ('jerusalem', 2),
#  ('cayenne', 2),
#  ('bagel', 2),
#  ('carbonara', 2),
#  ('edible', 2),
#  ('chantilly', 2),
#  ('padrón', 2),
#  ('chi', 2),
#  ('frangelico', 2),
#  ('cran', 2),
#  ('dungeness', 2),
#  ('virgin', 2),
#  ('peachy', 2),
#  ('fennel-', 2),
#  ('fettuccine', 2),
#  ('fresno', 2),
#  ('achiote', 2),
#  ('shishito', 2),
#  ('sauteed', 2),
#  ('san', 2),
#  ('dill', 2),
#  ('healthy', 2),
#  ('jumbo', 2),
#  ('kansas', 2),
#  ('pancetta', 2),
#  ('limoncello', 2),
#  ('yogurt', 2),
#  ('crimini', 2),
#  ('matzo', 2),
#  ('nacho', 2),
#  ('crazy', 2),
#  ('scented', 2),
#  ('shellfish', 2),
#  ('pancetta-', 2),
#  ('parfait', 2),
#  ('pisco', 2),
#  ('pluot', 2),
#  ('nutritional', 2),
#  ('puff', 2),
#  ('rosy', 2),
#  ('scampi', 2),
#  ('silky', 2),
#  ('aïoli', 2),
#  ('tiramisù', 2),
#  ('vadouvan', 2),
#  ('sebastiani', 1),
#  ('barcelona', 1),
#  ('bistec', 1),
#  ('thyme', 1),
#  ('plain', 1),
#  ('atomic', 1),
#  ('publican', 1),
#  ('rye', 1),
#  ('campbell', 1),
#  ('devil', 1),
#  ('muddy', 1),
#  ('ligurian', 1),
#  ('laban', 1),
#  ('thick', 1),
#  ('pbj', 1),
#  ('iroquois', 1),
#  ('chimichurri', 1),
#  ('boulangère', 1),
#  ('single', 1),
#  ('manchurian', 1),
#  ('triggerfish', 1),
#  ('northeastern', 1),
#  ('hefty', 1),
#  ('artisan', 1),
#  ('yakisoba', 1),
#  ('henrietta', 1),
#  ('hallaq', 1),
#  ('louisiana', 1),
#  ('italianate', 1),
#  ('stale', 1),
#  ('bavarian', 1),
#  ('rumtopf', 1),
#  ('séjour', 1),
#  ('ellen', 1),
#  ('andalusian', 1),
#  ('asado', 1),
#  ('ted', 1),
#  ('bess', 1),
#  ('feigenbaum', 1),
#  ('mock', 1),
#  ('tagine', 1),
#  ('live', 1),
#  ('marinara', 1),
#  ('rosados', 1),
#  ('moorish', 1),
#  ('blackfish', 1),
#  ('witbi', 1),
#  ('pesto', 1),
#  ('firm', 1),
#  ('gateau', 1),
#  ('sturdy', 1),
#  ('bosnian', 1),
#  ('argan', 1),
#  ('bloomed', 1),
#  ('granny', 1),
#  ('bulgarian', 1),
#  ('ukrainian', 1),
#  ('macedonian', 1),
#  ('hete', 1),
#  ('algerian', 1),
#  ('post', 1),
#  ('thanksgiving', 1),
#  ('hyderabad', 1),
#  ('makhani', 1),
#  ('mogul', 1),
#  ('souffléed', 1),
#  ('lean', 1),
#  ('galbi', 1),
#  ('laurent', 1),
#  ('mendiant', 1),
#  ('cochin', 1),
#  ('iranian', 1),
#  ('deborah', 1),
#  ('scarlet', 1),
#  ('libre', 1),
#  ('egyptian', 1),
#  ('pasqualina', 1),
#  ('sangria', 1),
#  ('panelle', 1),
#  ('genévri', 1),
#  ('quintessential', 1),
#  ('costa', 1),
#  ('brighton', 1),
#  ('seeni', 1),
#  ('baghali', 1),
#  ('cellophane', 1),
#  ('jewish', 1),
#  ('pizzeria', 1),
#  ('merciful', 1),
#  ('bengali', 1),
#  ('balkan', 1),
#  ('cajun', 1),
#  ('alsatian', 1),
#  ('louie', 1),
#  ('ald', 1),
#  ('borscht', 1),
#  ('sungold', 1),
#  ('fitty', 1),
#  ('mele', 1),
#  ('za’atar', 1),
#  ('kenneth', 1),
#  ('appleberry', 1),
#  ('mad', 1),
#  ('cary', 1),
#  ('coloradito', 1),
#  ('bihari', 1),
#  ('corny', 1),
#  ('purloined', 1),
#  ('15-grain', 1),
#  ('flageolet', 1),
#  ('minimalist', 1),
#  ('liberian', 1),
#  ('rick', 1),
#  ('sablé', 1),
#  ('juive', 1),
#  ('lav', 1),
#  ('tall', 1),
#  ('temporary', 1),
#  ('triangulo', 1),
#  ('cordial', 1),
#  ('alaskan', 1),
#  ('tabard', 1),
#  ('bad', 1),
#  ('simplest', 1),
#  ('sedgemoor', 1),
#  ('charlie', 1),
#  ('navel', 1),
#  ('louro', 1),
#  ('sanctimonious', 1),
#  ('spotted', 1),
#  ('oyster', 1),
#  ('rhum', 1),
#  ('tony', 1),
#  ('rawia', 1),
#  ('missionary', 1),
#  ('unstrung', 1),
#  ('sangrita', 1),
#  ('frittata', 1),
#  ('main', 1),
#  ('butterf', 1),
#  ('mare', 1),
#  ('pre', 1),
#  ('summer', 1),
#  ('vichy', 1),
#  ('tavern', 1),
#  ('rhode', 1),
#  ('many', 1),
#  ('mighty', 1),
#  ('salad', 1),
#  ('puritan', 1),
#  ('armenian', 1),
#  ('whist', 1),
#  ('impossible', 1),
#  ('aylenish', 1),
#  ('cal', 1),
#  ('mauro', 1),
#  ('jeremy', 1),
#  ('supernatural', 1),
#  ('unmeasured', 1),
#  ('crockpot', 1),
#  ('gillette', 1),
#  ('secret', 1),
#  ('ghanaian', 1),
#  ('olio', 1),
#  ('walnut', 1),
#  ('excellent', 1),
#  ('lassi', 1),
#  ('finnish', 1),
#  ('île', 1),
#  ('anselm', 1),
#  ('fourth', 1),
#  ('monkfish', 1),
#  ('ultrafast', 1),
#  ('puesta', 1),
#  ('marianito', 1),
#  ('exciting', 1),
#  ('next', 1),
#  ('lucky', 1),
#  ('ginga', 1),
#  ('pastel', 1),
#  ('festive', 1),
#  ('sassy', 1),
#  ('luchetti', 1),
#  ('sephardic', 1),
#  ('cellar', 1),
#  ('hull', 1),
#  ('colorful', 1),
#  ('springtime', 1),
#  ('nico', 1),
#  ('updated', 1),
#  ('gefilte', 1),
#  ('friendly', 1),
#  ('hainanese', 1),
#  ('salle', 1),
#  ('pleyel', 1),
#  ('beet-', 1),
#  ('cali', 1),
#  ('harira', 1),
#  ('optional', 1),
#  ('strained', 1),
#  ('shakshuka', 1),
#  ('nwa', 1),
#  ('umbrian', 1),
#  ('codfish', 1),
#  ('hummingbird', 1),
#  ('smart', 1),
#  ('pakistani', 1),
#  ('singaporean', 1),
#  ('seelbach', 1),
#  ('venezuelan', 1),
#  ('somali', 1),
#  ('hmong', 1),
#  ('normande', 1),
#  ('tourtière', 1),
#  ('nordic', 1),
#  ('syrian', 1),
#  ('frangipane', 1),
#  ('utica', 1),
#  ('false', 1),
#  ('wintertime', 1),
#  ('griddled', 1),
#  ('twin', 1),
#  ('frosty', 1),
#  ('pro', 1),
#  ('philadelphia', 1),
#  ('patra', 1),
#  ('machhi', 1),
#  ('ispahan', 1),
#  ('bryant', 1),
#  ('nuong', 1),
#  ('enchilada', 1),
#  ('doro', 1),
#  ('ethiopian', 1),
#  ('uchucuta', 1),
#  ('62nd', 1),
#  ('soufflazy', 1),
#  ('mussa', 1),
#  ('lucali', 1),
#  ('crab', 1),
#  ('own', 1),
#  ('tembleque', 1),
#  ('blond', 1),
#  ('santiago', 1),
#  ('oyakodon', 1),
#  ('oreo', 1),
#  ('francese', 1),
#  ('vinegared', 1),
#  ('sonoran', 1),
#  ('gajar', 1),
#  ('ganache', 1),
#  ('dávila', 1),
#  ('pastitsio', 1),
#  ('freestyle', 1),
#  ('huevos', 1),
#  ('loco', 1),
#  ('xo', 1),
#  ('obe', 1),
#  ('yuca', 1),
#  ('jumble', 1),
#  ('bavette', 1),
#  ('libyan', 1),
#  ('kentucky', 1),
#  ('pancit', 1),
#  ('7up', 1),
#  ('flutemaginley', 1),
#  ('abstract', 1),
#  ('kaddu', 1),
#  ('seis', 1),
#  ('ceci', 1),
#  ('lablabi', 1),
#  ('frico', 1),
#  ('meen', 1),
#  ('handmade', 1),
#  ('pierre', 1),
#  ('eventide', 1),
#  ('khachapuri', 1),
#  ('spatchcocked', 1),
#  ('greg', 1),
#  ('juneteenth', 1),
#  ('suprême', 1),
#  ('volaille', 1),
#  ('fermière', 1),
#  ('cervelle', 1),
#  ('marbled', 1),
#  ('shalom', 1),
#  ('crunchi', 1),
#  ('yakitori', 1),
#  ('tatemada', 1),
#  ('choco', 1),
#  ('sook', 1),
#  ('maharashtrian', 1),
#  ('lard', 1),
#  ('gamja', 1),
#  ('mughlai', 1),
#  ('iga', 1),
#  ('balinese', 1),
#  ('numbing', 1),
#  ('pure', 1),
#  ('yerushalmi', 1),
#  ('octopus', 1),
#  ('drunkard', 1),
#  ('12-minute', 1),
#  ('anne', 1),
#  ('ikra', 1),
#  ('fishmong', 1),
#  ('tibetan', 1),
#  ('leftover', 1),
#  ('cannoli', 1),
#  ('ashkinaze', 1),
#  ('presidente', 1),
#  ('pegu', 1),
#  ('junior', 1),
#  ('muddled', 1),
#  ('victorian', 1),
#  ('makai', 1),
#  ('grainy', 1),
#  ('chivito', 1),
#  ('pomodoro', 1),
#  ('amazing', 1),
#  ('right', 1),
#  ('bean', 1),
#  ('ibérico', 1),
#  ('mandoo', 1),
#  ('abuelo', 1),
#  ('albertine', 1),
#  ('afghan', 1),
#  ('beehive', 1),
#  ('24th', 1),
#  ('30-minute', 1),
#  ('wibble', 1),
#  ('local', 1),
#  ('açai', 1),
#  ('adam', 1),
#  ('affogato', 1),
#  ('alabama', 1),
#  ('alive', 1),
#  ('banana', 1),
#  ('plum', 1),
#  ('amalfi', 1),
#  ('donabe', 1),
#  ('brad', 1),
#  ('back', 1),
#  ('rosewater', 1),
#  ('barbari', 1),
#  ('piña', 1),
#  ('croque', 1),
#  ('stuffed', 1),
#  ('beverly', 1),
#  ('hunt', 1),
#  ('bistro', 1),
#  ('malted', 1),
#  ('kelp', 1),
#  ('bluewat', 1),
#  ('prune', 1),
#  ('skinless', 1),
#  ('burrito', 1),
#  ('british', 1),
#  ('broccolini', 1),
#  ('shut', 1),
#  ('paratha', 1),
#  ('butter-', 1),
#  ('gala', 1),
#  ('camille', 1),
#  ('cardamom', 1),
#  ('caribbean', 1),
#  ('carole', 1),
#  ('ceremonial', 1),
#  ('dangerous', 1),
#  ('daily', 1),
#  ('amish', 1),
#  ('chef', 1),
#  ('chewy', 1),
#  ('membrillo', 1),
#  ('chicory', 1),
#  ('rubbed', 1),
#  ('tortechocolate', 1),
#  ('chopstick', 1),
#  ('chickpea', 1),
#  ('applejack', 1),
#  ...]
